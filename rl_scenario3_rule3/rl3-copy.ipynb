# %% [markdown]
# # ga 3

# %%
import random
import numpy as np
import math
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt  # Importar matplotlib para plotar gráficos
from functools import partial  # Adicionar no início do código
import networkx as nx
from link_capacity import calcular_capacidade_link, interference_from_jammer
from antenna_null import realistic_antenna_gain

NUM_UAVS = 4
lambda_0 = 0.125
P_INTERFERENCE_DBM = 100
P_NOISE_DBM = -100
BANDWIDTH = 20e6
TRANSMIT_POWER_DBM = 20
MINDIST = 20

# Definir os tipos de indivíduos e fitness
creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # Maximizar o fitnessAS
creator.create("Individual", list, fitness=creator.FitnessMax)  # Indivíduo é uma listaas

#ATENCAO JAMMER POSITION NO CREATE INDIVIDUAL

# Nova função para criar um indivíduo
def create_individual(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, epoch_total_length=200, previous_best_solution=None, initial_positions=None, jammer_position=None):
    individual = []
    
    # Definir as posições iniciais de acordo com o epoch
    if epoch == 0:
        start_positions = initial_positions  # Posições fixas passadas manualmente
    else:
        start_positions = []
        for uav in range(num_uavs):
            last_timeslot_idx = (num_timeslots - 1) * num_uavs * 2 + uav * 2
            start_positions.append(previous_best_solution[last_timeslot_idx:last_timeslot_idx + 2])
    
    # Gerar posições finais adaptado à tua lógica
    final_positions = []
    for uav in range(num_uavs):
        if epoch == 0:
            # Epoch 1: 0 → 200 (epoch_length)
            last_x = random.uniform(epoch_total_length - timeslot_length, epoch_total_length)
        else:
            # Epoch 2: 100 → 300, Epoch 3: 200 → 400, etc.
            end_position = epoch_total_length + (epoch * timeslot_length)
            last_x = random.uniform(end_position - timeslot_length, end_position)
        
        last_y = random.uniform(min_y, max_y)
        final_positions.append([last_x, last_y])
    
    # Calcular todas as posições intermediárias
    for t in range(num_timeslots):
        for uav in range(num_uavs):
            start_x, start_y = start_positions[uav]
            end_x, end_y = final_positions[uav]
            
            # Calcular posição baseada no progresso linear
            alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
            
            x = start_x + alpha * (end_x - start_x)
            y = start_y + alpha * (end_y - start_y)
            
            # Adicionar x,y ao indivíduo
            individual.extend([x, y])
    
    return creator.Individual(individual)


def print_communication_values_per_timeslot(individual, num_uavs, num_timeslots, jammer_position):
    all_min_capacities = []
    all_interference_matrices = []
    all_fitness_values = []  # ← ADICIONAR para armazenar fitness de cada timeslot

    for t in range(num_timeslots):
        angles = []
        positions = []
        
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        comm_matrix, interference_matrix = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)
        all_interference_matrices.append(interference_matrix)

        # ← USAR A MESMA LÓGICA DO evaluate_individual
        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))
                    except:
                        pass
        
        # Cálculo usando apenas links usados (IGUAL AO evaluate_individual)
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
            all_min_capacities.extend(capacidades_usadas)  # ← Adicionar todas as capacidades usadas
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Calcular fitness do timeslot (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness = (C_media_total ** alpha) * (C_min_total ** beta)
        all_fitness_values.append(fitness)

    # Calcular fitness médio (IGUAL AO evaluate_individual)
    if len(all_fitness_values) > 0:
        avg_fitness = sum(all_fitness_values) / len(all_fitness_values)
    else:
        avg_fitness = 0.0

    if len(all_min_capacities) > 0:
        avg_min_capacity = sum(all_min_capacities) / len(all_min_capacities)
    else:
        avg_min_capacity = 0.0

    return all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness  # ← ADICIONAR avg_fitness

# Função para calcular a capacidade de comunicação entre todos os UAVs
def calculate_communication_capacity(antenna_angles, alignments, positions, jammer_position):
    communication_capacity = np.zeros((NUM_UAVS, NUM_UAVS))
    interference_matrix = np.full((NUM_UAVS, NUM_UAVS), P_INTERFERENCE_DBM)

    for i in range(NUM_UAVS):
        null_dir_i = antenna_angles[i]

        dx_jam = jammer_position[0] - positions[i][0]
        dy_jam = jammer_position[1] - positions[i][1]
        dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360

        G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)

        dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
        P_interf_dBm_i = interference_from_jammer(P_INTERFERENCE_DBM, G_jammer_i, lambda_0, dist_jammer_i)

        interference_matrix[i, :] = P_interf_dBm_i

    for i in range(NUM_UAVS):
        for j in range(NUM_UAVS):
            if i != j:
                null_dir_i = antenna_angles[i]
                null_dir_j = antenna_angles[j]

                dx_ij = positions[j][0] - positions[i][0]
                dy_ij = positions[j][1] - positions[i][1]
                dir_tx_to_rx = np.degrees(np.arctan2(dy_ij, dx_ij)) % 360

                dx_ji = positions[i][0] - positions[j][0]
                dy_ji = positions[i][1] - positions[j][1]
                dir_rx_to_tx = np.degrees(np.arctan2(dy_ji, dx_ji)) % 360

                G_tx = realistic_antenna_gain(dir_tx_to_rx, null_dir_i)
                G_rx = realistic_antenna_gain(dir_rx_to_tx, null_dir_j)

                capacity = calcular_capacidade_link(
                    pos1=positions[i],
                    pos2=positions[j],
                    lambda_0=lambda_0,
                    P_tx_dBm=TRANSMIT_POWER_DBM,
                    G_tx_dB=G_tx,
                    G_rx_dB=G_rx,
                    P_interference_dBm=interference_matrix[i, j],
                    P_noise_dBm=P_NOISE_DBM,
                    bandwidth=BANDWIDTH
                )

                communication_capacity[i][j] = capacity

    return communication_capacity, interference_matrix

def has_collision(individual, num_uavs, num_timeslots, min_distance=MINDIST):
    """
    Verifica se há pelo menos uma colisão nas posições dos timeslots.
    Para na primeira colisão encontrada.
    
    Args:
        individual: Lista com as posições [x1, y1, x2, y2, ...]
        num_uavs: Número de UAVs
        num_timeslots: Número de timeslots
        min_distance: Distância mínima de segurança
    
    Returns:
        bool: True se há pelo menos uma colisão, False caso contrário
    """
    # Verificar cada timeslot
    for t in range(num_timeslots):
        # Extrair posições de todos os UAVs neste timeslot
        positions = []
        for uav in range(num_uavs):
            idx_x = t * num_uavs * 2 + uav * 2
            idx_y = t * num_uavs * 2 + uav * 2 + 1
            x = individual[idx_x]
            y = individual[idx_y]
            positions.append(np.array([x, y]))
        
        # Verificar colisões entre todos os pares de UAVs neste timeslot
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                distance = np.linalg.norm(positions[i] - positions[j])
                if distance < min_distance:
                    return True  # PARA IMEDIATAMENTE na primeira colisão
    
    return False  # Nenhuma colisão encontrada

def evaluate_individual(individual, num_uavs, num_timeslots, jammer_position):
    # Verificar se há pelo menos uma colisão
    if has_collision(individual, num_uavs, num_timeslots):
        return (0.0,)  # FITNESS 0 imediatamente
    
    # Se não há colisões, calcular o fitness normalmente
    alpha, beta = 1.0, 1.0
    total_fitness = 0

    for t in range(num_timeslots):
        positions = []
        angles = []
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            # Calcular ângulo dinamicamente
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        # Calcular matriz de comunicação
        comm_matrix, _ = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)

        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Cálculo do fitness usando apenas links usados
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Fitness sem penalização por colisões (já sabemos que não há colisões)
        fitness = (C_media_total ** alpha) * (C_min_total ** beta)
        total_fitness += fitness

    # Calcular a média do fitness total
    average_fitness = total_fitness / num_timeslots if num_timeslots > 0 else 0
    return (average_fitness,)

def mutate_individual(individual, min_x, max_x, min_y, max_y, mutation_rate, num_uavs, num_timeslots, epoch, timeslot_length, epoch_total_length):
    for uav in range(num_uavs):
        if random.random() < mutation_rate:
            # Extrair posições iniciais
            start_x = individual[uav * 2]
            start_y = individual[uav * 2 + 1]
            
            # Nova posição final - ADAPTADO À TUA LÓGICA
            if epoch == 0:
                # Epoch 1: 0 → 200 (epoch_length)
                new_final_x = random.uniform(epoch_total_length - timeslot_length, epoch_total_length)
            else:
                # Epoch 2: 100 → 300, Epoch 3: 200 → 400, etc.
                end_position = epoch_total_length + (epoch * timeslot_length)
                new_final_x = random.uniform(end_position - timeslot_length, end_position)
            
            new_final_y = random.uniform(min_y, max_y)
            
            # Atualizar a posição final
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2] = new_final_x
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2 + 1] = new_final_y
            
            # Recalcular posições intermediárias (t=1 até num_timeslots-1)
            for t in range(1, num_timeslots):
                alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
                x = start_x + alpha * (new_final_x - start_x)
                y = start_y + alpha * (new_final_y - start_y)
                
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                individual[idx_x] = x
                individual[idx_y] = y
    
    return individual,


def custom_crossover(ind1, ind2, num_uavs):
    num_timeslots = len(ind1) // (num_uavs * 2)
    
    # Trocar posições de UAVs inteiros (exceto a posição inicial t=0)
    for uav in range(num_uavs):
        if random.random() < 0.5:
            for t in range(1, num_timeslots):  # Começar de t=1
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                
                # Trocar x,y para todos os timeslots deste UAV (exceto t=0)
                ind1[idx_x], ind2[idx_x] = ind2[idx_x], ind1[idx_x]
                ind1[idx_y], ind2[idx_y] = ind2[idx_y], ind1[idx_y]
    
    return ind1, ind2

# Configuração do DEAP atualizada
def setup_deap(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, crossover_rate, mutation_rate, initial_positions, previous_best_solution=None, jammer_position=None, epoch_total_length=300):
    toolbox = base.Toolbox()
    
    # Registrar funções
    toolbox.register("individual", create_individual, 
                     num_uavs=num_uavs, 
                     num_timeslots=num_timeslots, 
                     timeslot_length=timeslot_length, 
                     epoch=epoch, 
                     min_y=min_y, 
                     max_y=max_y,
                     epoch_total_length=epoch_total_length,  # ← ADICIONAR
                     previous_best_solution=previous_best_solution,
                     initial_positions=initial_positions,
                     jammer_position=jammer_position)  # Passar a posição do jammer aqui
    
    # O restante do código permanece o mesmo...

    
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("evaluate", evaluate_individual, num_uavs=num_uavs, num_timeslots=num_timeslots, jammer_position=jammer_position)
    
    # Usar partial para fixar o argumento num_uavs na função custom_crossover
    toolbox.register("mate", partial(custom_crossover, num_uavs=num_uavs))
    
    min_x = epoch * num_timeslots * timeslot_length
    max_x = (epoch * num_timeslots + num_timeslots) * timeslot_length
    
    toolbox.register("mutate", mutate_individual, 
                 min_x=min_x, 
                 max_x=max_x, 
                 min_y=min_y, 
                 max_y=max_y, 
                 mutation_rate=mutation_rate,
                 num_uavs=num_uavs,
                 num_timeslots=num_timeslots,
                 epoch=epoch,
                 timeslot_length=timeslot_length,
                 epoch_total_length=epoch_total_length)  # ← ADICIONAR
    
    toolbox.register("select", tools.selTournament, tournsize=3)  # Seleção por torneio
    
    return toolbox

def genetic_algorithm(num_uavs, num_timeslots, timeslot_length, population_size, generations, crossover_rate, mutation_rate, epoch, initial_positions, previous_best_solution=None, jammer_position=None, min_y=0.0, max_y=5.0, epoch_total_length=300):
    # Configurar o DEAP
    toolbox = setup_deap(
        num_uavs=num_uavs,
        num_timeslots=num_timeslots,
        timeslot_length=timeslot_length,
        epoch=epoch,
        min_y=min_y,
        max_y=max_y,
        crossover_rate=crossover_rate,
        mutation_rate=mutation_rate,
        initial_positions=initial_positions,
        previous_best_solution=previous_best_solution,
        jammer_position=jammer_position,
        epoch_total_length=epoch_total_length  # ← ADICIONAR
    )

    
    # Criar população inicial
    population = toolbox.population(n=population_size)
    
    # Avaliar a população inicial
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit
    
    # Configurar estatísticas para impressão
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("std", np.std)
    stats.register("min", np.min)
    stats.register("max", np.max)
    
    # Listas para armazenar os dados de cada geração
    gen_list = []
    avg_list = []
    std_list = []
    min_list = []
    max_list = []
    
    # Executar o algoritmo genético com eaSimple
    for gen in range(generations):
        # Avançar uma geração
        algorithms.eaSimple(
            population, 
            toolbox, 
            cxpb=crossover_rate,  # Probabilidade de cruzamento
            mutpb=mutation_rate,  # Probabilidade de mutação
            ngen=1,               # Apenas uma geração por iteração
            stats=stats,          # Estatísticas para impressão
            verbose=False         # Desativar impressão da tabela para cada geração
        )
        
        # Coletar os dados da geração atual
        record = stats.compile(population)
        gen_list.append(gen)
        avg_list.append(record["avg"])
        std_list.append(record["std"])
        min_list.append(record["min"])
        max_list.append(record["max"])
        
        # Escrever os valores no arquivo
        #write_fitness_values(epoch, gen, record["avg"], record["max"], record["min"], record["std"])
    
    # Retornar o melhor indivíduo
    best_individual = tools.selBest(population, k=1)[0]
    return best_individual

# Função para gerar posições iniciais dos UAVs
def generate_initial_positions(num_uavs, min_y, max_y, timeslot_length, manual=False, manual_positions=None):
    if manual and manual_positions is not None:
        return manual_positions  # Usa as posições fornecidas

    positions = []
    max_attempts = 1000  # para evitar loops infinitos

    for _ in range(num_uavs):
        attempts = 0
        while True:
            y = random.uniform(min_y, max_y)
            x = random.uniform(0, timeslot_length)  # entre -timeslot_length e 0
            
            candidate = (x, y)
            
            # Verifica se está longe o suficiente das outras posições já geradas
            if all(np.linalg.norm(np.array(candidate) - np.array(pos)) >= MINDIST for pos in positions):
                positions.append(candidate)
                break
            
            attempts += 1
            if attempts >= max_attempts:
                # Se não conseguir, aceita a posição mesmo assim para evitar bloqueio
                positions.append(candidate)
                break
                
    return positions

# def save_best_solution_to_file(best_solution, initial_positions, filename="best_solution_epoch.txt"):
#     with open(filename, "a") as file:
#         # Escrever apenas a melhor solução (que já inclui tudo)
#         individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
#         file.write(f"{individual_str}\n \n")

def save_best_solution_to_file(best_solution, initial_positions, filename="best_solution_epoch.txt"):
    # Ler o conteúdo existente do arquivo
    try:
        with open(filename, "r") as file:
            existing_content = file.readlines()
            # Processar o conteúdo existente se necessário
            print("Conteúdo existente no arquivo:")
            for line in existing_content:
                print(line.strip())
    except FileNotFoundError:
        # Se o arquivo não existir, não há conteúdo para ler
        print("O arquivo não existe. Criando um novo arquivo.")

    # Escrever a nova melhor solução no final do arquivo
    with open(filename, "a") as file:
        individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
        file.write(f"{individual_str}\n\n")


def write_fitness_values(epoch, gen, avg, max_val, min_val, std, filename="fitness_values.txt"):
    
    with open(filename, "a") as file:
        if gen == 0:  # Escrever o cabeçalho no início de cada epoch
            file.write(f"=== Epoch {epoch + 1} ===\n")
            file.write("gen\tavg\tmax\tmin\tstd\n")
        file.write(f"{gen}\t{avg:.4f}\t{max_val:.4f}\t{min_val:.4f}\t{std:.4f}\n")

# Função principal atualizada
def simulate_uavs_with_ga(num_epochs, num_timeslots, timeslot_length, num_uavs, population_size=50, generations=50, crossover_rate=0.8, mutation_rate=0.15, manual_initial_positions=None, jammer_position=None, min_y=0.0, max_y=10.0, epoch_total_length=300):
    # Gerar posições iniciais dos UAVs
    initial_positions = generate_initial_positions(
        num_uavs, min_y, max_y, timeslot_length,
        manual=manual_initial_positions is not None,
        manual_positions=manual_initial_positions
    )

    previous_best_solution = None
    
    for epoch in range(num_epochs):
        # Executar o algoritmo genético
        best_solution = genetic_algorithm(
            num_uavs=num_uavs,
            num_timeslots=num_timeslots,
            timeslot_length=timeslot_length,
            population_size=population_size,
            generations=generations,
            crossover_rate=crossover_rate,
            mutation_rate=mutation_rate,
            epoch=epoch,
            initial_positions=initial_positions,
            previous_best_solution=previous_best_solution,
            jammer_position=jammer_position,  # Passar a posição do jammer aqui
            min_y=min_y,
            max_y=max_y,
            epoch_total_length=epoch_total_length  # ← ADICIONAR
        )

        # O restante do código permanece o mesmo...


        # Salvar a melhor solução em um arquivo de texto
        #save_best_solution_to_file(best_solution, initial_positions)
        
        all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness = print_communication_values_per_timeslot(best_solution, num_uavs, num_timeslots, jammer_position)

        # Guardar a melhor solução para a próxima epoch


        # # Calcular e imprimir a coerência dos valores
        # best_fitness = best_solution.fitness.values[0]
        # recalculated_fitness = evaluate_individual(best_solution, num_uavs, num_timeslots, jammer_position)[0]
        # # Ler o último valor máximo do fitness_values.txt
        # with open("fitness_values.txt", "r") as file:
        #     lines = file.readlines()
        #     last_max_fitness = float(lines[-1].split("\t")[2])  # Último max na última linha
        # # Comparar os valores
        # print(f"Fitness da melhor solução: {best_fitness:.4f}")
        # print(f"Fitness recalculado: {recalculated_fitness:.4f}")
        # print(f"Último max no arquivo: {last_max_fitness:.4f}")
        # print(f"São iguais? {'✅' if abs(best_fitness - last_max_fitness) < 1 else '❌'}")
        # # Guardar a melhor solução para a próxima epoch
        # previous_best_solution = best_solution



        previous_best_solution = best_solution

    return best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity
# Out:
# d:\Desktop\repo\gym\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# d:\Desktop\repo\gym\.venv\Lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %% [markdown]
# # RL 2

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces
import networkx as nx
from link_capacity import calcular_capacidade_link, interference_from_jammer
from antenna_null import realistic_antenna_gain

class UAVCommunicationEnv(gym.Env):
    def __init__(self, num_uavs=4, num_timeslots=6):
        super().__init__()
        
        # Parâmetros do ambiente
        self.num_uavs = num_uavs
        self.num_timeslots = num_timeslots
        
        # Áreas reais
        self.initial_area_real = (0, 60, 0, 60)      # x_min, x_max, y_min, y_max
        self.target_area_real = (60, 120, 0, 60)
        
        # Parâmetros de comunicação
        self.lambda_0 = 0.125
        self.P_INTERFERENCE_DBM = 100
        self.P_NOISE_DBM = -100
        self.BANDWIDTH = 20e6
        self.TRANSMIT_POWER_DBM = 20
        
        # Espaço de observação normalizado [0,1]: [uav1_x, uav1_y, ..., uav4_x, uav4_y, jammer_x, jammer_y]
        self.observation_space = spaces.Box(
            low=0.0,
            high=1.0,
            shape=(11,),  # 10 originais + 1 collision_score
            dtype=np.float32
        )
        
        # Espaço de ação normalizado [0,1]: [uav1_x_final, uav1_y_final, ..., uav4_x_final, uav4_y_final]
        self.action_space = spaces.Box(
            low=0.0,
            high=1.0,
            shape=(8,),  # 4 UAVs * 2 coords finais
            dtype=np.float32
        )

    def _normalize_uav_position(self, pos, area_type='initial'):
        """Normaliza posição de UAV para [0,1]"""
        if area_type == 'initial':
            x_min, x_max, y_min, y_max = self.initial_area_real
        elif area_type == 'target':
            x_min, x_max, y_min, y_max = self.target_area_real
        
        norm_x = (pos[0] - x_min) / (x_max - x_min)
        norm_y = (pos[1] - y_min) / (y_max - y_min)
        return np.array([norm_x, norm_y])
    
    def _normalize_jammer_position(self, pos):
        """Normaliza posição do jammer para [0,1]"""
        # Jammer: x ∈ [0,120], y = 500 (fixo)
        norm_x = pos[0] / 120.0  # x entre 0 e 120
        norm_y = 1.0  # y sempre 500, normalizado como 1.0
        return np.array([norm_x, norm_y])
    
    def _denormalize_uav_position(self, norm_pos, area_type='target'):
        """Desnormaliza posição de UAV de [0,1] para coordenadas reais"""
        if area_type == 'initial':
            x_min, x_max, y_min, y_max = self.initial_area_real
        elif area_type == 'target':
            x_min, x_max, y_min, y_max = self.target_area_real
        
        real_x = norm_pos[0] * (x_max - x_min) + x_min
        real_y = norm_pos[1] * (y_max - y_min) + y_min
        return np.array([real_x, real_y])

    def _generate_initial_positions(self):
        """Gera posições iniciais aleatórias"""
        positions = []
        
        for _ in range(self.num_uavs):
            x = np.random.uniform(0, 60)
            y = np.random.uniform(0, 60)
            positions.append(np.array([x, y]))
        
        return np.array(positions)

    def _calculate_reward(self, final_positions_real):
        """Calcula reward com penalização por colisões em todas as posições intermediárias e finais."""
        alpha, beta = 1.0, 1.0
        total_fitness = 0

        for t in range(self.num_timeslots):
            positions = []
            angles = []
            
            # Calcular posições interpoladas dos UAVs neste timeslot
            for i in range(self.num_uavs):
                start_pos = self.uav_positions_real[i]
                end_pos = final_positions_real[i]

                # Interpolação linear
                alpha_interp = t / (self.num_timeslots - 1) if self.num_timeslots > 1 else 0
                current_pos = start_pos + alpha_interp * (end_pos - start_pos)
                positions.append(current_pos)

                # Calcular ângulo da antena (direção oposta ao jammer)
                angle = np.degrees(np.arctan2(
                    self.jammer_position_real[1] - current_pos[1],
                    self.jammer_position_real[0] - current_pos[0]
                ))
                angles.append(angle)

            # 🔴 Verificar colisões neste timeslot
            if not self._check_no_collisions(positions):
                return 0.0  # colisão = reward 0 imediato

            # Calcular matriz de comunicação
            comm_matrix, _ = self._calculate_communication_capacity(
                angles, [1.0] * self.num_uavs, positions, self.jammer_position_real
            )

            # Avaliar grafo (mesma lógica do GA)
            G = nx.DiGraph()
            for i in range(self.num_uavs):
                for j in range(self.num_uavs):
                    if i != j and comm_matrix[i][j] > 0:
                        G.add_edge(i, j, capacity=comm_matrix[i][j])

            # Encontrar caminhos ativos
            links_usados = set()
            for i in range(self.num_uavs):
                for j in range(self.num_uavs):
                    if i != j:
                        try:
                            path = nx.shortest_path(G, source=i, target=j, 
                                                    weight=lambda u, v, d: 1/d['capacity'])
                            for u, v in zip(path[:-1], path[1:]):
                                links_usados.add((u, v))
                                links_usados.add((v, u))
                        except:
                            pass

            # Calcular fitness do timeslot
            capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados 
                                if u < self.num_uavs and v < self.num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0

            fitness = (C_media_total ** alpha) * (C_min_total ** beta)
            total_fitness += fitness

        # Reward médio (se não houve colisões)
        avg_fit = total_fitness / self.num_timeslots if self.num_timeslots > 0 else 0
        reward = np.log10(1.0 + avg_fit)

        return float(reward)

    def _check_no_collisions(self, positions, min_dist=20.0):
        """
        Retorna False se existir colisão (distância < min_dist) entre quaisquer UAVs.
        """
        for i in range(self.num_uavs):
            for j in range(i + 1, self.num_uavs):
                d = np.linalg.norm(positions[i] - positions[j])
                if d < min_dist:
                    return False  # colisão detectada
        return True

    def _calculate_communication_capacity(self, antenna_angles, alignments, positions, jammer_position):
        """Mesma função do teu código"""
        communication_capacity = np.zeros((self.num_uavs, self.num_uavs))
        interference_matrix = np.full((self.num_uavs, self.num_uavs), self.P_INTERFERENCE_DBM)

        for i in range(self.num_uavs):
            null_dir_i = antenna_angles[i]

            dx_jam = jammer_position[0] - positions[i][0]
            dy_jam = jammer_position[1] - positions[i][1]
            dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360

            G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)

            dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
            P_interf_dBm_i = interference_from_jammer(self.P_INTERFERENCE_DBM, G_jammer_i, 
                                                    self.lambda_0, dist_jammer_i)

            interference_matrix[i, :] = P_interf_dBm_i

        for i in range(self.num_uavs):
            for j in range(self.num_uavs):
                if i != j:
                    null_dir_i = antenna_angles[i]
                    null_dir_j = antenna_angles[j]

                    dx_ij = positions[j][0] - positions[i][0]
                    dy_ij = positions[j][1] - positions[i][1]
                    dir_tx_to_rx = np.degrees(np.arctan2(dy_ij, dx_ij)) % 360

                    dx_ji = positions[i][0] - positions[j][0]
                    dy_ji = positions[i][1] - positions[j][1]
                    dir_rx_to_tx = np.degrees(np.arctan2(dy_ji, dx_ji)) % 360

                    G_tx = realistic_antenna_gain(dir_tx_to_rx, null_dir_i)
                    G_rx = realistic_antenna_gain(dir_rx_to_tx, null_dir_j)

                    capacity = calcular_capacidade_link(
                        pos1=positions[i],
                        pos2=positions[j],
                        lambda_0=self.lambda_0,
                        P_tx_dBm=self.TRANSMIT_POWER_DBM,
                        G_tx_dB=G_tx,
                        G_rx_dB=G_rx,
                        P_interference_dBm=interference_matrix[i, j],
                        P_noise_dBm=self.P_NOISE_DBM,
                        bandwidth=self.BANDWIDTH
                    )

                    communication_capacity[i][j] = capacity

        return communication_capacity, interference_matrix
    
    def reset(self, initial_positions=None, jammer_position=None, seed=None, options=None):
        super().reset(seed=seed)
        
        # Usar posições fornecidas se existirem
        # if initial_positions is not None:
        #     self.uav_positions_real = np.array(initial_positions)
        # else:
        #     self.uav_positions_real = self._generate_initial_positions()

        # Fixar UAVs em posições conhecidas (por exemplo, formação linear)
        self.uav_positions_real = np.array([
            [20, 20],
            [20, 40],
            [40, 20],
            [40, 40]
        ])
        
        # if jammer_position is not None:
        #     self.jammer_position_real = np.array(jammer_position)
        # else:
        #     self.jammer_position_real = np.array([
        #         np.random.uniform(0, 120),
        #         500.0
        #     ])

        # Fixar jammer numa posição constante
        self.jammer_position_real = np.array([60.0, 500.0])
        
        # Normalizar para observação
        uav_positions_norm = []
        for pos in self.uav_positions_real:
            norm_pos = self._normalize_uav_position(pos, 'initial')
            uav_positions_norm.extend(norm_pos)
        
        jammer_norm = self._normalize_jammer_position(self.jammer_position_real)
        

        collision_level = self._calculate_collision_score(self.uav_positions_real)
        obs = np.concatenate([uav_positions_norm, jammer_norm, [collision_level]])

        
        return obs.astype(np.float32), {}

    def step(self, action):
        # Desnormalizar ações para coordenadas reais
        action_reshaped = action.reshape(4, 2)
        final_positions_real = []

        for norm_pos in action_reshaped:
            real_pos = self._denormalize_uav_position(norm_pos, 'target')
            final_positions_real.append(real_pos)

        final_positions_real = np.array(final_positions_real)

        # ✅ Guardar cópia das posições iniciais antes de atualizar
        initial_positions_copy = self.uav_positions_real.copy()

        # Calcular reward base
        reward = self._calculate_reward(final_positions_real)

        # Calcular penalização/ajuste por colisão
        collision_level = self._calculate_collision_score(final_positions_real)
        reward = reward * collision_level  # reduz reward se colididos


        # ✅ Normalizar o reward (mais informativo)
        #reward = reward / (1e8 + reward)

        # ✅ Nova observação = posições finais (não as iniciais)
        uav_positions_norm = []
        for pos in final_positions_real:
            norm_pos = self._normalize_uav_position(pos, 'target')
            uav_positions_norm.extend(norm_pos)

        jammer_norm = self._normalize_jammer_position(self.jammer_position_real)
        collision_level = self._calculate_collision_score(final_positions_real)

        obs = np.concatenate([uav_positions_norm, jammer_norm, [collision_level]])


        # Episódio termina (decisão única)
        terminated = True
        truncated = False

        info = {
            'initial_positions_real': initial_positions_copy,  # 👈 corrigido
            'final_positions_real': final_positions_real,
            'jammer_position_real': self.jammer_position_real
        }

        return obs.astype(np.float32), reward, terminated, truncated, info

    def _calculate_collision_score(self, positions):
        """
        Retorna:
        1.0 → seguro (sem colisões)
        0.0 → colisão (distância < 20 m)
        """
        min_dist = 20.0
        for i in range(self.num_uavs):
            for j in range(i + 1, self.num_uavs):
                d = np.linalg.norm(positions[i] - positions[j])
                if d < min_dist:
                    return 0.0  # colisão = morte total
        return 1.0  # nenhum par colide


# Função para salvar (adiciona antes do if __name__ == "__main__":)
def save_best_solution_to_file(initial_positions, final_positions, num_timeslots=6, filename="best_solution_rl.txt"):
    """
    Salva a melhor solução do RL no mesmo formato do GA
    """
    # Ler o conteúdo existente do arquivo
    try:
        with open(filename, "r") as file:
            existing_content = file.readlines()
            print("Conteúdo existente no arquivo:")
            for line in existing_content:
                print(line.strip())
    except FileNotFoundError:
        print("O arquivo não existe. Criando um novo arquivo.")

    # Criar a solução completa (mesmo formato do GA)
    best_solution = []
    
    # Para cada timeslot, calcular posições interpoladas
    for t in range(num_timeslots):
        for uav in range(len(initial_positions)):
            start_pos = initial_positions[uav]
            end_pos = final_positions[uav]
            
            # Interpolação linear (mesma lógica do GA)
            alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
            x = start_pos[0] + alpha * (end_pos[0] - start_pos[0])
            y = start_pos[1] + alpha * (end_pos[1] - start_pos[1])
            
            best_solution.extend([x, y])

    # Escrever a nova melhor solução no final do arquivo
    with open(filename, "a") as file:
        individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
        file.write(f"{individual_str}\n\n")
    
    print(f"Solução salva com {len(best_solution)} valores")
    return best_solution

if __name__ == "__main__":
    env = UAVCommunicationEnv()
    
    # Resetar o ambiente (posições iniciais aleatórias válidas)
    obs, _ = env.reset()
    
    print(f"Observação inicial: {obs}")
    print(f"Shape observação: {obs.shape}")
    print(f"Nível inicial de colisão (collision_level): {obs[-1]:.3f}")  # 👈 estado inicial
    
    # Ação aleatória
    action = env.action_space.sample()
    print(f"\nAção aleatória: {np.round(action, 3)}")
    
    # Executar a ação
    obs, reward, terminated, truncated, info = env.step(action)
    
    # Calcular nível final de colisão (só nas posições finais, para debug)
    collision_level_final = env._calculate_collision_score(info['final_positions_real'])
    
    print(f"\nReward: {reward:.4f}")
    print(f"Nível final de colisão (collision_level): {collision_level_final:.3f}")  # 👈 agora vem da função
    
    print("\nPosições iniciais reais:")
    print(np.round(info['initial_positions_real'], 2))
    
    print("\nPosições finais reais:")
    print(np.round(info['final_positions_real'], 2))
    
    print(f"\nPosição jammer: {info['jammer_position_real']}")
# Out:
# Observação inicial: [0.33333334 0.33333334 0.33333334 0.6666667  0.6666667  0.33333334
#  0.6666667  0.6666667  0.5        1.         1.        ]
# Shape observação: (11,)
# Nível inicial de colisão (collision_level): 1.000
#
# Ação aleatória: [0.407 0.315 0.477 0.075 0.338 0.924 0.106 0.76 ]
#
# Reward: 0.0000
# Nível final de colisão (collision_level): 0.000
#
# Posições iniciais reais:
# [[20 20]
#  [20 40]
#  [40 20]
#  [40 40]]
#
# Posições finais reais:
# [[84.41 18.88]
#  [88.63  4.52]
#  [80.29 55.42]
#  [66.35 45.57]]
#
# Posição jammer: [ 60. 500.]

# %% [markdown]
# # treinar com dataset

# %% [markdown]
# #Jammer_X,Jammer_Y,Fitness,Média_C_media_total,Média_C_min_total,Initial_X1,Initial_Y1,Initial_X2,Initial_Y2,Initial_X3,Initial_Y3,Initial_X4,Initial_Y4,Final_X1,Final_Y1,Final_X2,Final_Y2,Final_X3,Final_Y3,Final_X4,Final_Y4

# %%
import numpy as np
import pandas as pd

csv_path = "uav_dataset_reference_1_com_permutacoes.csv"
df = pd.read_csv(csv_path, comment='#')  # ignora header/comment

# Colunas esperadas (ex.: Jammer_X,Jammer_Y,Fitness,...,Final_X4,Final_Y4)
# Ajusta nomes se necessário

# Normalization helpers
def norm_initial(pos):
    # pos: (x,y) in [0,60] each
    return [(pos[0] - 0) / 60.0, (pos[1] - 0) / 60.0]

def norm_target(pos):
    # pos: (x,y) in [60,120] x [0,60]
    return [(pos[0] - 60.0) / 60.0, (pos[1] - 0) / 60.0]

def norm_jammer_x(x):
    return x / 120.0

# Construir arrays
N = len(df)
obs = np.zeros((N, 11), dtype=np.float32)
acts = np.zeros((N, 8), dtype=np.float32)

for i, row in df.iterrows():
    # jammer
    jx = row['Jammer_X']
    jy = row['Jammer_Y']  # provavelmente sempre 500
    # normalize jammer
    obs[i, 8] = norm_jammer_x(jx)
    obs[i, 9] = 1.0  # jy fixed -> 1.0 (mantém compatibilidade)

    # initial UAVs (columns Initial_X1, Initial_Y1, ...)
    for u in range(4):
        ix = row[f'Initial_X{u+1}']
        iy = row[f'Initial_Y{u+1}']
        obs[i, 2*u:2*u+2] = norm_initial((ix, iy))

    # final UAVs (target) -> actions (normalize target domain)
    for u in range(4):
        fx = row[f'Final_X{u+1}']
        fy = row[f'Final_Y{u+1}']
        acts[i, 2*u:2*u+2] = norm_target((fx, fy))

    # ✅ adicionar o collision_level fixo (sem cálculos)
    obs[i, 10] = 1.0

# Save for quick loading
np.savez_compressed("uav_dataset_reference_1_com_permutacoes_normalized.npz", obs=obs, acts=acts)
print("Saved:", obs.shape, acts.shape)
# Out:
# Saved: (305760, 11) (305760, 8)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

data = np.load("uav_dataset_reference_1_com_permutacoes_normalized.npz")

obs = torch.tensor(data["obs"], dtype=torch.float32)
acts = torch.tensor(data["acts"], dtype=torch.float32)
dataset = TensorDataset(obs, acts)
loader = DataLoader(dataset, batch_size=256, shuffle=True)

# %%
import torch.nn as nn

class PolicyNetwork(nn.Module):
    def __init__(self, input_dim=11, output_dim=8):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim),
            nn.Sigmoid()  # como as ações estão normalizadas em [0,1]
        )

    def forward(self, x):
        return self.net(x)

# %%
model = PolicyNetwork()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MSELoss()  # erro entre ação prevista e ação real do GA

# %%
n_epochs = 10
for epoch in range(n_epochs):
    total_loss = 0
    for batch_obs, batch_acts in loader:
        pred_acts = model(batch_obs)
        loss = criterion(pred_acts, batch_acts)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Época {epoch+1}/{n_epochs} - Loss: {total_loss/len(loader):.6f}")
# Out:
# Época 1/10 - Loss: 0.078301
# Época 2/10 - Loss: 0.075254
# Época 3/10 - Loss: 0.073567
# Época 4/10 - Loss: 0.072298
# Época 5/10 - Loss: 0.071523
# Época 6/10 - Loss: 0.071083
# Época 7/10 - Loss: 0.070801
# Época 8/10 - Loss: 0.070610
# Época 9/10 - Loss: 0.070437
# Época 10/10 - Loss: 0.070318

# %%
torch.save(model.state_dict(), "policy_pretrained_uav.pth")
print("Modelo pré-treinado salvo com sucesso!")
# Out:
# Modelo pré-treinado salvo com sucesso!

# %%
import torch
import numpy as np

# ===== 1. Recriar a mesma arquitetura usada no treino =====
class PolicyNetwork(torch.nn.Module):
    def __init__(self, input_dim=11, output_dim=8):
        super().__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(input_dim, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, output_dim),
            torch.nn.Sigmoid()  # ações normalizadas [0,1]
        )

    def forward(self, x):
        return self.net(x)

# ===== 2. Carregar modelo salvo =====
model = PolicyNetwork()
model.load_state_dict(torch.load("policy_pretrained_uav.pth", map_location="cpu"))
model.eval()  # modo teste
print("✅ Modelo carregado com sucesso!")

# ===== 3. Carregar uma amostra do dataset =====
data = np.load("uav_dataset_reference_1_com_permutacoes_normalized.npz")
obs = torch.tensor(data["obs"], dtype=torch.float32)
acts_true = torch.tensor(data["acts"], dtype=torch.float32)

# Escolher uma amostra aleatória
idx = np.random.randint(len(obs))
obs_sample = obs[idx].unsqueeze(0)
true_act = acts_true[idx]

# ===== 4. Fazer previsão =====
with torch.no_grad():
    pred_act = model(obs_sample).squeeze(0)

# ===== 5. Mostrar resultados =====
print("\n--- Teste de Policy Pré-Treinada ---")
print(f"Observação (normalizada): {obs_sample.numpy().round(3)}")
print(f"\nAção prevista pela policy: {pred_act.numpy().round(3)}")
print(f"Ação real do GA:           {true_act.numpy().round(3)}")

# (Opcional) diferença média
error = torch.mean((pred_act - true_act).abs()).item()
print(f"\nErro médio absoluto: {error:.5f}")
# Out:
# ✅ Modelo carregado com sucesso!
#
# --- Teste de Policy Pré-Treinada ---
# Observação (normalizada): [[0.333 0.333 1.    0.    0.    0.333 1.    0.333 0.5   1.    1.   ]]
#
# Ação prevista pela policy: [0.528 0.562 0.72  0.385 0.188 0.493 0.858 0.729]
# Ação real do GA:           [0.667 0.333 1.    0.333 0.333 0.333 1.    0.667]
#
# Erro médio absoluto: 0.15113

# %% [markdown]
# # ambiente com dataset - treino com pesos caregados

# %%
# Criar ambiente
env = UAVCommunicationEnv()
obs, _ = env.reset()

# Converter observação para tensor
obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)

# Gerar ação com o modelo pré-treinado
with torch.no_grad():
    pred_action = model(obs_tensor).squeeze(0).numpy()

# Passar essa ação ao ambiente
obs_next, reward, terminated, truncated, info = env.step(pred_action)

print("\n--- Teste no ambiente ---")
print(f"Ação prevista: {np.round(pred_action, 3)}")
print(f"Reward obtido: {reward:.4f}")
print(f"Posições finais reais:\n{np.round(info['final_positions_real'], 2)}")
# Out:
# --- Teste no ambiente ---
# Ação prevista: [0.222 0.37  0.288 0.691 0.768 0.387 0.855 0.719]
# Reward obtido: 0.0000
# Posições finais reais:
# [[ 73.31  22.18]
#  [ 77.29  41.49]
#  [106.06  23.2 ]
#  [111.27  43.14]]

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Criar o ambiente
env = make_vec_env(UAVCommunicationEnv, n_envs=4)

# %%
import torch

model = PPO("MlpPolicy", env, verbose=1)
pretrained_weights = torch.load("policy_pretrained_uav.pth", map_location="cpu")
model.policy.load_state_dict(pretrained_weights, strict=False)
print("✅ Pesos do pré-treino carregados na policy PPO!")
# Out:
# Using cpu device
# ✅ Pesos do pré-treino carregados na policy PPO!

# %%
model.learn(total_timesteps=300_000)
model.save("policy_finetuned.zip")
print("✅ Fine-tuning RL concluído!")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.0675   |
# | time/              |          |
# |    fps             | 583      |
# |    iterations      | 1        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0678      |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 2           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012364815 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0014      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00716    |
# |    std                  | 1.01        |
# |    value_loss           | 0.239       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 444        |
# |    iterations           | 3          |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00715751 |
# |    clip_fraction        | 0.0794     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.3      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.371      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.272     |
# |    std                  | 0.996      |
# |    value_loss           | 0.349      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 4            |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066694934 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.424       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.28        |
# |    std                  | 0.983        |
# |    value_loss           | 0.32         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.206       |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 5           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010083646 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08e-05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.977       |
# |    value_loss           | 0.424       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.139        |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 6            |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0107181715 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.1        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.351        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0165      |
# |    std                  | 0.972        |
# |    value_loss           | 0.619        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.205       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 7           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012881261 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.963       |
# |    value_loss           | 0.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.273       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 8           |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009742517 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.656       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.164      |
# |    std                  | 0.95        |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 9           |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011331115 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.665       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0292     |
# |    std                  | 0.938       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.341        |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 10           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0134468125 |
# |    clip_fraction        | 0.224        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.7        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.695        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0334      |
# |    std                  | 0.923        |
# |    value_loss           | 1.64         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.411       |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 11          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015628356 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.957       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0373     |
# |    std                  | 0.908       |
# |    value_loss           | 1.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.142       |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 12          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015692867 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0451     |
# |    std                  | 0.89        |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.546       |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 13          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.018202204 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0529     |
# |    std                  | 0.87        |
# |    value_loss           | 3.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.612       |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 14          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.026190337 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0597     |
# |    std                  | 0.847       |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 1.23        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 15          |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.036500506 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0688     |
# |    std                  | 0.821       |
# |    value_loss           | 5.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 16          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.057788484 |
# |    clip_fraction        | 0.516       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0815     |
# |    std                  | 0.786       |
# |    value_loss           | 6.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 2.52       |
# | time/                   |            |
# |    fps                  | 277        |
# |    iterations           | 17         |
# |    time_elapsed         | 501        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.10497006 |
# |    clip_fraction        | 0.593      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.02      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.03       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0971    |
# |    std                  | 0.737      |
# |    value_loss           | 8.7        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 3.66       |
# | time/                   |            |
# |    fps                  | 262        |
# |    iterations           | 18         |
# |    time_elapsed         | 561        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.10710734 |
# |    clip_fraction        | 0.588      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.44      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.8        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.683      |
# |    value_loss           | 11         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 4.8        |
# | time/                   |            |
# |    fps                  | 247        |
# |    iterations           | 19         |
# |    time_elapsed         | 629        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.08348743 |
# |    clip_fraction        | 0.556      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.83      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.68       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.636      |
# |    value_loss           | 11.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 5.28       |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 20         |
# |    time_elapsed         | 700        |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.05511277 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.31      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.14       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0961    |
# |    std                  | 0.598      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 5.74       |
# | time/                   |            |
# |    fps                  | 220        |
# |    iterations           | 21         |
# |    time_elapsed         | 779        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.04236789 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.84      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.52       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0844    |
# |    std                  | 0.566      |
# |    value_loss           | 8.26       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.01        |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 22          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.031798173 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.43       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0713     |
# |    std                  | 0.538       |
# |    value_loss           | 6.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.06        |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 23          |
# |    time_elapsed         | 941         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.025590718 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.057      |
# |    std                  | 0.514       |
# |    value_loss           | 4.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 5.99        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 24          |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.018693931 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0439     |
# |    std                  | 0.495       |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.4         |
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 25          |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.015268853 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0375     |
# |    std                  | 0.478       |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.59        |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 26          |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.013260534 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.675       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.462       |
# |    value_loss           | 1.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.6         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 27          |
# |    time_elapsed         | 1282        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.014278607 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.989       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.449       |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.52        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 28          |
# |    time_elapsed         | 1369        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.011660234 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.975       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.436       |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.45        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 29          |
# |    time_elapsed         | 1453        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.009267333 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00753    |
# |    std                  | 0.433       |
# |    value_loss           | 0.706       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.64        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 30          |
# |    time_elapsed         | 1540        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.012552252 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.364       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00728    |
# |    std                  | 0.425       |
# |    value_loss           | 0.791       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.46        |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 31          |
# |    time_elapsed         | 1627        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.013459284 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.323       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0062     |
# |    std                  | 0.417       |
# |    value_loss           | 0.674       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.72        |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 32          |
# |    time_elapsed         | 1715        |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.008694913 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00466    |
# |    std                  | 0.41        |
# |    value_loss           | 0.739       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.72        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 33          |
# |    time_elapsed         | 1802        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.012422428 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.331       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.402       |
# |    value_loss           | 0.713       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.67        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 34          |
# |    time_elapsed         | 1889        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.013146663 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.322       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0051     |
# |    std                  | 0.397       |
# |    value_loss           | 0.638       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.75        |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 35          |
# |    time_elapsed         | 1975        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.015407164 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.338       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00791    |
# |    std                  | 0.396       |
# |    value_loss           | 0.548       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.69        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 36          |
# |    time_elapsed         | 2060        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.016286759 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.711       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00793    |
# |    std                  | 0.388       |
# |    value_loss           | 0.815       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 6.69        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 37          |
# |    time_elapsed         | 2146        |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.020409886 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00998    |
# |    std                  | 0.382       |
# |    value_loss           | 0.725       |
# -----------------------------------------
# ✅ Fine-tuning RL concluído!

# %% [markdown]
# # testar ambiente

# %%
from stable_baselines3 import PPO
model = PPO.load("policy_finetuned.zip")

# %%
env_single = UAVCommunicationEnv()
obs, _ = env_single.reset()

# %%
action, _ = model.predict(obs, deterministic=True)
obs, reward, terminated, truncated, info = env_single.step(action)

print("Ação sugerida:", action)
print("Reward obtida:", reward)
print("Posições finais:", info['final_positions_real'])
print("Posição jammer:", info['jammer_position_real'])
# Out:
# Ação sugerida: [0. 0. 0. 1. 1. 0. 1. 1.]
# Reward obtida: 6.695992395294639
# Posições finais: [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
# Posição jammer: [ 60. 500.]

# %% [markdown]
# # novo

# %%
import gymnasium as gym
from matplotlib.pylab import seed
import numpy as np
from gymnasium import spaces
import networkx as nx
from link_capacity import calcular_capacidade_link, interference_from_jammer
from antenna_null import realistic_antenna_gain

class UAVCommunicationEnv(gym.Env):
    def __init__(self, num_uavs=4, num_timeslots=6):
        super().__init__()
        
        # Parâmetros do ambiente
        self.num_uavs = num_uavs
        self.num_timeslots = num_timeslots
        
        # Áreas reais
        self.initial_area_real = (0, 60, 0, 60)      # x_min, x_max, y_min, y_max
        self.target_area_real = (60, 120, 0, 60)
        
        # Parâmetros de comunicação
        self.lambda_0 = 0.125
        self.P_INTERFERENCE_DBM = 100
        self.P_NOISE_DBM = -100
        self.BANDWIDTH = 20e6
        self.TRANSMIT_POWER_DBM = 20
        
        # Espaço de observação normalizado [0,1]: [uav1_x, uav1_y, ..., uav4_x, uav4_y, jammer_x, jammer_y]
        self.observation_space = spaces.Box(
            low=0.0,
            high=1.0,
            shape=(11,),  # 10 originais + 1 collision_score
            dtype=np.float32
        )
        
        # Espaço de ação normalizado [0,1]: [uav1_x_final, uav1_y_final, ..., uav4_x_final, uav4_y_final]
        self.action_space = spaces.Box(
            low=0.0,
            high=1.0,
            shape=(8,),  # 4 UAVs * 2 coords finais
            dtype=np.float32
        )

    def _normalize_uav_position(self, pos, area_type='initial'):
        """Normaliza posição de UAV para [0,1]"""
        if area_type == 'initial':
            x_min, x_max, y_min, y_max = self.initial_area_real
        elif area_type == 'target':
            x_min, x_max, y_min, y_max = self.target_area_real
        
        norm_x = (pos[0] - x_min) / (x_max - x_min)
        norm_y = (pos[1] - y_min) / (y_max - y_min)
        return np.array([norm_x, norm_y])
    
    def _normalize_jammer_position(self, pos):
        """Normaliza posição do jammer para [0,1]"""
        # Jammer: x ∈ [0,120], y = 500 (fixo)
        norm_x = pos[0] / 120.0  # x entre 0 e 120
        norm_y = 1.0  # y sempre 500, normalizado como 1.0
        return np.array([norm_x, norm_y])
    
    def _denormalize_uav_position(self, norm_pos, area_type='target'):
        """Desnormaliza posição de UAV de [0,1] para coordenadas reais"""
        if area_type == 'initial':
            x_min, x_max, y_min, y_max = self.initial_area_real
        elif area_type == 'target':
            x_min, x_max, y_min, y_max = self.target_area_real
        
        real_x = norm_pos[0] * (x_max - x_min) + x_min
        real_y = norm_pos[1] * (y_max - y_min) + y_min
        return np.array([real_x, real_y])

    def _generate_initial_positions(self):
        """Gera posições iniciais aleatórias"""
        positions = []
        
        for _ in range(self.num_uavs):
            x = np.random.uniform(0, 60)
            y = np.random.uniform(0, 60)
            positions.append(np.array([x, y]))
        
        return np.array(positions)

    def _calculate_reward(self, final_positions_real):
        """Calcula reward com penalização por colisões em todas as posições intermediárias e finais."""
        alpha, beta = 1.0, 1.0
        total_fitness = 0

        for t in range(self.num_timeslots):
            positions = []
            angles = []
            
            # Calcular posições interpoladas dos UAVs neste timeslot
            for i in range(self.num_uavs):
                start_pos = self.uav_positions_real[i]
                end_pos = final_positions_real[i]

                # Interpolação linear
                alpha_interp = t / (self.num_timeslots - 1) if self.num_timeslots > 1 else 0
                current_pos = start_pos + alpha_interp * (end_pos - start_pos)
                positions.append(current_pos)

                # Calcular ângulo da antena (direção oposta ao jammer)
                angle = np.degrees(np.arctan2(
                    self.jammer_position_real[1] - current_pos[1],
                    self.jammer_position_real[0] - current_pos[0]
                ))
                angles.append(angle)

            # 🔴 Verificar colisões neste timeslot
            if not self._check_no_collisions(positions):
                return 0.0  # colisão = reward 0 imediato

            # Calcular matriz de comunicação
            comm_matrix, _ = self._calculate_communication_capacity(
                angles, [1.0] * self.num_uavs, positions, self.jammer_position_real
            )

            # Avaliar grafo (mesma lógica do GA)
            G = nx.DiGraph()
            for i in range(self.num_uavs):
                for j in range(self.num_uavs):
                    if i != j and comm_matrix[i][j] > 0:
                        G.add_edge(i, j, capacity=comm_matrix[i][j])

            # Encontrar caminhos ativos
            links_usados = set()
            for i in range(self.num_uavs):
                for j in range(self.num_uavs):
                    if i != j:
                        try:
                            path = nx.shortest_path(G, source=i, target=j, 
                                                    weight=lambda u, v, d: 1/d['capacity'])
                            for u, v in zip(path[:-1], path[1:]):
                                links_usados.add((u, v))
                                links_usados.add((v, u))
                        except:
                            pass

            # Calcular fitness do timeslot
            capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados 
                                if u < self.num_uavs and v < self.num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0

            fitness = (C_media_total ** alpha) * (C_min_total ** beta)
            total_fitness += fitness

        # Reward médio (se não houve colisões)
        avg_fit = total_fitness / self.num_timeslots if self.num_timeslots > 0 else 0
        reward = np.log10(1.0 + avg_fit)

        return float(reward)

    def _check_no_collisions(self, positions, min_dist=20.0):
        """
        Retorna False se existir colisão (distância < min_dist) entre quaisquer UAVs.
        """
        for i in range(self.num_uavs):
            for j in range(i + 1, self.num_uavs):
                d = np.linalg.norm(positions[i] - positions[j])
                if d < min_dist:
                    return False  # colisão detectada
        return True

    def _calculate_communication_capacity(self, antenna_angles, alignments, positions, jammer_position):
        """Mesma função do teu código"""
        communication_capacity = np.zeros((self.num_uavs, self.num_uavs))
        interference_matrix = np.full((self.num_uavs, self.num_uavs), self.P_INTERFERENCE_DBM)

        for i in range(self.num_uavs):
            null_dir_i = antenna_angles[i]

            dx_jam = jammer_position[0] - positions[i][0]
            dy_jam = jammer_position[1] - positions[i][1]
            dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360

            G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)

            dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
            P_interf_dBm_i = interference_from_jammer(self.P_INTERFERENCE_DBM, G_jammer_i, 
                                                    self.lambda_0, dist_jammer_i)

            interference_matrix[i, :] = P_interf_dBm_i

        for i in range(self.num_uavs):
            for j in range(self.num_uavs):
                if i != j:
                    null_dir_i = antenna_angles[i]
                    null_dir_j = antenna_angles[j]

                    dx_ij = positions[j][0] - positions[i][0]
                    dy_ij = positions[j][1] - positions[i][1]
                    dir_tx_to_rx = np.degrees(np.arctan2(dy_ij, dx_ij)) % 360

                    dx_ji = positions[i][0] - positions[j][0]
                    dy_ji = positions[i][1] - positions[j][1]
                    dir_rx_to_tx = np.degrees(np.arctan2(dy_ji, dx_ji)) % 360

                    G_tx = realistic_antenna_gain(dir_tx_to_rx, null_dir_i)
                    G_rx = realistic_antenna_gain(dir_rx_to_tx, null_dir_j)

                    capacity = calcular_capacidade_link(
                        pos1=positions[i],
                        pos2=positions[j],
                        lambda_0=self.lambda_0,
                        P_tx_dBm=self.TRANSMIT_POWER_DBM,
                        G_tx_dB=G_tx,
                        G_rx_dB=G_rx,
                        P_interference_dBm=interference_matrix[i, j],
                        P_noise_dBm=self.P_NOISE_DBM,
                        bandwidth=self.BANDWIDTH
                    )

                    communication_capacity[i][j] = capacity

        return communication_capacity, interference_matrix
    
    def reset(self, initial_positions=None, jammer_position=None, seed=None, options=None):
        super().reset(seed=seed)
        
        # 🔹 Usar posições fornecidas (ou gerar novas)
        if initial_positions is not None:
            self.uav_positions_real = np.array(initial_positions)
        else:
            self.uav_positions_real = self._generate_initial_positions()

        # 🔹 Usar jammer fornecido (ou gerar aleatório)
        if jammer_position is not None:
            self.jammer_position_real = np.array(jammer_position)
        else:
            jammer_x = np.random.uniform(0, 120)
            self.jammer_position_real = np.array([jammer_x, 500.0])
        
        # 🔹 Normalizar observação
        uav_positions_norm = []
        for pos in self.uav_positions_real:
            norm_pos = self._normalize_uav_position(pos, 'initial')
            uav_positions_norm.extend(norm_pos)

        jammer_norm = self._normalize_jammer_position(self.jammer_position_real)
        collision_level = self._calculate_collision_score(self.uav_positions_real)
        
        obs = np.concatenate([uav_positions_norm, jammer_norm, [collision_level]])
        return obs.astype(np.float32), {}

    def step(self, action):
        # Desnormalizar ações para coordenadas reais
        action_reshaped = action.reshape(4, 2)
        final_positions_real = []

        for norm_pos in action_reshaped:
            real_pos = self._denormalize_uav_position(norm_pos, 'target')
            final_positions_real.append(real_pos)

        final_positions_real = np.array(final_positions_real)

        # ✅ Guardar cópia das posições iniciais antes de atualizar
        initial_positions_copy = self.uav_positions_real.copy()

        # Calcular reward base
        reward = self._calculate_reward(final_positions_real)

        # Calcular penalização/ajuste por colisão
        collision_level = self._calculate_collision_score(final_positions_real)
        reward = reward * collision_level  # reduz reward se colididos


        # ✅ Normalizar o reward (mais informativo)
        #reward = reward / (1e8 + reward)

        # ✅ Nova observação = posições finais (não as iniciais)
        uav_positions_norm = []
        for pos in final_positions_real:
            norm_pos = self._normalize_uav_position(pos, 'target')
            uav_positions_norm.extend(norm_pos)

        jammer_norm = self._normalize_jammer_position(self.jammer_position_real)
        collision_level = self._calculate_collision_score(final_positions_real)

        obs = np.concatenate([uav_positions_norm, jammer_norm, [collision_level]])


        # Episódio termina (decisão única)
        terminated = True
        truncated = False

        info = {
            'initial_positions_real': initial_positions_copy,  # 👈 corrigido
            'final_positions_real': final_positions_real,
            'jammer_position_real': self.jammer_position_real
        }

        return obs.astype(np.float32), reward, terminated, truncated, info

    def _calculate_collision_score(self, positions):
        """
        Retorna:
        1.0 → seguro (sem colisões)
        0.0 → colisão (distância < 20 m)
        """
        min_dist = 20.0
        for i in range(self.num_uavs):
            for j in range(i + 1, self.num_uavs):
                d = np.linalg.norm(positions[i] - positions[j])
                if d < min_dist:
                    return 0.0  # colisão = morte total
        return 1.0  # nenhum par colide


# Função para salvar (adiciona antes do if __name__ == "__main__":)
def save_best_solution_to_file(initial_positions, final_positions, num_timeslots=6, filename="best_solution_rl.txt"):
    """
    Salva a melhor solução do RL no mesmo formato do GA
    """
    # Ler o conteúdo existente do arquivo
    try:
        with open(filename, "r") as file:
            existing_content = file.readlines()
            print("Conteúdo existente no arquivo:")
            for line in existing_content:
                print(line.strip())
    except FileNotFoundError:
        print("O arquivo não existe. Criando um novo arquivo.")

    # Criar a solução completa (mesmo formato do GA)
    best_solution = []
    
    # Para cada timeslot, calcular posições interpoladas
    for t in range(num_timeslots):
        for uav in range(len(initial_positions)):
            start_pos = initial_positions[uav]
            end_pos = final_positions[uav]
            
            # Interpolação linear (mesma lógica do GA)
            alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
            x = start_pos[0] + alpha * (end_pos[0] - start_pos[0])
            y = start_pos[1] + alpha * (end_pos[1] - start_pos[1])
            
            best_solution.extend([x, y])

    # Escrever a nova melhor solução no final do arquivo
    with open(filename, "a") as file:
        individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
        file.write(f"{individual_str}\n\n")
    
    print(f"Solução salva com {len(best_solution)} valores")
    return best_solution

if __name__ == "__main__":
    env = UAVCommunicationEnv()
    
    # Resetar o ambiente (posições iniciais aleatórias válidas)
    obs, _ = env.reset()
    
    print(f"Observação inicial: {obs}")
    print(f"Shape observação: {obs.shape}")
    print(f"Nível inicial de colisão (collision_level): {obs[-1]:.3f}")  # 👈 estado inicial
    
    # Ação aleatória
    action = env.action_space.sample()
    print(f"\nAção aleatória: {np.round(action, 3)}")
    
    # Executar a ação
    obs, reward, terminated, truncated, info = env.step(action)
    
    # Calcular nível final de colisão (só nas posições finais, para debug)
    collision_level_final = env._calculate_collision_score(info['final_positions_real'])
    
    print(f"\nReward: {reward:.4f}")
    print(f"Nível final de colisão (collision_level): {collision_level_final:.3f}")  # 👈 agora vem da função
    
    print("\nPosições iniciais reais:")
    print(np.round(info['initial_positions_real'], 2))
    
    print("\nPosições finais reais:")
    print(np.round(info['final_positions_real'], 2))
    
    print(f"\nPosição jammer: {info['jammer_position_real']}")
# Out:
# Observação inicial: [0.9877661  0.43570402 0.716469   0.5391555  0.24965817 0.2146129
#  0.80083466 0.6718551  0.04984722 1.         0.        ]
# Shape observação: (11,)
# Nível inicial de colisão (collision_level): 0.000
#
# Ação aleatória: [0.925 0.446 0.403 0.171 0.273 0.108 0.696 0.282]
#
# Reward: 0.0000
# Nível final de colisão (collision_level): 0.000
#
# Posições iniciais reais:
# [[59.27 26.14]
#  [42.99 32.35]
#  [14.98 12.88]
#  [48.05 40.31]]
#
# Posições finais reais:
# [[115.47  26.78]
#  [ 84.17  10.26]
#  [ 76.37   6.47]
#  [101.77  16.95]]
#
# Posição jammer: [  5.98166636 500.        ]

# %%
env = UAVCommunicationEnv()
for _ in range(3):
    obs, _ = env.reset()
    print("Jam:", env.jammer_position_real)
    print("UAVs:", np.round(env.uav_positions_real, 2))
    print("-" * 50)
# Out:
# Jam: [106.72439712 500.        ]
# UAVs: [[53.63  1.56]
#  [37.29  7.76]
#  [47.19 53.46]
#  [43.41 37.53]]
# --------------------------------------------------
# Jam: [ 78.65654103 500.        ]
# UAVs: [[53.74 59.85]
#  [30.59 19.8 ]
#  [ 2.41 44.56]
#  [26.19 10.38]]
# --------------------------------------------------
# Jam: [ 27.43609167 500.        ]
# UAVs: [[53.65 53.99]
#  [34.73 12.89]
#  [43.17 20.02]
#  [45.13  5.02]]
# --------------------------------------------------

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

env = make_vec_env(UAVCommunicationEnv, n_envs=4)
model = PPO.load("policy_finetuned.zip", env=env)

model.learn(total_timesteps=300_000)
model.save("policy_generalized.zip")

print("✅ Treino com randomização concluído!")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.132    |
# | time/              |          |
# |    fps             | 1075     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.257       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012329125 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.0209      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.265       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00335    |
# |    std                  | 0.368       |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.135       |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 3           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013818019 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0392      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00318    |
# |    std                  | 0.366       |
# |    value_loss           | 0.624       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.19      |
# | time/                   |           |
# |    fps                  | 626       |
# |    iterations           | 4         |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0176154 |
# |    clip_fraction        | 0.21      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.19     |
# |    explained_variance   | 0.292     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.024     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.00419  |
# |    std                  | 0.364     |
# |    value_loss           | 0.564     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0611      |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 5           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015765892 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.35        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00473    |
# |    std                  | 0.365       |
# |    value_loss           | 0.55        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.202        |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 6            |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0132192625 |
# |    clip_fraction        | 0.188        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.52         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 0.364        |
# |    value_loss           | 0.534        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.135      |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 7          |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01746976 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.419      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.361      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00283   |
# |    std                  | 0.363      |
# |    value_loss           | 0.51       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.0655     |
# | time/                   |            |
# |    fps                  | 548        |
# |    iterations           | 8          |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01626423 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0616     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00255   |
# |    std                  | 0.362      |
# |    value_loss           | 0.472      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 9           |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017676707 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00315    |
# |    std                  | 0.359       |
# |    value_loss           | 0.468       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.204       |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 10          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017448526 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00344    |
# |    std                  | 0.356       |
# |    value_loss           | 0.413       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.265       |
# | time/                   |             |
# |    fps                  | 511         |
# |    iterations           | 11          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016756292 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0291      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.351       |
# |    value_loss           | 0.456       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 12          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015163917 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.309       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.35        |
# |    value_loss           | 0.474       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.195       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 13          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.015799148 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.351       |
# |    value_loss           | 0.488       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 14          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.017041424 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.29        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -6.85e-05   |
# |    std                  | 0.352       |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.133       |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 15          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.019257328 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0265      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 0.349       |
# |    value_loss           | 0.427       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 16          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.017450364 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0345      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.000807   |
# |    std                  | 0.351       |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 17          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.015767522 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0508      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00165    |
# |    std                  | 0.349       |
# |    value_loss           | 0.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0652      |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 18          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.016888786 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.351       |
# |    value_loss           | 0.422       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 19          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.019138211 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00153    |
# |    std                  | 0.349       |
# |    value_loss           | 0.413       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 20          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.017114205 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.328       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00285    |
# |    std                  | 0.348       |
# |    value_loss           | 0.425       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0681      |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 21          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.017674208 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.436       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 0.346       |
# |    value_loss           | 0.408       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.0646     |
# | time/                   |            |
# |    fps                  | 473        |
# |    iterations           | 22         |
# |    time_elapsed         | 380        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01529713 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0112     |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.00186   |
# |    std                  | 0.343      |
# |    value_loss           | 0.437      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.203       |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 23          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.017647315 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.218       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00365    |
# |    std                  | 0.342       |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.211       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 24          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016505435 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.275       |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.342       |
# |    value_loss           | 0.412       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0635      |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 25          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.020392634 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00298    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00486    |
# |    std                  | 0.338       |
# |    value_loss           | 0.461       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 26          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.020610126 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00336     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.337       |
# |    value_loss           | 0.378       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 27          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.017507687 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0515      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 0.335       |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 28          |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.023537848 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.406       |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.336       |
# |    value_loss           | 0.399       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.129      |
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 29         |
# |    time_elapsed         | 509        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.01999439 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.514      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.044      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.00382   |
# |    std                  | 0.333      |
# |    value_loss           | 0.375      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 30          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020849127 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00195    |
# |    std                  | 0.33        |
# |    value_loss           | 0.359       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 31          |
# |    time_elapsed         | 546         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.019750964 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.288       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.33        |
# |    value_loss           | 0.379       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.196      |
# | time/                   |            |
# |    fps                  | 464        |
# |    iterations           | 32         |
# |    time_elapsed         | 564        |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.01505134 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.39      |
# |    explained_variance   | 0.525      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0539     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.000605  |
# |    std                  | 0.331      |
# |    value_loss           | 0.391      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.134      |
# | time/                   |            |
# |    fps                  | 463        |
# |    iterations           | 33         |
# |    time_elapsed         | 583        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.01822618 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.35      |
# |    explained_variance   | 0.571      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.214      |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.000669  |
# |    std                  | 0.328      |
# |    value_loss           | 0.419      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.256       |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 34          |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.015633088 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.148       |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00159    |
# |    std                  | 0.327       |
# |    value_loss           | 0.412       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.071       |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 35          |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.018328026 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.306       |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.00398    |
# |    std                  | 0.326       |
# |    value_loss           | 0.341       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.266       |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 36          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.018890921 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00237    |
# |    std                  | 0.323       |
# |    value_loss           | 0.425       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.267      |
# | time/                   |            |
# |    fps                  | 459        |
# |    iterations           | 37         |
# |    time_elapsed         | 659        |
# |    total_timesteps      | 303104     |
# | train/                  |            |
# |    approx_kl            | 0.01941482 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0438     |
# |    n_updates            | 730        |
# |    policy_gradient_loss | -0.00229   |
# |    std                  | 0.322      |
# |    value_loss           | 0.403      |
# ----------------------------------------
# ✅ Treino com randomização concluído!

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

env = make_vec_env(UAVCommunicationEnv, n_envs=4)
model = PPO.load("policy_generalized.zip", env=env)

model.learn(total_timesteps=1_000_000)
model.save("policy_generalized2.zip")

print("✅ Treino com randomização concluído!")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.0659   |
# | time/              |          |
# |    fps             | 1123     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.0693     |
# | time/                   |            |
# |    fps                  | 759        |
# |    iterations           | 2          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01915798 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.12      |
# |    explained_variance   | 0.598      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0258     |
# |    n_updates            | 750        |
# |    policy_gradient_loss | -0.00163   |
# |    std                  | 0.319      |
# |    value_loss           | 0.362      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.389       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 3           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017185546 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.658       |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.319       |
# |    value_loss           | 0.384       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.196      |
# | time/                   |            |
# |    fps                  | 666        |
# |    iterations           | 4          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01844792 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | 0.528      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 770        |
# |    policy_gradient_loss | -0.00198   |
# |    std                  | 0.318      |
# |    value_loss           | 0.407      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.259       |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 5           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017672423 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.45        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.319       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 6           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015130812 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.794       |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 0.318       |
# |    value_loss           | 0.432       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.128       |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 7           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.019441487 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.33        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00267    |
# |    std                  | 0.317       |
# |    value_loss           | 0.352       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.263        |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 8            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0148784965 |
# |    clip_fraction        | 0.224        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.196        |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.317        |
# |    value_loss           | 0.393        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0652      |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 9           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.018958572 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.319       |
# |    value_loss           | 0.353       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.126       |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 10          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.019727131 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0882      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00364    |
# |    std                  | 0.323       |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 11          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016866412 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00945    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.325       |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.133       |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 12          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022782974 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0923      |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.325       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 13          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017841391 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00315    |
# |    std                  | 0.325       |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0657      |
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 14          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.019465774 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00418    |
# |    std                  | 0.324       |
# |    value_loss           | 0.365       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 563        |
# |    iterations           | 15         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.01812825 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.598      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.03       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.00327   |
# |    std                  | 0.322      |
# |    value_loss           | 0.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 16          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015883021 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0923      |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 0.323       |
# |    value_loss           | 0.358       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.202       |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 17          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.016937986 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.000674   |
# |    std                  | 0.322       |
# |    value_loss           | 0.352       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.0629     |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 18         |
# |    time_elapsed         | 267        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.01798869 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.566      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0379     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.00258   |
# |    std                  | 0.323      |
# |    value_loss           | 0.41       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 19          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.018814404 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00118    |
# |    std                  | 0.323       |
# |    value_loss           | 0.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0661      |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 20          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.017869014 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.276       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.000498    |
# |    std                  | 0.321       |
# |    value_loss           | 0.321       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 21          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.017074317 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0738      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0023     |
# |    std                  | 0.322       |
# |    value_loss           | 0.324       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.135       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 22          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.016235784 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.146       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.32        |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 23          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.017272998 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.198       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.322       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0626      |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 24          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.017779954 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0456      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.326       |
# |    value_loss           | 0.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0647      |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 25          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.018107802 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0421      |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.00326    |
# |    std                  | 0.326       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.195       |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 26          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.021048835 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.233       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00301    |
# |    std                  | 0.326       |
# |    value_loss           | 0.332       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 27          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.016091539 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.673       |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.000977   |
# |    std                  | 0.324       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.261       |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 28          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.016904984 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0481      |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.323       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0624      |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 29          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.018851046 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.243       |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.00152    |
# |    std                  | 0.323       |
# |    value_loss           | 0.335       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 30          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.017851904 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00417     |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.322       |
# |    value_loss           | 0.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 31          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.017338987 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0547      |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.323       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.129       |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 32          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.017230887 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.0023     |
# |    std                  | 0.321       |
# |    value_loss           | 0.349       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.262       |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 33          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.017349068 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0403      |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 0.321       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 34          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.021167848 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.148       |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00448    |
# |    std                  | 0.322       |
# |    value_loss           | 0.363       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.133      |
# | time/                   |            |
# |    fps                  | 518        |
# |    iterations           | 35         |
# |    time_elapsed         | 553        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.01718153 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.12      |
# |    explained_variance   | 0.576      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.227      |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | -0.0034    |
# |    std                  | 0.32       |
# |    value_loss           | 0.347      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.136      |
# | time/                   |            |
# |    fps                  | 517        |
# |    iterations           | 36         |
# |    time_elapsed         | 570        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.01551377 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.651      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0632     |
# |    n_updates            | 1090       |
# |    policy_gradient_loss | -0.00232   |
# |    std                  | 0.321      |
# |    value_loss           | 0.264      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.403       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 37          |
# |    time_elapsed         | 586         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.015975105 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0858      |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.319       |
# |    value_loss           | 0.331       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.135       |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 38          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.015452509 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.514       |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00244    |
# |    std                  | 0.318       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.195       |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 39          |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.017548501 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 0.319       |
# |    value_loss           | 0.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.137       |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 40          |
# |    time_elapsed         | 636         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.017171685 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.198       |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00313    |
# |    std                  | 0.32        |
# |    value_loss           | 0.322       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.129       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 41          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.019007541 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0425      |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 0.319       |
# |    value_loss           | 0.322       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.134      |
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 42         |
# |    time_elapsed         | 670        |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.01709373 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.07      |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0117     |
# |    n_updates            | 1150       |
# |    policy_gradient_loss | -0.0039    |
# |    std                  | 0.318      |
# |    value_loss           | 0.37       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.269       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 43          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.015273307 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.54        |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.317       |
# |    value_loss           | 0.364       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.0652     |
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 44         |
# |    time_elapsed         | 703        |
# |    total_timesteps      | 360448     |
# | train/                  |            |
# |    approx_kl            | 0.02000675 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | 0.579      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.139      |
# |    n_updates            | 1170       |
# |    policy_gradient_loss | -0.00369   |
# |    std                  | 0.315      |
# |    value_loss           | 0.319      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.268      |
# | time/                   |            |
# |    fps                  | 511        |
# |    iterations           | 45         |
# |    time_elapsed         | 720        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.01585425 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.244      |
# |    n_updates            | 1180       |
# |    policy_gradient_loss | -0.00278   |
# |    std                  | 0.316      |
# |    value_loss           | 0.337      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0666      |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 46          |
# |    time_elapsed         | 737         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.015621172 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0028     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.000679   |
# |    std                  | 0.315       |
# |    value_loss           | 0.349       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.201      |
# | time/                   |            |
# |    fps                  | 508        |
# |    iterations           | 47         |
# |    time_elapsed         | 757        |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.01896353 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.169      |
# |    n_updates            | 1200       |
# |    policy_gradient_loss | -0.00218   |
# |    std                  | 0.313      |
# |    value_loss           | 0.367      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.27        |
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 48          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.015873766 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.00452    |
# |    std                  | 0.314       |
# |    value_loss           | 0.334       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0708      |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 49          |
# |    time_elapsed         | 793         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.020795539 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00371    |
# |    std                  | 0.313       |
# |    value_loss           | 0.299       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.138       |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 50          |
# |    time_elapsed         | 809         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.015681198 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | -0.00443    |
# |    std                  | 0.312       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.197       |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 51          |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.018229486 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.307       |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00309    |
# |    std                  | 0.312       |
# |    value_loss           | 0.331       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 52          |
# |    time_elapsed         | 848         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.021859823 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.176       |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.00365    |
# |    std                  | 0.31        |
# |    value_loss           | 0.351       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | 0.0648   |
# | time/                   |          |
# |    fps                  | 501      |
# |    iterations           | 53       |
# |    time_elapsed         | 865      |
# |    total_timesteps      | 434176   |
# | train/                  |          |
# |    approx_kl            | 0.017334 |
# |    clip_fraction        | 0.216    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.87    |
# |    explained_variance   | 0.604    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.236    |
# |    n_updates            | 1260     |
# ...
# |    loss                 | 0.076       |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00244    |
# |    std                  | 0.298       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0668      |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 107         |
# |    time_elapsed         | 1797        |
# |    total_timesteps      | 876544      |
# | train/                  |             |
# |    approx_kl            | 0.017288646 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0366      |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00285    |
# |    std                  | 0.299       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.197       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 108         |
# |    time_elapsed         | 1814        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.019882444 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0633      |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00219    |
# |    std                  | 0.298       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 109         |
# |    time_elapsed         | 1830        |
# |    total_timesteps      | 892928      |
# | train/                  |             |
# |    approx_kl            | 0.016912553 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.000964   |
# |    std                  | 0.298       |
# |    value_loss           | 0.264       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.131       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 110         |
# |    time_elapsed         | 1847        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.018569613 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00348    |
# |    std                  | 0.296       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.132      |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 111        |
# |    time_elapsed         | 1864       |
# |    total_timesteps      | 909312     |
# | train/                  |            |
# |    approx_kl            | 0.01881555 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.672      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.249      |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | -0.00474   |
# |    std                  | 0.295      |
# |    value_loss           | 0.289      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 112         |
# |    time_elapsed         | 1881        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.021384107 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00474    |
# |    std                  | 0.292       |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.258       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 113         |
# |    time_elapsed         | 1902        |
# |    total_timesteps      | 925696      |
# | train/                  |             |
# |    approx_kl            | 0.018169846 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00666    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00315    |
# |    std                  | 0.293       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.128       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 114         |
# |    time_elapsed         | 1920        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.018651512 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.291       |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 115         |
# |    time_elapsed         | 1937        |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.018795192 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0478      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00299    |
# |    std                  | 0.292       |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 116         |
# |    time_elapsed         | 1954        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.017913464 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0551      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.293       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.129       |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 117         |
# |    time_elapsed         | 1973        |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.019720439 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00306    |
# |    std                  | 0.296       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.132       |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 118         |
# |    time_elapsed         | 1991        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.020661753 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.299       |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.00435    |
# |    std                  | 0.294       |
# |    value_loss           | 0.224       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.134       |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 119         |
# |    time_elapsed         | 2008        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.016523497 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00311    |
# |    std                  | 0.293       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0601      |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 120         |
# |    time_elapsed         | 2024        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.017455772 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.293       |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0682      |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 121         |
# |    time_elapsed         | 2043        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.018310606 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.292       |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 122         |
# |    time_elapsed         | 2060        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.017729048 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.216       |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 0.293       |
# |    value_loss           | 0.284       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 123         |
# |    time_elapsed         | 2078        |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.018502217 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.657       |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 0.293       |
# |    value_loss           | 0.323       |
# -----------------------------------------
# ✅ Treino com randomização concluído!

# %%
from stable_baselines3 import PPO
import numpy as np

model = PPO.load("policy_generalized2.zip")
env = UAVCommunicationEnv()

for i in range(5):
    obs, _ = env.reset()
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    print(f"Teste {i+1}")
    print(f"Reward: {reward:.3f}")
    print("Jammer:", env.jammer_position_real)
    print("UAVs iniciais:", np.round(info['initial_positions_real'], 2))
    print("UAVs finais:", np.round(info['final_positions_real'], 2))
    print("-" * 70)
# Out:
# Teste 1
# Reward: 0.000
# Jammer: [ 98.8603959 500.       ]
# UAVs iniciais: [[55.51 43.43]
#  [21.96 22.47]
#  [39.02 48.64]
#  [53.8  58.99]]
# UAVs finais: [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
# ----------------------------------------------------------------------
# Teste 2
# Reward: 0.000
# Jammer: [ 97.46724611 500.        ]
# UAVs iniciais: [[54.73  7.04]
#  [ 5.38 18.45]
#  [32.9  41.99]
#  [15.58 48.72]]
# UAVs finais: [[ 60.     0.  ]
#  [ 60.    56.25]
#  [120.     0.  ]
#  [120.    60.  ]]
# ----------------------------------------------------------------------
# Teste 3
# Reward: 0.000
# Jammer: [ 91.07112456 500.        ]
# UAVs iniciais: [[19.58 59.49]
#  [29.79 25.77]
#  [39.06 57.47]
#  [12.63  7.29]]
# UAVs finais: [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
# ----------------------------------------------------------------------
# Teste 4
# Reward: 0.000
# Jammer: [100.09393695 500.        ]
# UAVs iniciais: [[54.65 48.52]
#  [37.52 53.86]
#  [50.19  4.89]
#  [45.94 51.18]]
# UAVs finais: [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
# ----------------------------------------------------------------------
# Teste 5
# Reward: 0.000
# Jammer: [ 71.55739647 500.        ]
# UAVs iniciais: [[38.13 24.66]
#  [ 4.04 35.78]
#  [30.41 31.9 ]
#  [ 9.93 49.27]]
# UAVs finais: [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
# ----------------------------------------------------------------------

# %%
from stable_baselines3 import PPO
import numpy as np

# Carregar o modelo PPO previamente treinado
model = PPO.load("policy_generalized.zip")
env = UAVCommunicationEnv()

# Define as tuas posições iniciais (exemplo — todas a >20m entre si)
custom_positions = np.array([
    [20, 40],
    [40, 20],
    [20, 20],
    [40, 40]
])

# Define a posição do jammer (opcional)
custom_jammer = np.array([70.0, 500.0])

# Reset do ambiente (gera estado base)
obs, _ = env.reset()

# Sobrescreve as posições iniciais e jammer
env.uav_positions_real = custom_positions
env.jammer_position_real = custom_jammer

# Recalcular observação normalizada (com collision_level incluído)
uav_positions_norm = []
for pos in env.uav_positions_real:
    uav_positions_norm.extend(env._normalize_uav_position(pos, 'initial'))

jammer_norm = env._normalize_jammer_position(env.jammer_position_real)
collision_level = env._calculate_collision_score(env.uav_positions_real)

# 👇 Agora a observação tem 11 elementos
obs = np.concatenate([uav_positions_norm, jammer_norm, [collision_level]]).astype(np.float32)

# Testa a política treinada (modo determinístico)
action, _ = model.predict(obs, deterministic=True)

# Passa a ação ao ambiente
obs, reward, terminated, truncated, info = env.step(action)

# Mostra resultados
print("\n--- RESULTADOS DO TESTE ---")
print(f"Reward obtido: {reward:.3f}")
print("Nível de colisão final:", round(obs[-1], 3))
print("\nJammer:", env.jammer_position_real)
print("\nUAVs iniciais:\n", np.round(info['initial_positions_real'], 2))
print("\nUAVs finais:\n", np.round(info['final_positions_real'], 2))

# (Opcional) Verificar distâncias mínimas entre UAVs
dist_min = np.inf
for i in range(env.num_uavs):
    for j in range(i + 1, env.num_uavs):
        d = np.linalg.norm(info['final_positions_real'][i] - info['final_positions_real'][j])
        dist_min = min(dist_min, d)
print(f"\nDistância mínima entre UAVs finais: {dist_min:.2f} m")
# Out:
# --- RESULTADOS DO TESTE ---
# Reward obtido: 0.000
# Nível de colisão final: 1.0
#
# Jammer: [ 70. 500.]
#
# UAVs iniciais:
#  [[20 40]
#  [40 20]
#  [20 20]
#  [40 40]]
#
# UAVs finais:
#  [[ 60.   0.]
#  [ 60.  60.]
#  [120.   0.]
#  [120.  60.]]
#
# Distância mínima entre UAVs finais: 60.00 m

# %%
from stable_baselines3 import PPO
import numpy as np

# Carrega o modelo treinado
model = PPO.load("policy_generalized.zip")
env = UAVCommunicationEnv()

n_tests = 10
results = []

for i in range(n_tests):
    obs, _ = env.reset()  # novas posições e jammer
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    
    results.append(reward)
    print(f"Teste {i+1}/{n_tests}: Reward = {reward:.3f}")

print("\n✅ Média dos rewards:", np.mean(results))
print("📉 Desvio padrão:", np.std(results))
# Out:
# Teste 1/10: Reward = 0.000
# Teste 2/10: Reward = 0.000
# Teste 3/10: Reward = 0.000
# Teste 4/10: Reward = 0.000
# Teste 5/10: Reward = 0.000
# Teste 6/10: Reward = 0.000
# Teste 7/10: Reward = 0.000
# Teste 8/10: Reward = 0.000
# Teste 9/10: Reward = 0.000
# Teste 10/10: Reward = 0.000
#
# ✅ Média dos rewards: 0.0
# 📉 Desvio padrão: 0.0

# %% [markdown]
# # analisar

# %%
import pandas as pd
import numpy as np
from stable_baselines3 import PPO

# === 1. Carregar modelo e ambiente ===
model_path = "policy_generalized.zip"  # ajusta conforme o modelo treinado neste ambiente
model = PPO.load(model_path)
env = UAVCommunicationEnv()

# === 2. Carregar dataset original ===
csv_path = "dataset_combined_com_permutacoes.csv"  # <-- ajusta o nome conforme o teu
df = pd.read_csv(csv_path)

# === 3. Preparar lista para armazenar as novas linhas ===
new_rows = []

# === 4. Loop por cada linha do CSV ===
for _, row in df.iterrows():
    # ----- Extrair jammer -----
    jammer_real = np.array([row["Jammer_X"], row["Jammer_Y"]])

    # ----- Extrair posições iniciais -----
    uav_positions_real = []
    for i in range(1, 5):
        uav_positions_real.append(np.array([row[f"Initial_X{i}"], row[f"Initial_Y{i}"]]))
    uav_positions_real = np.array(uav_positions_real)

    # ----- Normalizar observação -----
    uav_positions_norm = []
    for pos in uav_positions_real:
        uav_positions_norm.extend(env._normalize_uav_position(pos, "initial"))
    jammer_norm = env._normalize_jammer_position(jammer_real)

    # ✅ Cria vetor de observação (com collision_level=1 pois dataset não tem colisões)
    obs = np.concatenate([uav_positions_norm, jammer_norm, [1.0]]).astype(np.float32)

    # ----- Predição da política -----
    action, _ = model.predict(obs, deterministic=True)

    # ----- Desnormalizar ação para coordenadas reais -----
    action_reshaped = action.reshape(4, 2)
    predicted_final_positions = [
        env._denormalize_uav_position(a, "target") for a in action_reshaped
    ]
    predicted_final_positions = np.array(predicted_final_positions)

    # ----- Extrair posições finais reais -----
    real_final_positions = []
    for i in range(1, 5):
        real_final_positions.append(np.array([row[f"Final_X{i}"], row[f"Final_Y{i}"]]))
    real_final_positions = np.array(real_final_positions)

    # ----- Montar nova linha -----
    new_row = {
        "Jammer_X": row["Jammer_X"],
        "Jammer_Y": row["Jammer_Y"],
    }

    # Initials
    for i in range(4):
        new_row[f"Initial_X{i+1}"] = uav_positions_real[i][0]
        new_row[f"Initial_Y{i+1}"] = uav_positions_real[i][1]

    # Predicted Finals
    for i in range(4):
        new_row[f"Predicted_Final_X{i+1}"] = predicted_final_positions[i][0]
        new_row[f"Predicted_Final_Y{i+1}"] = predicted_final_positions[i][1]

    # Real Finals
    for i in range(4):
        new_row[f"Real_Final_X{i+1}"] = real_final_positions[i][0]
        new_row[f"Real_Final_Y{i+1}"] = real_final_positions[i][1]

    new_rows.append(new_row)

# === 5. Criar DataFrame final ===
new_df = pd.DataFrame(new_rows)

# === 6. Guardar novo CSV ===
output_path = "uav_predictions_collision_aware.csv"
new_df.to_csv(output_path, index=False)
print(f"✅ Novo CSV gerado com sucesso: {output_path}")
print(f"Total de linhas: {len(new_df)}")
# Out:
# ✅ Novo CSV gerado com sucesso: uav_predictions_collision_aware.csv
# Total de linhas: 2400

# %%
import numpy as np
import networkx as nx
import pandas as pd

def has_collision_final_positions(final_positions, min_distance=20):
    """
    Verifica se há colisões apenas nas posições finais
    """
    num_uavs = len(final_positions)
    
    for i in range(num_uavs):
        for j in range(i + 1, num_uavs):
            x1, y1 = final_positions[i]
            x2, y2 = final_positions[j]
            
            distance = np.sqrt((x1 - x2)**2 + (y1 - y2)**2)
            
            if distance < min_distance:
                return True  # Há colisão
    
    return False  # Sem colisões

def analisar_comunicacoes_interpolado_sem_verificacao_colisoes(initial_positions, final_positions, num_uavs, num_timeslots, jammer_position):
    """
    Analisa comunicações interpolando entre posições inicial e final
    SEM VERIFICAR COLISÕES (para Análise 1)
    """
    
    def criar_best_solution_interpolado(initial_pos, final_pos, num_uavs, num_timeslots):
        """
        Cria best_solution interpolando linearmente entre posições inicial e final
        """
        best_solution = []
        
        for t in range(num_timeslots):
            # Calcular fator de interpolação (0 no início, 1 no final)
            if num_timeslots == 1:
                alpha = 1.0  # Se só há 1 timeslot, usar posição final
            else:
                alpha = t / (num_timeslots - 1)
            
            # Para cada UAV
            for uav in range(num_uavs):
                start_x, start_y = initial_pos[uav]
                end_x, end_y = final_pos[uav]
                
                # Interpolação linear
                x = start_x + alpha * (end_x - start_x)
                y = start_y + alpha * (end_y - start_y)
                
                # Adicionar ao best_solution
                best_solution.extend([x, y])
        
        return best_solution
    
    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # CRIAR BEST_SOLUTION ATRAVÉS DE INTERPOLAÇÃO
    best_solution = criar_best_solution_interpolado(initial_positions, final_positions, num_uavs, num_timeslots)
    
    # SEM VERIFICAÇÃO DE COLISÕES - continuar sempre com a análise
    resultados = []
    todos_c_media = []
    todos_c_min = []
    
    # Analisar cada timeslot
    for t in range(num_timeslots):
        positions = []
        angles = []
        
        for i in range(num_uavs):
            idx_pos = t * num_uavs * 2 + i * 2
            x, y = best_solution[idx_pos:idx_pos+2]
            positions.append(np.array([x, y]))
            
            # Calcular ângulo dinamicamente
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            angles.append(angle)
        
        # Calcular matriz de comunicação
        comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
        
        # Gerar métricas detalhadas
        metricas = avaliar_grafo(comm_matrix)
        
        # Cálculo do fitness usando apenas links usados
        capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Adicionar às listas do epoch
        todos_c_media.append(C_media_total)
        todos_c_min.append(C_min_total)
        
        resultados.append({
            'epoch': 1,
            'timeslot': t+1,
            'metricas': metricas,
            'C_media_total': C_media_total,
            'C_min_total': C_min_total
        })
    
    # Calcular fitness final
    alpha, beta = 1.0, 1.0
    fitness_por_timeslot = []
    
    for i in range(len(todos_c_media)):
        C_media = todos_c_media[i]
        C_min = todos_c_min[i]
        fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
        fitness_por_timeslot.append(fitness_timeslot)
    
    # Fitness médio do epoch
    fitness_epoch = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
    
    # Calcular também as médias para informação
    media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
    media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
    
    return resultados, fitness_epoch, media_c_media_epoch, media_c_min_epoch

def analisar_comunicacoes_interpolado_final(initial_positions, final_positions, num_uavs, num_timeslots, jammer_position):
    """
    Analisa comunicações interpolando entre posições inicial e final
    VERIFICA COLISÕES APENAS NAS POSIÇÕES FINAIS
    """
    
    def criar_best_solution_interpolado(initial_pos, final_pos, num_uavs, num_timeslots):
        """
        Cria best_solution interpolando linearmente entre posições inicial e final
        """
        best_solution = []
        
        for t in range(num_timeslots):
            # Calcular fator de interpolação (0 no início, 1 no final)
            if num_timeslots == 1:
                alpha = 1.0  # Se só há 1 timeslot, usar posição final
            else:
                alpha = t / (num_timeslots - 1)
            
            # Para cada UAV
            for uav in range(num_uavs):
                start_x, start_y = initial_pos[uav]
                end_x, end_y = final_pos[uav]
                
                # Interpolação linear
                x = start_x + alpha * (end_x - start_x)
                y = start_y + alpha * (end_y - start_y)
                
                # Adicionar ao best_solution
                best_solution.extend([x, y])
        
        return best_solution
    
    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # CRIAR BEST_SOLUTION ATRAVÉS DE INTERPOLAÇÃO
    best_solution = criar_best_solution_interpolado(initial_positions, final_positions, num_uavs, num_timeslots)
    
    # 🆕 VERIFICAR COLISÕES APENAS NAS POSIÇÕES FINAIS (não ao longo do caminho)
    tem_colisoes = has_collision_final_positions(final_positions)
    
    if tem_colisoes:
        return [(0.0, "Solução com colisões nas posições finais")], 0.0, 0.0, 0.0
    
    # Se não há colisões nas posições finais, continuar com a análise normal
    resultados = []
    todos_c_media = []
    todos_c_min = []
    
    # Analisar cada timeslot
    for t in range(num_timeslots):
        positions = []
        angles = []
        
        for i in range(num_uavs):
            idx_pos = t * num_uavs * 2 + i * 2
            x, y = best_solution[idx_pos:idx_pos+2]
            positions.append(np.array([x, y]))
            
            # Calcular ângulo dinamicamente
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            angles.append(angle)
        
        # Calcular matriz de comunicação
        comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
        
        # Gerar métricas detalhadas
        metricas = avaliar_grafo(comm_matrix)
        
        # Cálculo do fitness usando apenas links usados
        capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Adicionar às listas do epoch
        todos_c_media.append(C_media_total)
        todos_c_min.append(C_min_total)
        
        resultados.append({
            'epoch': 1,
            'timeslot': t+1,
            'metricas': metricas,
            'C_media_total': C_media_total,
            'C_min_total': C_min_total
        })
    
    # Calcular fitness final
    alpha, beta = 1.0, 1.0
    fitness_por_timeslot = []
    
    for i in range(len(todos_c_media)):
        C_media = todos_c_media[i]
        C_min = todos_c_min[i]
        fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
        fitness_por_timeslot.append(fitness_timeslot)
    
    # Fitness médio do epoch
    fitness_epoch = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
    
        # Calcular também as médias para informação
    media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
    media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
    
    return resultados, fitness_epoch, media_c_media_epoch, media_c_min_epoch

# %%
def carregar_e_analisar_dataset_final(caminho_dataset, num_uavs=4, num_timeslots=6):
    """
    Carrega o dataset e analisa comunicações para valores reais e preditos
    TRÊS ANÁLISES com verificação de colisões apenas nas posições finais:
    1. Todas as linhas (valores reais)
    2. Apenas sem colisões
    3. Todas as linhas com colisões = 0
    """
    
    # CARREGAR O DATASET
    df = pd.read_csv(caminho_dataset)
    
    # ANÁLISE 1: Todas as linhas (valores reais)
    fitness_reais = []
    fitness_preditos = []
    c_media_reais = []
    c_media_preditos = []
    c_min_reais = []
    c_min_preditos = []
    
    # ANÁLISE 2: Apenas sem colisões
    fitness_reais_sem_colisoes = []
    fitness_preditos_sem_colisoes = []
    c_media_reais_sem_colisoes = []
    c_media_preditos_sem_colisoes = []
    c_min_reais_sem_colisoes = []
    c_min_preditos_sem_colisoes = []
    
    # ANÁLISE 3: Todas as linhas, mas colisões = 0
    fitness_reais_colisoes_zero = []
    fitness_preditos_colisoes_zero = []
    c_media_reais_colisoes_zero = []
    c_media_preditos_colisoes_zero = []
    c_min_reais_colisoes_zero = []
    c_min_preditos_colisoes_zero = []
    
    linhas_sem_colisoes = []
    total_linhas_sem_colisoes = 0
    
    # ANALISAR CADA LINHA DO DATASET
    for index, row in df.iterrows():
        # Extrair posições
        initial_positions = [
            (row['Initial_X1'], row['Initial_Y1']),
            (row['Initial_X2'], row['Initial_Y2']),
            (row['Initial_X3'], row['Initial_Y3']),
            (row['Initial_X4'], row['Initial_Y4'])
        ]
        
        final_positions_preditas = [
            (row['Predicted_Final_X1'], row['Predicted_Final_Y1']),
            (row['Predicted_Final_X2'], row['Predicted_Final_Y2']),
            (row['Predicted_Final_X3'], row['Predicted_Final_Y3']),
            (row['Predicted_Final_X4'], row['Predicted_Final_Y4'])
        ]
        
        final_positions_reais = [
            (row['Real_Final_X1'], row['Real_Final_Y1']),
            (row['Real_Final_X2'], row['Real_Final_Y2']),
            (row['Real_Final_X3'], row['Real_Final_Y3']),
            (row['Real_Final_X4'], row['Real_Final_Y4'])
        ]
        
        jammer_position = [row['Jammer_X'], row['Jammer_Y']]
        
        # VERIFICAR COLISÕES APENAS NAS POSIÇÕES FINAIS
        tem_colisoes_predito = has_collision_final_positions(final_positions_preditas)
        tem_colisoes_real = has_collision_final_positions(final_positions_reais)
        
        # CALCULAR VALORES REAIS DE COMUNICAÇÃO (mesmo com colisões) - USANDO FUNÇÃO SEM VERIFICAÇÃO
        resultados_pred, fitness_pred, c_media_pred, c_min_pred = analisar_comunicacoes_interpolado_sem_verificacao_colisoes(
            initial_positions=initial_positions,
            final_positions=final_positions_preditas,
            num_uavs=num_uavs,
            num_timeslots=num_timeslots,
            jammer_position=jammer_position
        )
        
        resultados_real, fitness_real, c_media_real, c_min_real = analisar_comunicacoes_interpolado_sem_verificacao_colisoes(
            initial_positions=initial_positions,
            final_positions=final_positions_reais,
            num_uavs=num_uavs,
            num_timeslots=num_timeslots,
            jammer_position=jammer_position
        )
        
        # ANÁLISE 1: Armazenar valores reais (independente de colisões)
        fitness_preditos.append(fitness_pred)
        fitness_reais.append(fitness_real)
        c_media_preditos.append(c_media_pred)
        c_media_reais.append(c_media_real)
        c_min_preditos.append(c_min_pred)
        c_min_reais.append(c_min_real)
        
        # ANÁLISE 2: Se não há colisões, adicionar às listas especiais
        if not tem_colisoes_predito:
            fitness_preditos_sem_colisoes.append(fitness_pred)
            fitness_reais_sem_colisoes.append(fitness_real)
            c_media_preditos_sem_colisoes.append(c_media_pred)
            c_media_reais_sem_colisoes.append(c_media_real)
            c_min_preditos_sem_colisoes.append(c_min_pred)
            c_min_reais_sem_colisoes.append(c_min_real)
            
            linhas_sem_colisoes.append(index + 1)
            total_linhas_sem_colisoes += 1
        
        # ANÁLISE 3: Colisões = 0
        # Para preditos
        if tem_colisoes_predito:
            fitness_preditos_colisoes_zero.append(0.0)
            c_media_preditos_colisoes_zero.append(0.0)
            c_min_preditos_colisoes_zero.append(0.0)
        else:
            fitness_preditos_colisoes_zero.append(fitness_pred)
            c_media_preditos_colisoes_zero.append(c_media_pred)
            c_min_preditos_colisoes_zero.append(c_min_pred)
        
        # Para reais
        if tem_colisoes_real:
            fitness_reais_colisoes_zero.append(0.0)
            c_media_reais_colisoes_zero.append(0.0)
            c_min_reais_colisoes_zero.append(0.0)
        else:
            fitness_reais_colisoes_zero.append(fitness_real)
            c_media_reais_colisoes_zero.append(c_media_real)
            c_min_reais_colisoes_zero.append(c_min_real)
    
    # CALCULAR MÉDIAS
    media_fitness_real_1 = np.mean(fitness_reais)
    media_fitness_predito_1 = np.mean(fitness_preditos)
    media_c_media_real_1 = np.mean(c_media_reais)
    media_c_media_predito_1 = np.mean(c_media_preditos)
    media_c_min_real_1 = np.mean(c_min_reais)
    media_c_min_predito_1 = np.mean(c_min_preditos)
    
    media_fitness_real_3 = np.mean(fitness_reais_colisoes_zero)
    media_fitness_predito_3 = np.mean(fitness_preditos_colisoes_zero)
    media_c_media_real_3 = np.mean(c_media_reais_colisoes_zero)
    media_c_media_predito_3 = np.mean(c_media_preditos_colisoes_zero)
    media_c_min_real_3 = np.mean(c_min_reais_colisoes_zero)
    media_c_min_predito_3 = np.mean(c_min_preditos_colisoes_zero)
    
    # ANÁLISE 1: RESULTADOS PARA TODAS AS LINHAS
    print(f"============================================================")
    print(f"ANÁLISE 1 - TODAS AS LINHAS (valores reais de comunicação)")
    print(f"============================================================")
    print(f"🎯 FITNESS: Real={media_fitness_real_1:.4f} | Predito={media_fitness_predito_1:.4f} | Diff={abs(media_fitness_real_1 - media_fitness_predito_1):.4f}")
    print(f"📊 C_MÉDIA: Real={media_c_media_real_1:.2f} | Predito={media_c_media_predito_1:.2f} | Diff={abs(media_c_media_real_1 - media_c_media_predito_1):.2f}")
    print(f"📉 C_MIN: Real={media_c_min_real_1:.2f} | Predito={media_c_min_predito_1:.2f} | Diff={abs(media_c_min_real_1 - media_c_min_predito_1):.2f}")
    
    # ANÁLISE 2: APENAS SEM COLISÕES
    if total_linhas_sem_colisoes > 0:
        media_fitness_real_2 = np.mean(fitness_reais_sem_colisoes)
        media_fitness_predito_2 = np.mean(fitness_preditos_sem_colisoes)
        media_c_media_real_2 = np.mean(c_media_reais_sem_colisoes)
        media_c_media_predito_2 = np.mean(c_media_preditos_sem_colisoes)
        media_c_min_real_2 = np.mean(c_min_reais_sem_colisoes)
        media_c_min_predito_2 = np.mean(c_min_preditos_sem_colisoes)
        
        print(f"\n======================================================================")
        print(f"ANÁLISE 2 - APENAS LINHAS SEM COLISÕES ({total_linhas_sem_colisoes}/{len(df)} linhas)")
        print(f"======================================================================")
        print(f"🎯 FITNESS: Real={media_fitness_real_2:.4f} | Predito={media_fitness_predito_2:.4f} | Diff={abs(media_fitness_real_2 - media_fitness_predito_2):.4f}")
        print(f"📊 C_MÉDIA: Real={media_c_media_real_2:.2f} | Predito={media_c_media_predito_2:.2f} | Diff={abs(media_c_media_real_2 - media_c_media_predito_2):.2f}")
        print(f"📉 C_MIN: Real={media_c_min_real_2:.2f} | Predito={media_c_min_predito_2:.2f} | Diff={abs(media_c_min_real_2 - media_c_min_predito_2):.2f}")
    
    # ANÁLISE 3: COLISÕES = 0
    print(f"\n======================================================================")
    print(f"ANÁLISE 3 - TODAS AS LINHAS (colisões = 0)")
    print(f"======================================================================")
    print(f"🎯 FITNESS: Real={media_fitness_real_3:.4f} | Predito={media_fitness_predito_3:.4f} | Diff={abs(media_fitness_real_3 - media_fitness_predito_3):.4f}")
    print(f"📊 C_MÉDIA: Real={media_c_media_real_3:.2f} | Predito={media_c_media_predito_3:.2f} | Diff={abs(media_c_media_real_3 - media_c_media_predito_3):.2f}")
    print(f"📉 C_MIN: Real={media_c_min_real_3:.2f} | Predito={media_c_min_predito_3:.2f} | Diff={abs(media_c_min_real_3 - media_c_min_predito_3):.2f}")

# USO
if __name__ == "__main__":
    caminho_do_dataset = "uav_predictions_collision_aware.csv"
    carregar_e_analisar_dataset_final(caminho_dataset=caminho_do_dataset, num_uavs=4, num_timeslots=6)
# Out:
# ============================================================
# ANÁLISE 1 - TODAS AS LINHAS (valores reais de comunicação)
# ============================================================
# 🎯 FITNESS: Real=18637252.4897 | Predito=7049194.5629 | Diff=11588057.9268
# 📊 C_MÉDIA: Real=6214.50 | Predito=4886.77 | Diff=1327.74
# 📉 C_MIN: Real=2739.45 | Predito=1207.30 | Diff=1532.15
#
# ======================================================================
# ANÁLISE 2 - APENAS LINHAS SEM COLISÕES (2400/2400 linhas)
# ======================================================================
# 🎯 FITNESS: Real=18637252.4897 | Predito=7049194.5629 | Diff=11588057.9268
# 📊 C_MÉDIA: Real=6214.50 | Predito=4886.77 | Diff=1327.74
# 📉 C_MIN: Real=2739.45 | Predito=1207.30 | Diff=1532.15
#
# ======================================================================
# ANÁLISE 3 - TODAS AS LINHAS (colisões = 0)
# ======================================================================
# 🎯 FITNESS: Real=17647643.4736 | Predito=7049194.5629 | Diff=10598448.9107
# 📊 C_MÉDIA: Real=5895.72 | Predito=4886.77 | Diff=1008.96
# 📉 C_MIN: Real=2636.21 | Predito=1207.30 | Diff=1428.91

# %%
import pandas as pd
import numpy as np
import os
import glob

def calculate_mean_euclidean_distance_single(dataset_file):
    """
    Calcula a Mean Euclidean Distance para um único ficheiro
    
    Args:
        dataset_file: Caminho do ficheiro CSV
    
    Returns:
        dict: Estatísticas da distância euclidiana
    """
    
    try:
        # Carregar dataset
        df = pd.read_csv(dataset_file)
        
        # Lista para armazenar todas as distâncias
        all_distances = []
        
        # Calcular distância euclidiana para cada linha e cada UAV
        for index, row in df.iterrows():
            for uav in range(1, 5):  # UAVs 1, 2, 3, 4
                # Posições preditas
                pred_x = row[f'Predicted_Final_X{uav}']
                pred_y = row[f'Predicted_Final_Y{uav}']
                
                # Posições reais
                real_x = row[f'Real_Final_X{uav}']
                real_y = row[f'Real_Final_Y{uav}']
                
                # Calcular distância euclidiana
                distance = np.sqrt((pred_x - real_x)**2 + (pred_y - real_y)**2)
                all_distances.append(distance)
        
        # Calcular estatísticas
        results = {
            'filename': os.path.basename(dataset_file),
            'total_predictions': len(all_distances),
            'total_lines': len(df),
            'mean_distance': np.mean(all_distances),
            'std_distance': np.std(all_distances),
            'min_distance': np.min(all_distances),
            'max_distance': np.max(all_distances),
            'median_distance': np.median(all_distances)
        }
        
        return results
        
    except Exception as e:
        print(f"❌ Erro ao processar {dataset_file}: {e}")
        return None

def analyze_multiple_files(file_list=None, directory=None, pattern="*.csv"):
    """
    Analisa múltiplos ficheiros e calcula Mean Euclidean Distance
    
    Args:
        file_list: Lista de caminhos de ficheiros (opcional)
        directory: Diretório para procurar ficheiros (opcional)
        pattern: Padrão de ficheiros a procurar (default: "*.csv")
    """
    
    # Determinar lista de ficheiros
    if file_list:
        files = file_list
    elif directory:
        files = glob.glob(os.path.join(directory, pattern))
    else:
        print("❌ Deve fornecer file_list ou directory")
        return
    
    if not files:
        print("❌ Nenhum ficheiro encontrado")
        return
    
    print(f"🔍 Encontrados {len(files)} ficheiros para analisar")
    print("="*80)
    
    # Analisar cada ficheiro
    results = []
    
    for file_path in files:
        print(f"📊 Analisando: {os.path.basename(file_path)}")
        result = calculate_mean_euclidean_distance_single(file_path)
        
        if result:
            results.append(result)
            print(f"   ✅ Mean Euclidean Distance: {result['mean_distance']:.4f}")
        else:
            print(f"   ❌ Falhou")
        print()
    
    # Mostrar resumo comparativo
    if results:
        print("="*80)
        print("📈 RESUMO COMPARATIVO - MEAN EUCLIDEAN DISTANCE")
        print("="*80)
        
        # Cabeçalho
        print(f"{'Ficheiro':<40} {'Mean Dist':<12} {'Std':<10} {'Min':<10} {'Max':<10} {'Linhas':<8}")
        print("-" * 90)
        
        # Resultados
        for result in results:
            filename = result['filename'][:37] + "..." if len(result['filename']) > 40 else result['filename']
            print(f"{filename:<40} {result['mean_distance']:<12.4f} {result['std_distance']:<10.4f} "
                  f"{result['min_distance']:<10.4f} {result['max_distance']:<10.4f} {result['total_lines']:<8}")
        
        # Encontrar melhor e pior
        best = min(results, key=lambda x: x['mean_distance'])
        worst = max(results, key=lambda x: x['mean_distance'])
        
        print("\n" + "="*50)
        print("🏆 RANKING:")
        print(f"   🥇 MELHOR: {best['filename']} (Mean: {best['mean_distance']:.4f})")
        print(f"   🥉 PIOR:   {worst['filename']} (Mean: {worst['mean_distance']:.4f})")
        print(f"   📊 DIFERENÇA: {worst['mean_distance'] - best['mean_distance']:.4f}")
        
        return results
    
    else:
        print("❌ Nenhum ficheiro foi processado com sucesso")
        return None

# Função de conveniência para usar facilmente
def quick_analysis(files):
    """
    Análise rápida de uma lista de ficheiros
    
    Args:
        files: Lista de caminhos de ficheiros
    """
    return analyze_multiple_files(file_list=files)

# Executar
if __name__ == "__main__":
    
    # OPÇÃO 1: Lista específica de ficheiros
    files_to_analyze = [
        "uav_predictions_collision_aware.csv"
    ]
    
    print("🚀 ANÁLISE DE MEAN EUCLIDEAN DISTANCE")
    print("="*80)
    
    results = quick_analysis(files_to_analyze)
# Out:
# 🚀 ANÁLISE DE MEAN EUCLIDEAN DISTANCE
# ================================================================================
# 🔍 Encontrados 1 ficheiros para analisar
# ================================================================================
# 📊 Analisando: uav_predictions_collision_aware.csv
#    ✅ Mean Euclidean Distance: 45.9226
#
# ================================================================================
# 📈 RESUMO COMPARATIVO - MEAN EUCLIDEAN DISTANCE
# ================================================================================
# Ficheiro                                 Mean Dist    Std        Min        Max        Linhas
# ------------------------------------------------------------------------------------------
# uav_predictions_collision_aware.csv      45.9226      16.8444    1.7354     83.1211    2400
#
# ==================================================
# 🏆 RANKING:
#    🥇 MELHOR: uav_predictions_collision_aware.csv (Mean: 45.9226)
#    🥉 PIOR:   uav_predictions_collision_aware.csv (Mean: 45.9226)
#    📊 DIFERENÇA: 0.0000
