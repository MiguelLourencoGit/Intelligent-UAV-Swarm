# %% [markdown]
# # avg

# %%
import random
import numpy as np
import math
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt  # Importar matplotlib para plotar gráficos
from functools import partial  # Adicionar no início do código
import networkx as nx
from link_capacity import calcular_capacidade_link, interference_from_jammer
from antenna_null import realistic_antenna_gain

NUM_UAVS = 4
lambda_0 = 0.125
P_INTERFERENCE_DBM = 100
P_NOISE_DBM = -100
BANDWIDTH = 20e6
TRANSMIT_POWER_DBM = 20
MINDIST = 20

# Definir os tipos de indivíduos e fitness
creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # Maximizar o fitnessAS
creator.create("Individual", list, fitness=creator.FitnessMax)  # Indivíduo é uma listaas

#ATENCAO JAMMER POSITION NO CREATE INDIVIDUAL

# Nova função para criar um indivíduo
def create_individual(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, epoch_total_length=300, previous_best_solution=None, initial_positions=None, jammer_position=None):
    individual = []
    
    # Definir as posições iniciais de acordo com o epoch
    if epoch == 0:
        start_positions = initial_positions  # Posições fixas passadas manualmente
    else:
        start_positions = []
        for uav in range(num_uavs):
            last_timeslot_idx = (num_timeslots - 1) * num_uavs * 2 + uav * 2
            start_positions.append(previous_best_solution[last_timeslot_idx:last_timeslot_idx + 2])
    
    # Gerar posições finais (sem verificação de MINDIST)
    final_positions = []
    for uav in range(num_uavs):
        last_x = random.uniform(epoch * epoch_total_length + epoch_total_length - timeslot_length,
                                 epoch * epoch_total_length + epoch_total_length)
        last_y = random.uniform(min_y, max_y)
        final_positions.append([last_x, last_y])
    
    # Calcular todas as posições intermediárias
    for t in range(num_timeslots):
        for uav in range(num_uavs):
            start_x, start_y = start_positions[uav]
            end_x, end_y = final_positions[uav]
            
            # Calcular posição baseada no progresso linear
            alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
            
            x = start_x + alpha * (end_x - start_x)
            y = start_y + alpha * (end_y - start_y)
            
            # Adicionar x,y ao indivíduo
            individual.extend([x, y])
    
    return creator.Individual(individual)

def print_communication_values_per_timeslot(individual, num_uavs, num_timeslots, jammer_position):
    all_min_capacities = []
    all_interference_matrices = []
    all_fitness_values = []  # ← ADICIONAR para armazenar fitness de cada timeslot

    for t in range(num_timeslots):
        angles = []
        positions = []
        
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        comm_matrix, interference_matrix = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)
        all_interference_matrices.append(interference_matrix)

        # ← USAR A MESMA LÓGICA DO evaluate_individual
        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))
                    except:
                        pass
        
        # Cálculo usando apenas links usados (IGUAL AO evaluate_individual)
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
            all_min_capacities.extend(capacidades_usadas)  # ← Adicionar todas as capacidades usadas
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Calcular fitness do timeslot (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness = (C_media_total ** alpha) * (C_min_total ** beta)
        all_fitness_values.append(fitness)

    # Calcular fitness médio (IGUAL AO evaluate_individual)
    if len(all_fitness_values) > 0:
        avg_fitness = sum(all_fitness_values) / len(all_fitness_values)
    else:
        avg_fitness = 0.0

    if len(all_min_capacities) > 0:
        avg_min_capacity = sum(all_min_capacities) / len(all_min_capacities)
    else:
        avg_min_capacity = 0.0

    return all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness  # ← ADICIONAR avg_fitness

# Função para calcular a capacidade de comunicação entre todos os UAVs
def calculate_communication_capacity(antenna_angles, alignments, positions, jammer_position):
    communication_capacity = np.zeros((NUM_UAVS, NUM_UAVS))
    interference_matrix = np.full((NUM_UAVS, NUM_UAVS), P_INTERFERENCE_DBM)

    for i in range(NUM_UAVS):
        null_dir_i = antenna_angles[i]

        dx_jam = jammer_position[0] - positions[i][0]
        dy_jam = jammer_position[1] - positions[i][1]
        dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360

        G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)

        dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
        P_interf_dBm_i = interference_from_jammer(P_INTERFERENCE_DBM, G_jammer_i, lambda_0, dist_jammer_i)

        interference_matrix[i, :] = P_interf_dBm_i

    for i in range(NUM_UAVS):
        for j in range(NUM_UAVS):
            if i != j:
                null_dir_i = antenna_angles[i]
                null_dir_j = antenna_angles[j]

                dx_ij = positions[j][0] - positions[i][0]
                dy_ij = positions[j][1] - positions[i][1]
                dir_tx_to_rx = np.degrees(np.arctan2(dy_ij, dx_ij)) % 360

                dx_ji = positions[i][0] - positions[j][0]
                dy_ji = positions[i][1] - positions[j][1]
                dir_rx_to_tx = np.degrees(np.arctan2(dy_ji, dx_ji)) % 360

                G_tx = realistic_antenna_gain(dir_tx_to_rx, null_dir_i)
                G_rx = realistic_antenna_gain(dir_rx_to_tx, null_dir_j)

                capacity = calcular_capacidade_link(
                    pos1=positions[i],
                    pos2=positions[j],
                    lambda_0=lambda_0,
                    P_tx_dBm=TRANSMIT_POWER_DBM,
                    G_tx_dB=G_tx,
                    G_rx_dB=G_rx,
                    P_interference_dBm=interference_matrix[i, j],
                    P_noise_dBm=P_NOISE_DBM,
                    bandwidth=BANDWIDTH
                )

                communication_capacity[i][j] = capacity

    return communication_capacity, interference_matrix

def has_collision(individual, num_uavs, num_timeslots, min_distance=MINDIST):
    """
    Verifica se há pelo menos uma colisão nas posições dos timeslots.
    Para na primeira colisão encontrada.
    
    Args:
        individual: Lista com as posições [x1, y1, x2, y2, ...]
        num_uavs: Número de UAVs
        num_timeslots: Número de timeslots
        min_distance: Distância mínima de segurança
    
    Returns:
        bool: True se há pelo menos uma colisão, False caso contrário
    """
    # Verificar cada timeslot
    for t in range(num_timeslots):
        # Extrair posições de todos os UAVs neste timeslot
        positions = []
        for uav in range(num_uavs):
            idx_x = t * num_uavs * 2 + uav * 2
            idx_y = t * num_uavs * 2 + uav * 2 + 1
            x = individual[idx_x]
            y = individual[idx_y]
            positions.append(np.array([x, y]))
        
        # Verificar colisões entre todos os pares de UAVs neste timeslot
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                distance = np.linalg.norm(positions[i] - positions[j])
                if distance < min_distance:
                    return True  # PARA IMEDIATAMENTE na primeira colisão
    
    return False  # Nenhuma colisão encontrada

def evaluate_individual(individual, num_uavs, num_timeslots, jammer_position):
    # Verificar se há pelo menos uma colisão
    if has_collision(individual, num_uavs, num_timeslots):
        return (0.0,)  # FITNESS 0 imediatamente
    
    # Se não há colisões, calcular o fitness normalmente
    alpha, beta = 1.0, 1.0
    total_fitness = 0

    for t in range(num_timeslots):
        positions = []
        angles = []
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            # Calcular ângulo dinamicamente
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        # Calcular matriz de comunicação
        comm_matrix, _ = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)

        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Cálculo do fitness usando apenas links usados
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Fitness sem penalização por colisões (já sabemos que não há colisões)
        fitness = (C_media_total ** alpha) * (C_min_total ** beta)
        total_fitness += fitness

    # Calcular a média do fitness total
    average_fitness = total_fitness / num_timeslots if num_timeslots > 0 else 0
    return (average_fitness,)

def mutate_individual(individual, min_x, max_x, min_y, max_y, mutation_rate, num_uavs, num_timeslots, epoch, timeslot_length, epoch_total_length):
    for uav in range(num_uavs):
        if random.random() < mutation_rate:
            # Extrair posições iniciais
            start_x = individual[uav * 2]
            start_y = individual[uav * 2 + 1]
            
            # Nova posição final
            new_final_x = random.uniform(epoch * epoch_total_length + epoch_total_length - timeslot_length, 
                                        epoch * epoch_total_length + epoch_total_length)
            new_final_y = random.uniform(min_y, max_y)
            
            # Atualizar a posição final
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2] = new_final_x
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2 + 1] = new_final_y
            
            # Recalcular posições intermediárias (t=1 até num_timeslots-1)
            for t in range(1, num_timeslots):
                alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
                x = start_x + alpha * (new_final_x - start_x)
                y = start_y + alpha * (new_final_y - start_y)
                
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                individual[idx_x] = x
                individual[idx_y] = y
    
    return individual,

def custom_crossover(ind1, ind2, num_uavs):
    num_timeslots = len(ind1) // (num_uavs * 2)
    
    # Trocar posições de UAVs inteiros (exceto a posição inicial t=0)
    for uav in range(num_uavs):
        if random.random() < 0.5:
            for t in range(1, num_timeslots):  # Começar de t=1
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                
                # Trocar x,y para todos os timeslots deste UAV (exceto t=0)
                ind1[idx_x], ind2[idx_x] = ind2[idx_x], ind1[idx_x]
                ind1[idx_y], ind2[idx_y] = ind2[idx_y], ind1[idx_y]
    
    return ind1, ind2

# Configuração do DEAP atualizada
def setup_deap(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, crossover_rate, mutation_rate, initial_positions, previous_best_solution=None, jammer_position=None, epoch_total_length=300):
    toolbox = base.Toolbox()
    
    # Registrar funções
    toolbox.register("individual", create_individual, 
                     num_uavs=num_uavs, 
                     num_timeslots=num_timeslots, 
                     timeslot_length=timeslot_length, 
                     epoch=epoch, 
                     min_y=min_y, 
                     max_y=max_y,
                     epoch_total_length=epoch_total_length,  # ← ADICIONAR
                     previous_best_solution=previous_best_solution,
                     initial_positions=initial_positions,
                     jammer_position=jammer_position)  # Passar a posição do jammer aqui
    
    # O restante do código permanece o mesmo...

    
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("evaluate", evaluate_individual, num_uavs=num_uavs, num_timeslots=num_timeslots, jammer_position=jammer_position)
    
    # Usar partial para fixar o argumento num_uavs na função custom_crossover
    toolbox.register("mate", partial(custom_crossover, num_uavs=num_uavs))
    
    min_x = epoch * num_timeslots * timeslot_length
    max_x = (epoch * num_timeslots + num_timeslots) * timeslot_length
    
    toolbox.register("mutate", mutate_individual, 
                 min_x=min_x, 
                 max_x=max_x, 
                 min_y=min_y, 
                 max_y=max_y, 
                 mutation_rate=mutation_rate,
                 num_uavs=num_uavs,
                 num_timeslots=num_timeslots,
                 epoch=epoch,
                 timeslot_length=timeslot_length,
                 epoch_total_length=epoch_total_length)  # ← ADICIONAR
    
    toolbox.register("select", tools.selTournament, tournsize=3)  # Seleção por torneio
    
    return toolbox

def genetic_algorithm(num_uavs, num_timeslots, timeslot_length, population_size, generations, crossover_rate, mutation_rate, epoch, initial_positions, previous_best_solution=None, jammer_position=None, min_y=0.0, max_y=5.0, epoch_total_length=300):
    # Configurar o DEAP
    toolbox = setup_deap(
        num_uavs=num_uavs,
        num_timeslots=num_timeslots,
        timeslot_length=timeslot_length,
        epoch=epoch,
        min_y=min_y,
        max_y=max_y,
        crossover_rate=crossover_rate,
        mutation_rate=mutation_rate,
        initial_positions=initial_positions,
        previous_best_solution=previous_best_solution,
        jammer_position=jammer_position,
        epoch_total_length=epoch_total_length  # ← ADICIONAR
    )

    
    # Criar população inicial
    population = toolbox.population(n=population_size)
    
    # Avaliar a população inicial
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit
    
    # Configurar estatísticas para impressão
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("std", np.std)
    stats.register("min", np.min)
    stats.register("max", np.max)
    
    # Listas para armazenar os dados de cada geração
    gen_list = []
    avg_list = []
    std_list = []
    min_list = []
    max_list = []
    
    # Executar o algoritmo genético com eaSimple
    for gen in range(generations):
        # Avançar uma geração
        algorithms.eaSimple(
            population, 
            toolbox, 
            cxpb=crossover_rate,  # Probabilidade de cruzamento
            mutpb=mutation_rate,  # Probabilidade de mutação
            ngen=1,               # Apenas uma geração por iteração
            stats=stats,          # Estatísticas para impressão
            verbose=False         # Desativar impressão da tabela para cada geração
        )
        
        # Coletar os dados da geração atual
        record = stats.compile(population)
        gen_list.append(gen)
        avg_list.append(record["avg"])
        std_list.append(record["std"])
        min_list.append(record["min"])
        max_list.append(record["max"])
        
        # Escrever os valores no arquivo
        #write_fitness_values(epoch, gen, record["avg"], record["max"], record["min"], record["std"])
    
    # Retornar o melhor indivíduo
    best_individual = tools.selBest(population, k=1)[0]
    return best_individual

# Função para gerar posições iniciais dos UAVs
def generate_initial_positions(num_uavs, min_y, max_y, timeslot_length, manual=False, manual_positions=None):
    if manual and manual_positions is not None:
        return manual_positions  # Usa as posições fornecidas

    positions = []
    max_attempts = 1000  # para evitar loops infinitos

    for _ in range(num_uavs):
        attempts = 0
        while True:
            y = random.uniform(min_y, max_y)
            x = random.uniform(0, timeslot_length)  # entre -timeslot_length e 0
            
            candidate = (x, y)
            
            # Verifica se está longe o suficiente das outras posições já geradas
            if all(np.linalg.norm(np.array(candidate) - np.array(pos)) >= MINDIST for pos in positions):
                positions.append(candidate)
                break
            
            attempts += 1
            if attempts >= max_attempts:
                # Se não conseguir, aceita a posição mesmo assim para evitar bloqueio
                positions.append(candidate)
                break
                
    return positions

def save_best_solution_to_file(best_solution, initial_positions, filename="best_solution_epoch.txt"):
    with open(filename, "a") as file:
        # Escrever apenas a melhor solução (que já inclui tudo)
        individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
        file.write(f"{individual_str}\n \n")

def write_fitness_values(epoch, gen, avg, max_val, min_val, std, filename="fitness_values.txt"):
    
    with open(filename, "a") as file:
        if gen == 0:  # Escrever o cabeçalho no início de cada epoch
            file.write(f"=== Epoch {epoch + 1} ===\n")
            file.write("gen\tavg\tmax\tmin\tstd\n")
        file.write(f"{gen}\t{avg:.4f}\t{max_val:.4f}\t{min_val:.4f}\t{std:.4f}\n")

# Função principal atualizada
def simulate_uavs_with_ga(num_epochs, num_timeslots, timeslot_length, num_uavs, population_size=50, generations=50, crossover_rate=0.8, mutation_rate=0.15, manual_initial_positions=None, jammer_position=None, min_y=0.0, max_y=10.0, epoch_total_length=300):
    # Gerar posições iniciais dos UAVs
    initial_positions = generate_initial_positions(
        num_uavs, min_y, max_y, timeslot_length,
        manual=manual_initial_positions is not None,
        manual_positions=manual_initial_positions
    )

    previous_best_solution = None
    
    for epoch in range(num_epochs):
        # Executar o algoritmo genético
        best_solution = genetic_algorithm(
            num_uavs=num_uavs,
            num_timeslots=num_timeslots,
            timeslot_length=timeslot_length,
            population_size=population_size,
            generations=generations,
            crossover_rate=crossover_rate,
            mutation_rate=mutation_rate,
            epoch=epoch,
            initial_positions=initial_positions,
            previous_best_solution=previous_best_solution,
            jammer_position=jammer_position,  # Passar a posição do jammer aqui
            min_y=min_y,
            max_y=max_y,
            epoch_total_length=epoch_total_length  # ← ADICIONAR
        )

        # O restante do código permanece o mesmo...


        # Salvar a melhor solução em um arquivo de texto
        save_best_solution_to_file(best_solution, initial_positions)
        
        all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness = print_communication_values_per_timeslot(best_solution, num_uavs, num_timeslots, jammer_position)

        # Guardar a melhor solução para a próxima epoch


        # # Calcular e imprimir a coerência dos valores
        # best_fitness = best_solution.fitness.values[0]
        # recalculated_fitness = evaluate_individual(best_solution, num_uavs, num_timeslots, jammer_position)[0]
        # # Ler o último valor máximo do fitness_values.txt
        # with open("fitness_values.txt", "r") as file:
        #     lines = file.readlines()
        #     last_max_fitness = float(lines[-1].split("\t")[2])  # Último max na última linha
        # # Comparar os valores
        # print(f"Fitness da melhor solução: {best_fitness:.4f}")
        # print(f"Fitness recalculado: {recalculated_fitness:.4f}")
        # print(f"Último max no arquivo: {last_max_fitness:.4f}")
        # print(f"São iguais? {'✅' if abs(best_fitness - last_max_fitness) < 1 else '❌'}")
        # # Guardar a melhor solução para a próxima epoch
        # previous_best_solution = best_solution



        previous_best_solution = best_solution

        return best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity

# %%
# Posições que respeitam MINDIST = 5 metros
posicoes_manuais1 = [
    (20.0, 20.0),   # UAV 1
    (20.0, 40.0),   # UAV 2 (60m de distância do UAV1)
    (40.0, 20.0),   # UAV 3 (60m de distância do UAV1)1
    (40.0, 40.0)    # UAV 4 (60m de distância dos outros)
]

# Executar simulação
best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity = simulate_uavs_with_ga(
    num_epochs=1, 
    num_timeslots=6, 
    timeslot_length=60, 
    num_uavs=NUM_UAVS,
    population_size=50,
    generations=50,
    manual_initial_positions=posicoes_manuais1,
    jammer_position=np.array([0,500]),
    min_y=0.0,
    max_y=60.0,
    epoch_total_length=120
)

print("Posições iniciais usadas:", initial_positions)
# Out:
# Posições iniciais usadas: [(20.0, 20.0), (20.0, 40.0), (40.0, 20.0), (40.0, 40.0)]

# %%
posicoes_manuais1 = [
    (20.0, 20.0),   # UAV 1
    (20.0, 40.0),   # UAV 2 (60m de distância do UAV1)
    (40.0, 20.0),   # UAV 3 (60m de distância do UAV1)
    (40.0, 40.0)    # UAV 4 (60m de distância dos outros)
]

# Lista de posições do jammer
jammer_positions = [
    np.array([0, 500]),
    np.array([200, 500]),
    np.array([400, 500]),
    np.array([600, 500]),
    np.array([800, 500]),
    np.array([1000, 500]),
    np.array([0, 30]),
    np.array([1000, 30]),
]

# Lista de configurações do GA (pop_size, generations)
ga_configs = [
    (50, 50),
    (100, 100),
    (200, 200),
    (500, 500),

]

# Parâmetros fixos
NUM_EPOCHS = 1
NUM_TIMESLOTS = 6
TIMESLOT_LENGTH = 60
EPOCH_TOTAL_LENGTH = 120

# Guardar os resultados
resultados = []

for jammer_pos in jammer_positions:
    for pop_size, generations in ga_configs:
        best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity = simulate_uavs_with_ga(
            num_epochs=NUM_EPOCHS, 
            num_timeslots=NUM_TIMESLOTS, 
            timeslot_length=TIMESLOT_LENGTH, 
            num_uavs=NUM_UAVS,
            population_size=pop_size,
            generations=generations,
            manual_initial_positions=posicoes_manuais1,
            jammer_position=jammer_pos,
            min_y=0.0,
            max_y=60.0,
            epoch_total_length=EPOCH_TOTAL_LENGTH
        )
        
        resultados.append({
            "jammer_position": jammer_pos.tolist(),
            "population_size": pop_size,
            "generations": generations,
            "best_solution": best_solution,
            "avg_min_capacity": avg_min_capacity
        })


# Resumo final
print("\nResumo das simulações:")
for r in resultados:
    print(r)
# Out:
# Resumo das simulações:
# {'jammer_position': [0, 500], 'population_size': 50, 'generations': 50, 'best_solution': [20.0, 20.0, 20.0, 40.0, 40.0, 20.0, 40.0, 40.0, 29.000812425413166, 23.470635092578775, 35.10841961054503, 42.990877886901835, 49.73117077983423, 20.744425021370716, 55.14616513537733, 40.27654819893732, 38.00162485082633, 26.941270185157546, 50.21683922109006, 45.98175577380366, 59.46234155966847, 21.488850042741436, 70.29233027075466, 40.55309639787463, 47.00243727623949, 30.411905277736317, 65.3252588316351, 48.9726336607055, 69.19351233950269, 22.233275064112153, 85.438495406132, 40.82964459681195, 56.003249701652656, 33.88254037031509, 80.43367844218012, 51.963511547607325, 78.92468311933693, 22.977700085482873, 100.58466054150934, 41.106192795749266, 65.00406212706582, 37.353175462893866, 95.54209805272515, 54.95438943450916, 88.65585389917116, 23.72212510685359, 115.73082567688667, 41.382740994686586], 'avg_min_capacity': np.float64(7249.793098171243)}
# {'jammer_position': [0, 500], 'population_size': 100, 'generations': 100, 'best_solution': [20.0, 20.0, 20.0, 40.0, 40.0, 20.0, 40.0, 40.0, 30.688046451824682, 18.880003326794785, 35.539824505538625, 39.003115607724716, 50.69592249391042, 18.399372457482798, 55.773889903215334, 38.431374950599114, 41.376092903649365, 17.76000665358957, 51.07964901107725, 38.00623121544944, 61.391844987820846, 16.7987449149656, 71.54777980643067, 36.86274990119823, 52.06413935547404, 16.640009980384356, 66.61947351661587, 37.009346823174155, 72.08776748173128, 15.198117372448397, 87.32166970964599, 35.29412485179734, 62.75218580729873, 15.52001330717914, 82.1592980221545, 36.01246243089888, 82.78368997564169, 13.597489829931197, 103.09555961286134, 33.725499802396456, 73.4402322591234, 14.400016633973925, 97.69912252769313, 35.015578038623595, 93.47961246955212, 11.996862287413997, 118.86944951607666, 32.15687475299557], 'avg_min_capacity': np.float64(9812.213272420016)}
# {'jammer_position': [0, 500], 'population_size': 200, 'generations': 200, 'best_solution': [20.0, 20.0, 20.0, 40.0, 40.0, 20.0, 40.0, 40.0,
def analisar_comunicacoes_detalhado(filename, num_uavs, num_timeslots, jammer_position):
    def parse_solution_file(filename):
        with open(filename, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        solutions = []
        current_solution = []
        for line in lines:
            if line.startswith('==='):  # Nova época
                if current_solution:
                    solutions.append(current_solution)
                    current_solution = []
            else:
                current_solution.extend(map(float, line.split()))
        if current_solution:
            solutions.append(current_solution)
        return solutions

    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # Processar arquivo de saída
    solucoes = parse_solution_file(filename)
    
    resultados = []
    for idx, solucao in enumerate(solucoes):
        print(f"\nAnálise para Época {idx+1}:")
        
        # 🚨 VERIFICAR COLISÕES PRIMEIRO (IGUAL AO evaluate_individual)
        tem_colisoes = has_collision(solucao, num_uavs, num_timeslots)
        print(f"🔍 Verificação de colisões: {'❌ TEM COLISÕES' if tem_colisoes else '✅ SEM COLISÕES'}")
        
        if tem_colisoes:
            print(f"🚨 SOLUÇÃO COM COLISÕES DETECTADA!")
            print(f"   Fitness = 0.0 (igual ao evaluate_individual)")
            print(f"   Não será feita análise detalhada.")
            print("="*50)
            return [(0.0, "Solução com colisões")]
        
        # Se não há colisões, continuar com a análise normal
        print(f"✅ Solução válida - prosseguindo com análise detalhada...")
        
        # Lista para armazenar todos os C_média_total e C_min_total do epoch
        todos_c_media = []
        todos_c_min = []
        
        # Recriar a solução para cada timeslot
        for t in range(num_timeslots):
            print(f"\nTimeslot {t+1}:")
            positions = []
            angles = []
            
            for i in range(num_uavs):
                idx_pos = t * num_uavs * 2 + i * 2  # MUDANÇA: *2, pois só temos x e y
                x, y = solucao[idx_pos:idx_pos+2]
                positions.append(np.array([x, y]))
                
                # Calcular ângulo dinamicamente
                angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
                angles.append(angle)
            
            # Calcular matriz de comunicação
            comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
            
            # Gerar métricas detalhadas
            metricas = avaliar_grafo(comm_matrix)
            
            # Exibir resultados
            print("\nMatriz de Comunicação (bps):")
            print(np.round(comm_matrix, 2))
            
            print("\nResumo de Capacidades:")
            print(f"- Capacidades: {metricas['capacidades']}")
            print(f"- Média: {np.mean(metricas['capacidades']):.2f} bps")
            print(f"- Mínima: {min(metricas['capacidades']):.2f} bps")
            print(f"- Máxima: {max(metricas['capacidades']):.2f} bps")
            
            print("\nCaminhos Críticos:")
            for (i,j), data in metricas['caminhos_minimos'].items():
                print(f"UAV {i} → UAV {j}: {data['path']} (Capacidade: {data['capacidade']:.2f} bps)")
            
            print("\nBottlenecks por UAV:")
            for uav, cap in metricas['bottlenecks'].items():
                print(f"UAV {uav}: {cap:.2f} bps")
            
            print(f"\nGrafo é fortemente conexo? {'Sim' if metricas['conectividade'] else 'Não'}")
            
            print("\nLinks Usados:")
            for u, v in metricas['links_usados']:
                print(f"{u} ↔ {v}")
            
            print("\nLinks Não Usados:")
            for u, v in metricas['links_nao_usados']:
                print(f"{u} ↔ {v}")
            
            # Cálculo do fitness usando apenas links usados
            capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0
            
            # Adicionar às listas do epoch
            todos_c_media.append(C_media_total)
            todos_c_min.append(C_min_total)
            
            print(f"\nCálculo do Fitness para Timeslot {t+1}:")
            print(f"Capacidades Usadas: {capacidades_usadas}")
            print(f"C_média_total = {C_media_total:.2f} bps")
            print(f"C_min_total = {C_min_total:.2f} bps")
            
            resultados.append({
                'epoch': idx+1,
                'timeslot': t+1,
                'metricas': metricas,
                'C_media_total': C_media_total,
                'C_min_total': C_min_total
            })
        
        # ✅ CORREÇÃO: Calcular fitness de cada timeslot e depois fazer a média (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness_por_timeslot = []
        
        for i in range(len(todos_c_media)):
            C_media = todos_c_media[i]
            C_min = todos_c_min[i]
            fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
            fitness_por_timeslot.append(fitness_timeslot)
        
        # Fitness médio do epoch (IGUAL AO evaluate_individual)
        fitness_epoch = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular também as médias para informação
        media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
        media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
        
        print(f"\n" + "="*50)
        print(f"RESUMO DO EPOCH {idx+1}:")
        print(f"Todos os C_média_total: {[f'{x:.2f}' for x in todos_c_media]}")
        print(f"Todos os C_min_total: {[f'{x:.2f}' for x in todos_c_min]}")
        print(f"Fitness por timeslot: {[f'{x:.4f}' for x in fitness_por_timeslot]}")
        print(f"Média dos C_média_total: {media_c_media_epoch:.2f} bps")
        print(f"Média dos C_min_total: {media_c_min_epoch:.2f} bps")
        print(f"🎯 Fitness do Epoch (CORRETO) = {fitness_epoch:.4f}")
        print(f"✅ Agora deve bater com o valor do gráfico!")
        print("="*50)
    
    return resultados

# %%
resultados = analisar_comunicacoes_detalhado(
    filename="best_solution_epoch.txt",
    num_uavs=4,  # ou o número correto de UAVs que você está usando
    num_timeslots=6,  # Confirmando que são 6 timeslots
    jammer_position=np.array([0,500])  # Posição do jammer
)
# Out:
# Análise para Época 1:
# 🔍 Verificação de colisões: ✅ SEM COLISÕES
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# Timeslot 1:
#
# Matriz de Comunicação (bps):
# [[   0.     15.58 5635.67  522.99]
#  [  15.58    0.    178.92 5253.86]
#  [5635.67  178.92    0.     28.2 ]
#  [ 522.99 5253.86   28.2     0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [15.581757060984389, 5635.667989738092, 522.9935746204219, 15.581757060984389, 178.91821657158118, 5253.858917538357, 5635.667989738092, 178.91821657158118, 28.197768312997905, 522.9935746204219, 5253.858917538357, 28.197768312997905]
# - Média: 1939.20 bps
# - Mínima: 15.58 bps
# - Máxima: 5635.67 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 3, 1] (Capacidade: 522.99 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 5635.67 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 522.99 bps)
# UAV 1 → UAV 0: [1, 3, 0] (Capacidade: 522.99 bps)
# UAV 1 → UAV 2: [1, 3, 0, 2] (Capacidade: 522.99 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 5253.86 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 5635.67 bps)
# UAV 2 → UAV 1: [2, 0, 3, 1] (Capacidade: 522.99 bps)
# UAV 2 → UAV 3: [2, 0, 3] (Capacidade: 522.99 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 522.99 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 5253.86 bps)
# UAV 3 → UAV 2: [3, 0, 2] (Capacidade: 522.99 bps)
#
# Bottlenecks por UAV:
# UAV 0: 15.58 bps
# UAV 1: 15.58 bps
# UAV 2: 28.20 bps
# UAV 3: 28.20 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 3 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Cálculo do Fitness para Timeslot 1:
# Capacidades Usadas: [5253.858917538357, 522.9935746204219, 5635.667989738092, 522.9935746204219, 5635.667989738092, 5253.858917538357]
# C_média_total = 3804.17 bps
# C_min_total = 522.99 bps
#
# Timeslot 2:
#
# Matriz de Comunicação (bps):
# [[   0.     38.38 5831.03 1182.75]
#  [  38.38    0.    242.76 5782.18]
#  [5831.03  242.76    0.     59.71]
#  [1182.75 5782.18   59.71    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [38.38155533094723, 5831.030368711805, 1182.7480265130023, 38.38155533094723, 242.75591287513512, 5782.183284619634, 5831.030368711805, 242.75591287513512, 59.712530258058536, 1182.7480265130023, 5782.183284619634, 59.712530258058536]
# - Média: 2189.47 bps
# - Mínima: 38.38 bps
# - Máxima: 5831.03 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 3, 1] (Capacidade: 1182.75 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 5831.03 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 1182.75 bps)
# UAV 1 → UAV 0: [1, 3, 0] (Capacidade: 1182.75 bps)
# UAV 1 → UAV 2: [1, 3, 0, 2] (Capacidade: 1182.75 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 5782.18 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 5831.03 bps)
# UAV 2 → UAV 1: [2, 0, 3, 1] (Capacidade: 1182.75 bps)
# UAV 2 → UAV 3: [2, 0, 3] (Capacidade: 1182.75 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 1182.75 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 5782.18 bps)
# UAV 3 → UAV 2: [3, 0, 2] (Capacidade: 1182.75 bps)
#
# Bottlenecks por UAV:
# UAV 0: 38.38 bps
# UAV 1: 38.38 bps
# UAV 2: 59.71 bps
# UAV 3: 59.71 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 3 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Cálculo do Fitness para Timeslot 2:
# Capacidades Usadas: [5782.183284619634, 1182.7480265130023, 5831.030368711805, 1182.7480265130023, 5831.030368711805, 5782.183284619634]
# C_média_total = 4265.32 bps
# C_min_total = 1182.75 bps
#
# Timeslot 3:
#
# Matriz de Comunicação (bps):
# [[   0.    149.35 6031.27 2457.32]
#  [ 149.35    0.    416.59 6390.43]
#  [6031.27  416.59    0.    166.85]
#  [2457.32 6390.43  166.85    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [149.3510199628927, 6031.267369978413, 2457.323523874595, 149.3510199628927, 416.59317305106117, 6390.427495982607, 6031.267369978413, 416.59317305106117, 166.85381763540013, 2457.323523874595, 6390.427495982607, 166.85381763540013]
# - Média: 2601.97 bps
# - Mínima: 149.35 bps
# - Máxima: 6390.43 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 3, 1] (Capacidade: 2457.32 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 6031.27 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 2457.32 bps)
# UAV 1 → UAV 0: [1, 3, 0] (Capacidade: 2457.32 bps)
# UAV 1 → UAV 2: [1, 3, 0, 2] (Capacidade: 2457.32 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 6390.43 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 6031.27 bps)
# UAV 2 → UAV 1: [2, 0, 3, 1] (Capacidade: 2457.32 bps)
# UAV 2 → UAV 3: [2, 0, 3] (Capacidade: 2457.32 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 2457.32 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 6390.43 bps)
# UAV 3 → UAV 2: [3, 0, 2] (Capacidade: 2457.32 bps)
#
# Bottlenecks por UAV:
# UAV 0: 149.35 bps
# UAV 1: 149.35 bps
# UAV 2: 166.85 bps
# UAV 3: 166.85 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 3 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Cálculo do Fitness para Timeslot 3:
# Capacidades Usadas: [6390.427495982607, 2457.323523874595, 6031.267369978413, 2457.323523874595, 6031.267369978413, 6390.427495982607]
# C_média_total = 4959.67 bps
# C_min_total = 2457.32 bps
#
# Timeslot 4:
#
# Matriz de Comunicação (bps):
# [[   0.   1724.24 6244.41 4151.72]
#  [1724.24    0.   1255.59 7039.93]
#  [6244.41 1255.59    0.    806.75]
#  [4151.72 7039.93  806.75    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [1724.2369089981341, 6244.414557134897, 4151.718534233045, 1724.2369089981341, 1255.5920800153276, 7039.934854447287, 6244.414557134897, 1255.5920800153276, 806.754816676094, 4151.718534233045, 7039.934854447287, 806.754816676094]
# - Média: 3537.11 bps
# - Mínima: 806.75 bps
# - Máxima: 7039.93 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 3, 1] (Capacidade: 4151.72 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 6244.41 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 4151.72 bps)
# UAV 1 → UAV 0: [1, 3, 0] (Capacidade: 4151.72 bps)
# UAV 1 → UAV 2: [1, 3, 0, 2] (Capacidade: 4151.72 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 7039.93 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 6244.41 bps)
# UAV 2 → UAV 1: [2, 0, 3, 1] (Capacidade: 4151.72 bps)
# UAV 2 → UAV 3: [2, 0, 3] (Capacidade: 4151.72 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 4151.72 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 7039.93 bps)
# UAV 3 → UAV 2: [3, 0, 2] (Capacidade: 4151.72 bps)
#
# Bottlenecks por UAV:
# UAV 0: 1724.24 bps
# UAV 1: 1255.59 bps
# UAV 2: 806.75 bps
# UAV 3: 806.75 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 3 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Cálculo do Fitness para Timeslot 4:
# Capacidades Usadas: [7039.934854447287, 4151.718534233045, 6244.414557134897, 4151.718534233045, 6244.414557134897, 7039.934854447287]
# C_média_total = 5812.02 bps
# C_min_total = 4151.72 bps
#
# Timeslot 5:
#
# Matriz de Comunicação (bps):
# [[    0.   15171.27  6478.62  5078.09]
#  [15171.27     0.    7778.3   7649.32]
#  [ 6478.62  7778.3      0.    7971.42]
#  [ 5078.09  7649.32  7971.42     0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [15171.274157245243, 6478.619807345589, 5078.08750390921, 15171.274157245243, 7778.303179564503, 7649.322919155659, 6478.619807345589, 7778.303179564503, 7971.424788888297, 5078.08750390921, 7649.322919155659, 7971.424788888297]
# - Média: 8354.51 bps
# - Mínima: 5078.09 bps
# - Máxima: 15171.27 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 15171.27 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 6478.62 bps)
# UAV 0 → UAV 3: [0, 1, 3] (Capacidade: 7649.32 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 15171.27 bps)
# UAV 1 → UAV 2: [1, 2] (Capacidade: 7778.30 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 7649.32 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 6478.62 bps)
# UAV 2 → UAV 1: [2, 1] (Capacidade: 7778.30 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 7971.42 bps)
# UAV 3 → UAV 0: [3, 1, 0] (Capacidade: 7649.32 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 7649.32 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 7971.42 bps)
#
# Bottlenecks por UAV:
# UAV 0: 5078.09 bps
# UAV 1: 7649.32 bps
# UAV 2: 6478.62 bps
# UAV 3: 5078.09 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 3 ↔ 1
# 2 ↔ 0
# 2 ↔ 3
# 0 ↔ 2
# 1 ↔ 0
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 3
# 3 ↔ 0
#
# Cálculo do Fitness para Timeslot 5:
# Capacidades Usadas: [15171.274157245243, 7778.303179564503, 7778.303179564503, 7649.322919155659, 6478.619807345589, 7971.424788888297, 6478.619807345589, 15171.274157245243, 7971.424788888297, 7649.322919155659]
# C_média_total = 9009.79 bps
# C_min_total = 6478.62 bps
#
# Timeslot 6:
#
# Matriz de Comunicação (bps):
# [[    0.    2555.1   6746.77  4230.07]
#  [ 2555.1      0.    8944.92  8057.45]
#  [ 6746.77  8944.92     0.   11407.03]
#  [ 4230.07  8057.45 11407.03     0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [2555.099722246125, 6746.770047878084, 4230.065367992126, 2555.099722246125, 8944.91610015192, 8057.450938107442, 6746.770047878084, 8944.91610015192, 11407.031129391416, 4230.065367992126, 8057.450938107442, 11407.031129391416]
# - Média: 6990.22 bps
# - Mínima: 2555.10 bps
# - Máxima: 11407.03 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 2, 1] (Capacidade: 6746.77 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 6746.77 bps)
# UAV 0 → UAV 3: [0, 2, 3] (Capacidade: 6746.77 bps)
# UAV 1 → UAV 0: [1, 2, 0] (Capacidade: 6746.77 bps)
# UAV 1 → UAV 2: [1, 2] (Capacidade: 8944.92 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 8057.45 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 6746.77 bps)
# UAV 2 → UAV 1: [2, 1] (Capacidade: 8944.92 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 11407.03 bps)
# UAV 3 → UAV 0: [3, 2, 0] (Capacidade: 6746.77 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 8057.45 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 11407.03 bps)
#
# Bottlenecks por UAV:
# UAV 0: 2555.10 bps
# UAV 1: 2555.10 bps
# UAV 2: 6746.77 bps
# UAV 3: 4230.07 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 1 ↔ 2
# 2 ↔ 1
# 3 ↔ 1
# 2 ↔ 0
# 2 ↔ 3
# 0 ↔ 2
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 0
# 0 ↔ 3
# 3 ↔ 0
#
# Cálculo do Fitness para Timeslot 6:
# Capacidades Usadas: [8944.91610015192, 8944.91610015192, 8057.450938107442, 6746.770047878084, 11407.031129391416, 6746.770047878084, 11407.031129391416, 8057.450938107442]
# C_média_total = 8789.04 bps
# C_min_total = 6746.77 bps
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['3804.17', '4265.32', '4959.67', '5812.02', '9009.79', '8789.04']
# Todos os C_min_total: ['522.99', '1182.75', '2457.32', '4151.72', '6478.62', '6746.77']
# Fitness por timeslot: ['1989558.2941', '5044799.4747', '12187520.6338', '24129882.1516', '58370997.2839', '59297645.6787']
# Média dos C_média_total: 6106.67 bps
# Média dos C_min_total: 3590.03 bps
# 🎯 Fitness do Epoch (CORRETO) = 26836733.9195
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================

# %% [markdown]
# # prod

# %%
import random
import numpy as np
import math
from deap import base, creator, tools, algorithms
import matplotlib.pyplot as plt  # Importar matplotlib para plotar gráficos
from functools import partial  # Adicionar no início do código
import networkx as nx
from link_capacity import calcular_capacidade_link, interference_from_jammer
from antenna_null import realistic_antenna_gain

NUM_UAVS = 4
lambda_0 = 0.125
P_INTERFERENCE_DBM = 100
P_NOISE_DBM = -100
BANDWIDTH = 20e6
TRANSMIT_POWER_DBM = 20
MINDIST = 20

# Definir os tipos de indivíduos e fitness
creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # Maximizar o fitnessAS
creator.create("Individual", list, fitness=creator.FitnessMax)  # Indivíduo é uma listaas

#ATENCAO JAMMER POSITION NO CREATE INDIVIDUAL

# Nova função para criar um indivíduo
def create_individual(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, epoch_total_length=300, previous_best_solution=None, initial_positions=None, jammer_position=None):
    individual = []
    
    # Definir as posições iniciais de acordo com o epoch
    if epoch == 0:
        start_positions = initial_positions  # Posições fixas passadas manualmente
    else:
        start_positions = []
        for uav in range(num_uavs):
            last_timeslot_idx = (num_timeslots - 1) * num_uavs * 2 + uav * 2
            start_positions.append(previous_best_solution[last_timeslot_idx:last_timeslot_idx + 2])
    
    # Gerar posições finais (sem verificação de MINDIST)
    final_positions = []
    for uav in range(num_uavs):
        last_x = random.uniform(epoch * epoch_total_length + epoch_total_length - timeslot_length,
                                 epoch * epoch_total_length + epoch_total_length)
        last_y = random.uniform(min_y, max_y)
        final_positions.append([last_x, last_y])
    
    # Calcular todas as posições intermediárias
    for t in range(num_timeslots):
        for uav in range(num_uavs):
            start_x, start_y = start_positions[uav]
            end_x, end_y = final_positions[uav]
            
            # Calcular posição baseada no progresso linear
            alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
            
            x = start_x + alpha * (end_x - start_x)
            y = start_y + alpha * (end_y - start_y)
            
            # Adicionar x,y ao indivíduo
            individual.extend([x, y])
    
    return creator.Individual(individual)

def print_communication_values_per_timeslot(individual, num_uavs, num_timeslots, jammer_position):
    all_min_capacities = []
    all_interference_matrices = []
    all_fitness_values = []  # ← ADICIONAR para armazenar fitness de cada timeslot

    for t in range(num_timeslots):
        angles = []
        positions = []
        
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        comm_matrix, interference_matrix = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)
        all_interference_matrices.append(interference_matrix)

        # ← USAR A MESMA LÓGICA DO evaluate_individual
        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))
                    except:
                        pass
        
        # Cálculo usando apenas links usados (IGUAL AO evaluate_individual)
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
            all_min_capacities.extend(capacidades_usadas)  # ← Adicionar todas as capacidades usadas
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Calcular fitness do timeslot (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness = (C_media_total ** alpha) * (C_min_total ** beta)
        all_fitness_values.append(fitness)

    # Calcular fitness médio (IGUAL AO evaluate_individual)
    if len(all_fitness_values) > 0:
        avg_fitness = sum(all_fitness_values) / len(all_fitness_values)
    else:
        avg_fitness = 0.0

    if len(all_min_capacities) > 0:
        avg_min_capacity = sum(all_min_capacities) / len(all_min_capacities)
    else:
        avg_min_capacity = 0.0

    return all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness  # ← ADICIONAR avg_fitness

# Função para calcular a capacidade de comunicação entre todos os UAVs
def calculate_communication_capacity(antenna_angles, alignments, positions, jammer_position):
    communication_capacity = np.zeros((NUM_UAVS, NUM_UAVS))
    interference_matrix = np.full((NUM_UAVS, NUM_UAVS), P_INTERFERENCE_DBM)

    for i in range(NUM_UAVS):
        null_dir_i = antenna_angles[i]

        dx_jam = jammer_position[0] - positions[i][0]
        dy_jam = jammer_position[1] - positions[i][1]
        dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360

        G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)

        dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
        P_interf_dBm_i = interference_from_jammer(P_INTERFERENCE_DBM, G_jammer_i, lambda_0, dist_jammer_i)

        interference_matrix[i, :] = P_interf_dBm_i

    for i in range(NUM_UAVS):
        for j in range(NUM_UAVS):
            if i != j:
                null_dir_i = antenna_angles[i]
                null_dir_j = antenna_angles[j]

                dx_ij = positions[j][0] - positions[i][0]
                dy_ij = positions[j][1] - positions[i][1]
                dir_tx_to_rx = np.degrees(np.arctan2(dy_ij, dx_ij)) % 360

                dx_ji = positions[i][0] - positions[j][0]
                dy_ji = positions[i][1] - positions[j][1]
                dir_rx_to_tx = np.degrees(np.arctan2(dy_ji, dx_ji)) % 360

                G_tx = realistic_antenna_gain(dir_tx_to_rx, null_dir_i)
                G_rx = realistic_antenna_gain(dir_rx_to_tx, null_dir_j)

                capacity = calcular_capacidade_link(
                    pos1=positions[i],
                    pos2=positions[j],
                    lambda_0=lambda_0,
                    P_tx_dBm=TRANSMIT_POWER_DBM,
                    G_tx_dB=G_tx,
                    G_rx_dB=G_rx,
                    P_interference_dBm=interference_matrix[i, j],
                    P_noise_dBm=P_NOISE_DBM,
                    bandwidth=BANDWIDTH
                )

                communication_capacity[i][j] = capacity

    return communication_capacity, interference_matrix

def has_collision(individual, num_uavs, num_timeslots, min_distance=MINDIST):
    """
    Verifica se há pelo menos uma colisão nas posições dos timeslots.
    Para na primeira colisão encontrada.
    
    Args:
        individual: Lista com as posições [x1, y1, x2, y2, ...]
        num_uavs: Número de UAVs
        num_timeslots: Número de timeslots
        min_distance: Distância mínima de segurança
    
    Returns:
        bool: True se há pelo menos uma colisão, False caso contrário
    """
    # Verificar cada timeslot
    for t in range(num_timeslots):
        # Extrair posições de todos os UAVs neste timeslot
        positions = []
        for uav in range(num_uavs):
            idx_x = t * num_uavs * 2 + uav * 2
            idx_y = t * num_uavs * 2 + uav * 2 + 1
            x = individual[idx_x]
            y = individual[idx_y]
            positions.append(np.array([x, y]))
        
        # Verificar colisões entre todos os pares de UAVs neste timeslot
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                distance = np.linalg.norm(positions[i] - positions[j])
                if distance < min_distance:
                    return True  # PARA IMEDIATAMENTE na primeira colisão
    
    return False  # Nenhuma colisão encontrada

def evaluate_individual(individual, num_uavs, num_timeslots, jammer_position):
    # Verificar se há pelo menos uma colisão
    if has_collision(individual, num_uavs, num_timeslots):
        return (0.0,)  # FITNESS 0 imediatamente
    
    # Se não há colisões, calcular o fitness normalmente
    alpha, beta = 1.0, 1.0
    fitness_por_timeslot = []

    for t in range(num_timeslots):
        positions = []
        angles = []
        for i in range(num_uavs):
            idx = t * num_uavs * 2 + i * 2
            x = individual[idx]
            y = individual[idx + 1]
            
            # Calcular ângulo dinamicamente
            angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
            positions.append(np.array([x, y]))
            angles.append(angle)

        # Calcular matriz de comunicação
        comm_matrix, _ = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)

        # Avaliar grafo
        G = nx.DiGraph()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])

        # Encontrar links usados através dos caminhos mínimos
        links_usados = set()
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            links_usados.add((u, v))
                            links_usados.add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Cálculo do fitness usando apenas links usados
        capacidades_usadas = [comm_matrix[u][v] for u, v in links_usados if u < num_uavs and v < num_uavs]
        if capacidades_usadas:
            C_media_total = np.mean(capacidades_usadas)
            C_min_total = min(capacidades_usadas)
        else:
            C_media_total = 0
            C_min_total = 0
        
        # Fitness para este timeslot
        fitness_timeslot = (C_media_total ** alpha) * (C_min_total ** beta)
        fitness_por_timeslot.append(fitness_timeslot)

    # Calcular o fitness total como o produto dos fitness de cada timeslot
    total_fitness = np.prod(fitness_por_timeslot) if fitness_por_timeslot else 0
    return (total_fitness,)

def mutate_individual(individual, min_x, max_x, min_y, max_y, mutation_rate, num_uavs, num_timeslots, epoch, timeslot_length, epoch_total_length):
    for uav in range(num_uavs):
        if random.random() < mutation_rate:
            # Extrair posições iniciais
            start_x = individual[uav * 2]
            start_y = individual[uav * 2 + 1]
            
            # Nova posição final
            new_final_x = random.uniform(epoch * epoch_total_length + epoch_total_length - timeslot_length, 
                                        epoch * epoch_total_length + epoch_total_length)
            new_final_y = random.uniform(min_y, max_y)
            
            # Atualizar a posição final
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2] = new_final_x
            individual[(num_timeslots - 1) * num_uavs * 2 + uav * 2 + 1] = new_final_y
            
            # Recalcular posições intermediárias (t=1 até num_timeslots-1)
            for t in range(1, num_timeslots):
                alpha = t / (num_timeslots - 1) if num_timeslots > 1 else 0
                x = start_x + alpha * (new_final_x - start_x)
                y = start_y + alpha * (new_final_y - start_y)
                
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                individual[idx_x] = x
                individual[idx_y] = y
    
    return individual,

def custom_crossover(ind1, ind2, num_uavs):
    num_timeslots = len(ind1) // (num_uavs * 2)
    
    # Trocar posições de UAVs inteiros (exceto a posição inicial t=0)
    for uav in range(num_uavs):
        if random.random() < 0.5:
            for t in range(1, num_timeslots):  # Começar de t=1
                idx_x = t * num_uavs * 2 + uav * 2
                idx_y = t * num_uavs * 2 + uav * 2 + 1
                
                # Trocar x,y para todos os timeslots deste UAV (exceto t=0)
                ind1[idx_x], ind2[idx_x] = ind2[idx_x], ind1[idx_x]
                ind1[idx_y], ind2[idx_y] = ind2[idx_y], ind1[idx_y]
    
    return ind1, ind2

# Configuração do DEAP atualizada
def setup_deap(num_uavs, num_timeslots, timeslot_length, epoch, min_y, max_y, crossover_rate, mutation_rate, initial_positions, previous_best_solution=None, jammer_position=None, epoch_total_length=300):
    toolbox = base.Toolbox()
    
    # Registrar funções
    toolbox.register("individual", create_individual, 
                     num_uavs=num_uavs, 
                     num_timeslots=num_timeslots, 
                     timeslot_length=timeslot_length, 
                     epoch=epoch, 
                     min_y=min_y, 
                     max_y=max_y,
                     epoch_total_length=epoch_total_length,  # ← ADICIONAR
                     previous_best_solution=previous_best_solution,
                     initial_positions=initial_positions,
                     jammer_position=jammer_position)  # Passar a posição do jammer aqui
    
    # O restante do código permanece o mesmo...

    
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("evaluate", evaluate_individual, num_uavs=num_uavs, num_timeslots=num_timeslots, jammer_position=jammer_position)
    
    # Usar partial para fixar o argumento num_uavs na função custom_crossover
    toolbox.register("mate", partial(custom_crossover, num_uavs=num_uavs))
    
    min_x = epoch * num_timeslots * timeslot_length
    max_x = (epoch * num_timeslots + num_timeslots) * timeslot_length
    
    toolbox.register("mutate", mutate_individual, 
                 min_x=min_x, 
                 max_x=max_x, 
                 min_y=min_y, 
                 max_y=max_y, 
                 mutation_rate=mutation_rate,
                 num_uavs=num_uavs,
                 num_timeslots=num_timeslots,
                 epoch=epoch,
                 timeslot_length=timeslot_length,
                 epoch_total_length=epoch_total_length)  # ← ADICIONAR
    
    toolbox.register("select", tools.selTournament, tournsize=3)  # Seleção por torneio
    
    return toolbox

def genetic_algorithm(num_uavs, num_timeslots, timeslot_length, population_size, generations, crossover_rate, mutation_rate, epoch, initial_positions, previous_best_solution=None, jammer_position=None, min_y=0.0, max_y=5.0, epoch_total_length=300):
    # Configurar o DEAP
    toolbox = setup_deap(
        num_uavs=num_uavs,
        num_timeslots=num_timeslots,
        timeslot_length=timeslot_length,
        epoch=epoch,
        min_y=min_y,
        max_y=max_y,
        crossover_rate=crossover_rate,
        mutation_rate=mutation_rate,
        initial_positions=initial_positions,
        previous_best_solution=previous_best_solution,
        jammer_position=jammer_position,
        epoch_total_length=epoch_total_length  # ← ADICIONAR
    )

    
    # Criar população inicial
    population = toolbox.population(n=population_size)
    
    # Avaliar a população inicial
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit
    
    # Configurar estatísticas para impressão
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("std", np.std)
    stats.register("min", np.min)
    stats.register("max", np.max)
    
    # Listas para armazenar os dados de cada geração
    gen_list = []
    avg_list = []
    std_list = []
    min_list = []
    max_list = []
    
    # Executar o algoritmo genético com eaSimple
    for gen in range(generations):
        # Avançar uma geração
        algorithms.eaSimple(
            population, 
            toolbox, 
            cxpb=crossover_rate,  # Probabilidade de cruzamento
            mutpb=mutation_rate,  # Probabilidade de mutação
            ngen=1,               # Apenas uma geração por iteração
            stats=stats,          # Estatísticas para impressão
            verbose=False         # Desativar impressão da tabela para cada geração
        )
        
        # Coletar os dados da geração atual
        record = stats.compile(population)
        gen_list.append(gen)
        avg_list.append(record["avg"])
        std_list.append(record["std"])
        min_list.append(record["min"])
        max_list.append(record["max"])
        
        # Escrever os valores no arquivo
        #write_fitness_values(epoch, gen, record["avg"], record["max"], record["min"], record["std"])
    
    # Retornar o melhor indivíduo
    best_individual = tools.selBest(population, k=1)[0]
    return best_individual

# Função para gerar posições iniciais dos UAVs
def generate_initial_positions(num_uavs, min_y, max_y, timeslot_length, manual=False, manual_positions=None):
    if manual and manual_positions is not None:
        return manual_positions  # Usa as posições fornecidas

    positions = []
    max_attempts = 1000  # para evitar loops infinitos

    for _ in range(num_uavs):
        attempts = 0
        while True:
            y = random.uniform(min_y, max_y)
            x = random.uniform(0, timeslot_length)  # entre -timeslot_length e 0
            
            candidate = (x, y)
            
            # Verifica se está longe o suficiente das outras posições já geradas
            if all(np.linalg.norm(np.array(candidate) - np.array(pos)) >= MINDIST for pos in positions):
                positions.append(candidate)
                break
            
            attempts += 1
            if attempts >= max_attempts:
                # Se não conseguir, aceita a posição mesmo assim para evitar bloqueio
                positions.append(candidate)
                break
                
    return positions

def save_best_solution_to_file(best_solution, initial_positions, filename="best_solution_epoch.txt"):
    with open(filename, "a") as file:
        # Escrever apenas a melhor solução (que já inclui tudo)
        individual_str = ' '.join([f"{best_solution[i]:.2f}" for i in range(len(best_solution))])
        file.write(f"{individual_str}\n \n")

def write_fitness_values(epoch, gen, avg, max_val, min_val, std, filename="fitness_values.txt"):
    
    with open(filename, "a") as file:
        if gen == 0:  # Escrever o cabeçalho no início de cada epoch
            file.write(f"=== Epoch {epoch + 1} ===\n")
            file.write("gen\tavg\tmax\tmin\tstd\n")
        file.write(f"{gen}\t{avg:.4f}\t{max_val:.4f}\t{min_val:.4f}\t{std:.4f}\n")

# Função principal atualizada
def simulate_uavs_with_ga(num_epochs, num_timeslots, timeslot_length, num_uavs, population_size=50, generations=50, crossover_rate=0.8, mutation_rate=0.15, manual_initial_positions=None, jammer_position=None, min_y=0.0, max_y=10.0, epoch_total_length=300):
    # Gerar posições iniciais dos UAVs
    initial_positions = generate_initial_positions(
        num_uavs, min_y, max_y, timeslot_length,
        manual=manual_initial_positions is not None,
        manual_positions=manual_initial_positions
    )

    previous_best_solution = None
    
    for epoch in range(num_epochs):
        # Executar o algoritmo genético
        best_solution = genetic_algorithm(
            num_uavs=num_uavs,
            num_timeslots=num_timeslots,
            timeslot_length=timeslot_length,
            population_size=population_size,
            generations=generations,
            crossover_rate=crossover_rate,
            mutation_rate=mutation_rate,
            epoch=epoch,
            initial_positions=initial_positions,
            previous_best_solution=previous_best_solution,
            jammer_position=jammer_position,  # Passar a posição do jammer aqui
            min_y=min_y,
            max_y=max_y,
            epoch_total_length=epoch_total_length  # ← ADICIONAR
        )

        # O restante do código permanece o mesmo...


        # Salvar a melhor solução em um arquivo de texto
        save_best_solution_to_file(best_solution, initial_positions)
        
        all_min_capacities, all_interference_matrices, avg_min_capacity, avg_fitness = print_communication_values_per_timeslot(best_solution, num_uavs, num_timeslots, jammer_position)

        # Guardar a melhor solução para a próxima epoch


        # # Calcular e imprimir a coerência dos valores
        # best_fitness = best_solution.fitness.values[0]
        # recalculated_fitness = evaluate_individual(best_solution, num_uavs, num_timeslots, jammer_position)[0]
        # # Ler o último valor máximo do fitness_values.txt
        # with open("fitness_values.txt", "r") as file:
        #     lines = file.readlines()
        #     last_max_fitness = float(lines[-1].split("\t")[2])  # Último max na última linha
        # # Comparar os valores
        # print(f"Fitness da melhor solução: {best_fitness:.4f}")
        # print(f"Fitness recalculado: {recalculated_fitness:.4f}")
        # print(f"Último max no arquivo: {last_max_fitness:.4f}")
        # print(f"São iguais? {'✅' if abs(best_fitness - last_max_fitness) < 1 else '❌'}")
        # # Guardar a melhor solução para a próxima epoch
        # previous_best_solution = best_solution



        previous_best_solution = best_solution

        return best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity

# %%
posicoes_manuais1 = [
    (20.0, 20.0),   # UAV 1
    (20.0, 40.0),   # UAV 2 (60m de distância do UAV1)
    (40.0, 20.0),   # UAV 3 (60m de distância do UAV1)
    (40.0, 40.0)    # UAV 4 (60m de distância dos outros)
]

# Lista de posições do jammer
jammer_positions = [
    np.array([0, 500]),
    np.array([200, 500]),
    np.array([400, 500]),
    np.array([600, 500]),
    np.array([800, 500]),
    np.array([1000, 500]),
    np.array([0, 30]),
    np.array([1000, 30]),
]

# Lista de configurações do GA (pop_size, generations)
ga_configs = [
    (50, 50),
    (100, 100),
    (200, 200),
    (500, 500),

]

# Parâmetros fixos
NUM_EPOCHS = 1
NUM_TIMESLOTS = 6
TIMESLOT_LENGTH = 60
EPOCH_TOTAL_LENGTH = 120

# Guardar os resultados
resultados = []

for jammer_pos in jammer_positions:
    for pop_size, generations in ga_configs:
        best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capac
 'population_size': 200, 'generations': 200, 'best_solution': [20.0, 20.0, 20.0, 40.0, 40.0, 20.0, 40.0, 40.0, 34.8169259234117, 23.883674082548193, 36.186278424947915, 43.842559981764474, 54.04735459724984, 16.06052786012649, 54.91485310880657, 36.38703988148601, 49.633851846823404, 27.767348165096386, 52.37255684989584, 47.68511996352895, 68.09470919449969, 12.121055720252986, 69.82970621761314, 32.77407976297202, 64.4507777702351, 31.651022247644583, 68.55883527484374, 51.527679945293414, 82.14206379174952, 8.18158358037948, 84.7445593264197, 29.161119644458033, 79.26770369364681, 35.53469633019277, 84.74511369979167, 55.37023992705789, 96.18941838899937, 4.242111440505971, 99.65941243522627, 25.54815952594404, 94.08462961705851, 39.41837041274097, 100.93139212473959, 59.21279990882236, 110.2367729862492, 0.3026393006324639, 114.57426554403284, 21.93519940743005], 'avg_min_capacity': np.float64(16433.341335042347)}
# {'jammer_position': [1000, 30], 'population_size': 500, 'generations': 500, 'best_solution': [20.0, 20.0, 20.0, 40.0, 40.0, 20.0, 40.0, 40.0, 31.798851138142215, 23.494844832705997, 33.10029907608087, 43.57917274783282, 50.5224358012539, 16.110878309896243, 52.261489391992896, 37.60148980281311, 43.59770227628443, 26.989689665411994, 46.200598152161746, 47.158345495665635, 61.0448716025078, 12.22175661979249, 64.52297878398579, 35.202979605626226, 55.39655341442664, 30.484534498117988, 59.30089722824261, 50.73751824349846, 71.5673074037617, 8.332634929688735, 76.78446817597867, 32.80446940843934, 67.19540455256886, 33.97937933082399, 72.40119630432349, 54.31669099133127, 82.0897432050156, 4.443513239584979, 89.04595756797158, 30.40595921125245, 78.99425569071107, 37.47422416352998, 85.50149538040435, 57.89586373916409, 92.6121790062695, 0.5543915494812239, 101.30744695996447, 28.007449014065568], 'avg_min_capacity': np.float64(15844.215090377682)}

# %%
# Posições que respeitam MINDIST = 5 metros
posicoes_manuais1 = [
    (20.0, 20.0),   # UAV 1
    (20.0, 80.0),   # UAV 2 (60m de distância do UAV1)
    (80.0, 20.0),   # UAV 3 (60m de distância do UAV1)
    (80.0, 80.0)    # UAV 4 (60m de distância dos outros)
]

# Executar simulação
best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity = simulate_uavs_with_ga(
    num_epochs=1, 
    num_timeslots=6, 
    timeslot_length=100, 
    num_uavs=NUM_UAVS,
    population_size=500,
    generations=500,
    manual_initial_positions=posicoes_manuais1,
    jammer_position=np.array([0,500]),
    min_y=0.0,
    max_y=100.0,
    epoch_total_length=200
)

print("Posições iniciais usadas:", initial_positions)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 10
#       2 posicoes_manuais1 = [
#       3     (20.0, 20.0),   # UAV 1
#       4     (20.0, 80.0),   # UAV 2 (60m de distância do UAV1)
#       5     (80.0, 20.0),   # UAV 3 (60m de distância do UAV1)
#       6     (80.0, 80.0)    # UAV 4 (60m de distância dos outros)
#       7 ]
#       9 # Executar simulação
# ---> 10 best_solution, initial_positions, jammer_position, all_min_capacities, all_interference_matrices, avg_min_capacity = simulate_uavs_with_ga(
#      11     num_epochs=1,
#      12     num_timeslots=6,
#      13     timeslot_length=100,
#      14     num_uavs=NUM_UAVS,
#      15     population_size=500,
#      16     generations=500,
#      17     manual_initial_positions=posicoes_manuais1,
#      18     jammer_position=np.array([0,500]),
#      19     min_y=0.0,
#      20     max_y=100.0,
#      21     epoch_total_length=200
#      22 )
#      24 print("Posições iniciais usadas:", initial_positions)
#
# Cell In[1], line 498, in simulate_uavs_with_ga(num_epochs, num_timeslots, timeslot_length, num_uavs, population_size, generations, crossover_rate, mutation_rate, manual_initial_positions, jammer_position, min_y, max_y, epoch_total_length)
#     494 previous_best_solution = None
#     496 for epoch in range(num_epochs):
#     497     # Executar o algoritmo genético
# --> 498     best_solution = genetic_algorithm(
#     499         num_uavs=num_uavs,
#     500         num_timeslots=num_timeslots,
#     501         timeslot_length=timeslot_length,
#     502         population_size=population_size,
#     503         generations=generations,
#     504         crossover_rate=crossover_rate,
#     505         mutation_rate=mutation_rate,
#     506         epoch=epoch,
#     507         initial_positions=initial_positions,
#     508         previous_best_solution=previous_best_solution,
#     509         jammer_position=jammer_position,  # Passar a posição do jammer aqui
#     510         min_y=min_y,
#     511         max_y=max_y,
#     512         epoch_total_length=epoch_total_length  # ← ADICIONAR
#     513     )
#     515     # O restante do código permanece o mesmo...
#     516
#     517
#     518     # Salvar a melhor solução em um arquivo de texto
#     519     save_best_solution_to_file(best_solution, initial_positions)
#
# Cell In[1], line 417, in genetic_algorithm(num_uavs, num_timeslots, timeslot_length, population_size, generations, crossover_rate, mutation_rate, epoch, initial_positions, previous_best_solution, jammer_position, min_y, max_y, epoch_total_length)
#     414 # Executar o algoritmo genético com eaSimple
#     415 for gen in range(generations):
#     416     # Avançar uma geração
# --> 417     algorithms.eaSimple(
#     418         population,
#     419         toolbox,
#     420         cxpb=crossover_rate,  # Probabilidade de cruzamento
#     421         mutpb=mutation_rate,  # Probabilidade de mutação
#     422         ngen=1,               # Apenas uma geração por iteração
#     423         stats=stats,          # Estatísticas para impressão
#     424         verbose=False         # Desativar impressão da tabela para cada geração
#     425     )
#     427     # Coletar os dados da geração atual
#     428     record = stats.compile(population)
#
# File d:\Desktop\repo\gym\gym_GA_env\Lib\site-packages\deap\algorithms.py:173, in eaSimple(population, toolbox, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     171 invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     172 fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
# --> 173 for ind, fit in zip(invalid_ind, fitnesses):
#     174     ind.fitness.values = fit
#     176 # Update the hall of fame with the generated individuals
#
# Cell In[1], line 242, in evaluate_individual(individual, num_uavs, num_timeslots, jammer_position)
#     239     angles.append(angle)
#     241 # Calcular matriz de comunicação
# --> 242 comm_matrix, _ = calculate_communication_capacity(angles, [1.0] * num_uavs, positions, jammer_position)
#     244 # Avaliar grafo
#     245 G = nx.DiGraph()
#
# Cell In[1], line 147, in calculate_communication_capacity(antenna_angles, alignments, positions, jammer_position)
#     143 dir_jammer_to_uav = np.degrees(np.arctan2(dy_jam, dx_jam)) % 360
#     145 G_jammer_i = realistic_antenna_gain(dir_jammer_to_uav, null_dir_i)
# --> 147 dist_jammer_i = np.linalg.norm(positions[i] - jammer_position)
#     148 P_interf_dBm_i = interference_from_jammer(P_INTERFERENCE_DBM, G_jammer_i, lambda_0, dist_jammer_i)
#     150 interference_matrix[i, :] = P_interf_dBm_i
#
# File d:\Desktop\repo\gym\gym_GA_env\Lib\site-packages\numpy\linalg\linalg.py:2552, in norm(x, ord, axis, keepdims)
#    2550     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2551 else:
# -> 2552     sqnorm = x.dot(x)
#    2553 ret = sqrt(sqnorm)
#    2554 if keepdims:
#
# KeyboardInterrupt:

# %%
def analisar_comunicacoes_detalhado(filename, num_uavs, num_timeslots, jammer_position):
    def parse_solution_file(filename):
        with open(filename, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        solutions = []
        current_solution = []
        for line in lines:
            if line.startswith('==='):  # Nova época
                if current_solution:
                    solutions.append(current_solution)
                    current_solution = []
            else:
                current_solution.extend(map(float, line.split()))
        if current_solution:
            solutions.append(current_solution)
        return solutions

    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # Processar arquivo de saída
    solucoes = parse_solution_file(filename)
    
    resultados = []
    for idx, solucao in enumerate(solucoes):
        print(f"\nAnálise para Época {idx+1}:")
        
        # 🚨 VERIFICAR COLISÕES PRIMEIRO (IGUAL AO evaluate_individual)
        tem_colisoes = has_collision(solucao, num_uavs, num_timeslots)
        print(f"🔍 Verificação de colisões: {'❌ TEM COLISÕES' if tem_colisoes else '✅ SEM COLISÕES'}")
        
        if tem_colisoes:
            print(f"🚨 SOLUÇÃO COM COLISÕES DETECTADA!")
            print(f"   Fitness = 0.0 (igual ao evaluate_individual)")
            print(f"   Não será feita análise detalhada.")
            print("="*50)
            return [(0.0, "Solução com colisões")]
        
        # Se não há colisões, continuar com a análise normal
        print(f"✅ Solução válida - prosseguindo com análise detalhada...")
        
        # Lista para armazenar todos os C_média_total e C_min_total do epoch
        todos_c_media = []
        todos_c_min = []
        
        # Recriar a solução para cada timeslot
        for t in range(num_timeslots):
            print(f"\nTimeslot {t+1}:")
            positions = []
            angles = []
            
            for i in range(num_uavs):
                idx_pos = t * num_uavs * 2 + i * 2  # MUDANÇA: *2, pois só temos x e y
                x, y = solucao[idx_pos:idx_pos+2]
                positions.append(np.array([x, y]))
                
                # Calcular ângulo dinamicamente
                angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
                angles.append(angle)
            
            # Calcular matriz de comunicação
            comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
            
            # Gerar métricas detalhadas
            metricas = avaliar_grafo(comm_matrix)
            
            # Exibir resultados
            print("\nMatriz de Comunicação (bps):")
            print(np.round(comm_matrix, 2))
            
            print("\nResumo de Capacidades:")
            print(f"- Capacidades: {metricas['capacidades']}")
            print(f"- Média: {np.mean(metricas['capacidades']):.2f} bps")
            print(f"- Mínima: {min(metricas['capacidades']):.2f} bps")
            print(f"- Máxima: {max(metricas['capacidades']):.2f} bps")
            
            print("\nCaminhos Críticos:")
            for (i,j), data in metricas['caminhos_minimos'].items():
                print(f"UAV {i} → UAV {j}: {data['path']} (Capacidade: {data['capacidade']:.2f} bps)")
            
            print("\nBottlenecks por UAV:")
            for uav, cap in metricas['bottlenecks'].items():
                print(f"UAV {uav}: {cap:.2f} bps")
            
            print(f"\nGrafo é fortemente conexo? {'Sim' if metricas['conectividade'] else 'Não'}")
            
            print("\nLinks Usados:")
            for u, v in metricas['links_usados']:
                print(f"{u} ↔ {v}")
            
            print("\nLinks Não Usados:")
            for u, v in metricas['links_nao_usados']:
                print(f"{u} ↔ {v}")
            
            # Cálculo do fitness usando apenas links usados
            capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0
            
            # Adicionar às listas do epoch
            todos_c_media.append(C_media_total)
            todos_c_min.append(C_min_total)
            
            print(f"\nCálculo do Fitness para Timeslot {t+1}:")
            print(f"Capacidades Usadas: {capacidades_usadas}")
            print(f"C_média_total = {C_media_total:.2f} bps")
            print(f"C_min_total = {C_min_total:.2f} bps")
            
            resultados.append({
                'epoch': idx+1,
                'timeslot': t+1,
                'metricas': metricas,
                'C_media_total': C_media_total,
                'C_min_total': C_min_total
            })
        
        # ✅ CORREÇÃO: Calcular fitness de cada timeslot e depois fazer a média (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness_por_timeslot = []
        
        for i in range(len(todos_c_media)):
            C_media = todos_c_media[i]
            C_min = todos_c_min[i]
            fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
            fitness_por_timeslot.append(fitness_timeslot)
        
        # Fitness médio do epoch (IGUAL AO evaluate_individual)
        fitness_epoch_media = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular o fitness total do epoch como o produto dos fitness de cada timeslot
        fitness_epoch_produto = np.prod(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular também as médias para informação
        media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
        media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
        
        print(f"\n" + "="*50)
        print(f"RESUMO DO EPOCH {idx+1}:")
        print(f"Todos os C_média_total: {[f'{x:.2f}' for x in todos_c_media]}")
        print(f"Todos os C_min_total: {[f'{x:.2f}' for x in todos_c_min]}")
        print(f"Fitness por timeslot: {[f'{x:.4f}' for x in fitness_por_timeslot]}")
        print(f"Média dos C_média_total: {media_c_media_epoch:.2f} bps")
        print(f"Média dos C_min_total: {media_c_min_epoch:.2f} bps")
        print(f"🎯 Fitness do Epoch (Média) = {fitness_epoch_media:.4f}")
        print(f"🎯 Fitness do Epoch (Produto) = {fitness_epoch_produto:.4f}")
        print(f"✅ Agora deve bater com o valor do gráfico!")
        print("="*50)
    
    return resultados

# %%
resultados = analisar_comunicacoes_detalhado(
    filename="best_solution_epoch.txt",
    num_uavs=4,  # ou o número correto de UAVs que você está usando
    num_timeslots=6,  # Confirmando que são 6 timeslots
    jammer_position=np.array([0,50])  # Posição do jammer
)
# Out:
# Análise para Época 1:
# 🔍 Verificação de colisões: ✅ SEM COLISÕES
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# Timeslot 1:
#
# Matriz de Comunicação (bps):
# [[0.0000e+00 7.0000e-02 8.4100e+00 1.8100e+00]
#  [7.0000e-02 0.0000e+00 1.8100e+00 8.4100e+00]
#  [1.6770e+01 3.6100e+00 0.0000e+00 1.8583e+02]
#  [3.6100e+00 1.6770e+01 1.8583e+02 0.0000e+00]]
#
# Resumo de Capacidades:
# - Capacidades: [0.07086531047780278, 8.407395792444083, 1.8105166093817286, 0.07086531047780278, 1.8105166093817286, 8.407395792444083, 16.774957554581317, 3.6124554512549087, 185.83266140507243, 3.6124554512549087, 16.774957554581317, 185.83266140507243]
# - Média: 36.08 bps
# - Mínima: 0.07 bps
# - Máxima: 185.83 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 2, 3, 1] (Capacidade: 8.41 bps)
# UAV 0 → UAV 2: [0, 2] (Capacidade: 8.41 bps)
# UAV 0 → UAV 3: [0, 2, 3] (Capacidade: 8.41 bps)
# UAV 1 → UAV 0: [1, 3, 2, 0] (Capacidade: 8.41 bps)
# UAV 1 → UAV 2: [1, 3, 2] (Capacidade: 8.41 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 8.41 bps)
# UAV 2 → UAV 0: [2, 0] (Capacidade: 16.77 bps)
# UAV 2 → UAV 1: [2, 3, 1] (Capacidade: 16.77 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 185.83 bps)
# UAV 3 → UAV 0: [3, 2, 0] (Capacidade: 16.77 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 16.77 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 185.83 bps)
#
# Bottlenecks por UAV:
# UAV 0: 0.07 bps
# UAV 1: 0.07 bps
# UAV 2: 3.61 bps
# UAV 3: 3.61 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 3 ↔ 1
# 2 ↔ 0
# 2 ↔ 3
# 0 ↔ 2
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 1
# 1 ↔ 2
# 2 ↔ 1
# 0 ↔ 3
# 3 ↔ 0
# 1 ↔ 0
#
# Cálculo do Fitness para Timeslot 1:
# Capacidades Usadas: [16.774957554581317, 16.774957554581317, 185.83266140507243, 8.407395792444083, 185.83266140507243, 8.407395792444083]
# C_média_total = 70.34 bps
# C_min_total = 8.41 bps
#
# Timeslot 2:
#
# Matriz de Comunicação (bps):
# [[  0.    62.06   4.39  25.38]
#  [ 62.06   0.    19.53  31.16]
#  [  6.96  30.95   0.   640.51]
#  [ 31.95  39.22 508.77   0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [62.06091870323886, 4.390855327998352, 25.38040971388361, 62.06091870323886, 19.530688260908683, 31.15542854535419, 6.959036405175312, 30.954048744157316, 640.5065589062269, 31.95203911294905, 39.22235522902988, 508.7736056752336]
# - Média: 121.91 bps
# - Mínima: 4.39 bps
# - Máxima: 640.51 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 62.06 bps)
# UAV 0 → UAV 2: [0, 3, 2] (Capacidade: 25.38 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 25.38 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 62.06 bps)
# UAV 1 → UAV 2: [1, 3, 2] (Capacidade: 31.16 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 31.16 bps)
# UAV 2 → UAV 0: [2, 3, 0] (Capacidade: 31.95 bps)
# UAV 2 → UAV 1: [2, 3, 1] (Capacidade: 39.22 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 640.51 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 31.95 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 39.22 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 508.77 bps)
#
# Bottlenecks por UAV:
# UAV 0: 4.39 bps
# UAV 1: 19.53 bps
# UAV 2: 6.96 bps
# UAV 3: 31.95 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 3 ↔ 1
# 0 ↔ 3
# 3 ↔ 0
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 0 ↔ 2
# 1 ↔ 2
# 2 ↔ 0
# 2 ↔ 1
#
# Cálculo do Fitness para Timeslot 2:
# Capacidades Usadas: [62.06091870323886, 39.22235522902988, 25.38040971388361, 31.95203911294905, 640.5065589062269, 62.06091870323886, 508.7736056752336, 31.15542854535419]
# C_média_total = 175.14 bps
# C_min_total = 25.38 bps
#
# Timeslot 3:
#
# Matriz de Comunicação (bps):
# [[   0.    547.49   35.38   36.47]
#  [ 547.49    0.     90.38  168.7 ]
#  [  44.53  113.79    0.   1258.97]
#  [  45.91  212.38 1258.97    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [547.4857680603575, 35.37531440473707, 36.46993490449956, 547.4857680603575, 90.3835053689902, 168.69981875697943, 44.5348751918811, 113.78604556616187, 1258.9684104110584, 45.91292030329101, 212.38032803785327, 1258.9684104110584]
# - Média: 363.37 bps
# - Mínima: 35.38 bps
# - Máxima: 1258.97 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 547.49 bps)
# UAV 0 → UAV 2: [0, 1, 3, 2] (Capacidade: 168.70 bps)
# UAV 0 → UAV 3: [0, 1, 3] (Capacidade: 168.70 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 547.49 bps)
# UAV 1 → UAV 2: [1, 3, 2] (Capacidade: 168.70 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 168.70 bps)
# UAV 2 → UAV 0: [2, 3, 1, 0] (Capacidade: 212.38 bps)
# UAV 2 → UAV 1: [2, 3, 1] (Capacidade: 212.38 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 1258.97 bps)
# UAV 3 → UAV 0: [3, 1, 0] (Capacidade: 212.38 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 212.38 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 1258.97 bps)
#
# Bottlenecks por UAV:
# UAV 0: 35.38 bps
# UAV 1: 90.38 bps
# UAV 2: 44.53 bps
# UAV 3: 45.91 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 3 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 1 ↔ 2
# 2 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
#
# Cálculo do Fitness para Timeslot 3:
# Capacidades Usadas: [547.4857680603575, 212.38032803785327, 1258.9684104110584, 547.4857680603575, 1258.9684104110584, 168.69981875697943]
# C_média_total = 665.66 bps
# C_min_total = 168.70 bps
#
# Timeslot 4:
#
# Matriz de Comunicação (bps):
# [[   0.   1569.54  388.18   31.73]
#  [1569.54    0.    291.14  973.68]
#  [ 388.18  291.14    0.   2116.09]
#  [  31.73  973.68 2116.09    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [1569.543500846668, 388.17504672205365, 31.733486881508767, 1569.543500846668, 291.14410682921755, 973.6831730773199, 388.17504672205365, 291.14410682921755, 2116.0907062297892, 31.733486881508767, 973.6831730773199, 2116.0907062297892]
# - Média: 895.06 bps
# - Mínima: 31.73 bps
# - Máxima: 2116.09 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 1569.54 bps)
# UAV 0 → UAV 2: [0, 1, 3, 2] (Capacidade: 973.68 bps)
# UAV 0 → UAV 3: [0, 1, 3] (Capacidade: 973.68 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 1569.54 bps)
# UAV 1 → UAV 2: [1, 3, 2] (Capacidade: 973.68 bps)
# UAV 1 → UAV 3: [1, 3] (Capacidade: 973.68 bps)
# UAV 2 → UAV 0: [2, 3, 1, 0] (Capacidade: 973.68 bps)
# UAV 2 → UAV 1: [2, 3, 1] (Capacidade: 973.68 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 2116.09 bps)
# UAV 3 → UAV 0: [3, 1, 0] (Capacidade: 973.68 bps)
# UAV 3 → UAV 1: [3, 1] (Capacidade: 973.68 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 2116.09 bps)
#
# Bottlenecks por UAV:
# UAV 0: 31.73 bps
# UAV 1: 291.14 bps
# UAV 2: 291.14 bps
# UAV 3: 31.73 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 3 ↔ 1
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
# 1 ↔ 3
#
# Links Não Usados:
# 1 ↔ 2
# 2 ↔ 1
# 0 ↔ 3
# 2 ↔ 0
# 3 ↔ 0
# 0 ↔ 2
#
# Cálculo do Fitness para Timeslot 4:
# Capacidades Usadas: [1569.543500846668, 973.6831730773199, 2116.0907062297892, 1569.543500846668, 2116.0907062297892, 973.6831730773199]
# C_média_total = 1553.11 bps
# C_min_total = 973.68 bps
#
# Timeslot 5:
#
# Matriz de Comunicação (bps):
# [[   0.   3180.87 1331.68 3377.56]
#  [3180.87    0.    567.5  1501.79]
#  [1331.68  567.5     0.   4219.82]
#  [3377.56 1501.79 4219.82    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [3180.8701146166386, 1331.6827906992887, 3377.5607007267663, 3180.8701146166386, 567.4969156554049, 1501.7897728798441, 1331.6827906992887, 567.4969156554049, 4219.817980522547, 3377.5607007267663, 1501.7897728798441, 4219.817980522547]
# - Média: 2363.20 bps
# - Mínima: 567.50 bps
# - Máxima: 4219.82 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 3180.87 bps)
# UAV 0 → UAV 2: [0, 3, 2] (Capacidade: 3377.56 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 3377.56 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 3180.87 bps)
# UAV 1 → UAV 2: [1, 0, 3, 2] (Capacidade: 3180.87 bps)
# UAV 1 → UAV 3: [1, 0, 3] (Capacidade: 3180.87 bps)
# UAV 2 → UAV 0: [2, 3, 0] (Capacidade: 3377.56 bps)
# UAV 2 → UAV 1: [2, 3, 0, 1] (Capacidade: 3180.87 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 4219.82 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 3377.56 bps)
# UAV 3 → UAV 1: [3, 0, 1] (Capacidade: 3180.87 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 4219.82 bps)
#
# Bottlenecks por UAV:
# UAV 0: 1331.68 bps
# UAV 1: 567.50 bps
# UAV 2: 567.50 bps
# UAV 3: 1501.79 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 0 ↔ 3
# 3 ↔ 0
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Links Não Usados:
# 1 ↔ 2
# 2 ↔ 1
# 3 ↔ 1
# 2 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Cálculo do Fitness para Timeslot 5:
# Capacidades Usadas: [3180.8701146166386, 3377.5607007267663, 3377.5607007267663, 4219.817980522547, 3180.8701146166386, 4219.817980522547]
# C_média_total = 3592.75 bps
# C_min_total = 3180.87 bps
#
# Timeslot 6:
#
# Matriz de Comunicação (bps):
# [[   0.   4357.34 1088.32 1954.3 ]
#  [4357.34    0.    575.49  978.91]
#  [1088.32  575.49    0.   6648.53]
#  [1954.3   978.91 6648.53    0.  ]]
#
# Resumo de Capacidades:
# - Capacidades: [4357.3414406488255, 1088.3164873869855, 1954.2960130246308, 4357.3414406488255, 575.4872838768771, 978.9082826609402, 1088.3164873869855, 575.4872838768771, 6648.532097428801, 1954.2960130246308, 978.9082826609402, 6648.532097428801]
# - Média: 2600.48 bps
# - Mínima: 575.49 bps
# - Máxima: 6648.53 bps
#
# Caminhos Críticos:
# UAV 0 → UAV 1: [0, 1] (Capacidade: 4357.34 bps)
# UAV 0 → UAV 2: [0, 3, 2] (Capacidade: 1954.30 bps)
# UAV 0 → UAV 3: [0, 3] (Capacidade: 1954.30 bps)
# UAV 1 → UAV 0: [1, 0] (Capacidade: 4357.34 bps)
# UAV 1 → UAV 2: [1, 0, 3, 2] (Capacidade: 1954.30 bps)
# UAV 1 → UAV 3: [1, 0, 3] (Capacidade: 1954.30 bps)
# UAV 2 → UAV 0: [2, 3, 0] (Capacidade: 1954.30 bps)
# UAV 2 → UAV 1: [2, 3, 0, 1] (Capacidade: 1954.30 bps)
# UAV 2 → UAV 3: [2, 3] (Capacidade: 6648.53 bps)
# UAV 3 → UAV 0: [3, 0] (Capacidade: 1954.30 bps)
# UAV 3 → UAV 1: [3, 0, 1] (Capacidade: 1954.30 bps)
# UAV 3 → UAV 2: [3, 2] (Capacidade: 6648.53 bps)
#
# Bottlenecks por UAV:
# UAV 0: 1088.32 bps
# UAV 1: 575.49 bps
# UAV 2: 575.49 bps
# UAV 3: 978.91 bps
#
# Grafo é fortemente conexo? Sim
#
# Links Usados:
# 0 ↔ 1
# 0 ↔ 3
# 3 ↔ 0
# 2 ↔ 3
# 1 ↔ 0
# 3 ↔ 2
#
# Links Não Usados:
# 1 ↔ 2
# 2 ↔ 1
# 3 ↔ 1
# 2 ↔ 0
# 0 ↔ 2
# 1 ↔ 3
#
# Cálculo do Fitness para Timeslot 6:
# Capacidades Usadas: [4357.3414406488255, 1954.2960130246308, 1954.2960130246308, 6648.532097428801, 4357.3414406488255, 6648.532097428801]
# C_média_total = 4320.06 bps
# C_min_total = 1954.30 bps
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['70.34', '175.14', '665.66', '1553.11', '3592.75', '4320.06']
# Todos os C_min_total: ['8.41', '25.38', '168.70', '973.68', '3180.87', '1954.30']
# Fitness por timeslot: ['591.3622', '4445.1003', '112297.5228', '1512232.9770', '11428069.8276', '8442669.2273']
# Média dos C_média_total: 1729.51 bps
# Média dos C_min_total: 1051.89 bps
# 🎯 Fitness do Epoch (Média) = 3583384.3362
# 🎯 Fitness do Epoch (Produto) = 43070181731910510435479605739520.0000
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================

# %% [markdown]
# # analisar

# %%
def analisar_comunicacoes_detalhado(filename, num_uavs, num_timeslots, jammer_position):
    def parse_solution_file(filename):
        with open(filename, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        solutions = []
        current_solution = []
        for line in lines:
            if line.startswith('==='):  # Nova época
                if current_solution:
                    solutions.append(current_solution)
                    current_solution = []
            else:
                current_solution.extend(map(float, line.split()))
        if current_solution:
            solutions.append(current_solution)
        return solutions

    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # Processar arquivo de saída
    solucoes = parse_solution_file(filename)
    
    resultados = []
    for idx, solucao in enumerate(solucoes):
        print(f"\nAnálise para Época {idx+1}:")
        
        # 🚨 VERIFICAR COLISÕES PRIMEIRO (IGUAL AO evaluate_individual)
        tem_colisoes = has_collision(solucao, num_uavs, num_timeslots)
        #print(f"🔍 Verificação de colisões: {'❌ TEM COLISÕES' if tem_colisoes else '✅ SEM COLISÕES'}")
        
        if tem_colisoes:
            #print(f"🚨 SOLUÇÃO COM COLISÕES DETECTADA!")
            #print(f"   Fitness = 0.0 (igual ao evaluate_individual)")
            #print(f"   Não será feita análise detalhada.")
            #print("="*50)
            return [(0.0, "Solução com colisões")]
        
        # Se não há colisões, continuar com a análise normal
        #print(f"✅ Solução válida - prosseguindo com análise detalhada...")
        
        # Lista para armazenar todos os C_média_total e C_min_total do epoch
        todos_c_media = []
        todos_c_min = []
        
        # Recriar a solução para cada timeslot
        for t in range(num_timeslots):
            #print(f"\nTimeslot {t+1}:")
            positions = []
            angles = []
            
            for i in range(num_uavs):
                idx_pos = t * num_uavs * 2 + i * 2  # MUDANÇA: *2, pois só temos x e y
                x, y = solucao[idx_pos:idx_pos+2]
                positions.append(np.array([x, y]))
                
                # Calcular ângulo dinamicamente
                angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
                angles.append(angle)
            
            # Calcular matriz de comunicação
            comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
            
            # Gerar métricas detalhadas
            metricas = avaliar_grafo(comm_matrix)
            
            # Exibir resultados
            # print("\nMatriz de Comunicação (bps):")
            # print(np.round(comm_matrix, 2))
            
            # print("\nResumo de Capacidades:")
            # print(f"- Capacidades: {metricas['capacidades']}")
            # print(f"- Média: {np.mean(metricas['capacidades']):.2f} bps")
            # print(f"- Mínima: {min(metricas['capacidades']):.2f} bps")
            # print(f"- Máxima: {max(metricas['capacidades']):.2f} bps")
            
            # print("\nCaminhos Críticos:")
            # for (i,j), data in metricas['caminhos_minimos'].items():
            #     print(f"UAV {i} → UAV {j}: {data['path']} (Capacidade: {data['capacidade']:.2f} bps)")
            
            # print("\nBottlenecks por UAV:")
            # for uav, cap in metricas['bottlenecks'].items():
            #     print(f"UAV {uav}: {cap:.2f} bps")
            
            # print(f"\nGrafo é fortemente conexo? {'Sim' if metricas['conectividade'] else 'Não'}")
            
            # print("\nLinks Usados:")
            # for u, v in metricas['links_usados']:
            #     print(f"{u} ↔ {v}")
            
            # print("\nLinks Não Usados:")
            # for u, v in metricas['links_nao_usados']:
            #     print(f"{u} ↔ {v}")
            
            # Cálculo do fitness usando apenas links usados
            capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0
            
            # Adicionar às listas do epoch
            todos_c_media.append(C_media_total)
            todos_c_min.append(C_min_total)
            
            # print(f"\nCálculo do Fitness para Timeslot {t+1}:")
            # print(f"Capacidades Usadas: {capacidades_usadas}")
            # print(f"C_média_total = {C_media_total:.2f} bps")
            # print(f"C_min_total = {C_min_total:.2f} bps")
            
            resultados.append({
                'epoch': idx+1,
                'timeslot': t+1,
                'metricas': metricas,
                'C_media_total': C_media_total,
                'C_min_total': C_min_total
            })
        
        # ✅ CORREÇÃO: Calcular fitness de cada timeslot e depois fazer a média (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness_por_timeslot = []
        
        for i in range(len(todos_c_media)):
            C_media = todos_c_media[i]
            C_min = todos_c_min[i]
            fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
            fitness_por_timeslot.append(fitness_timeslot)
        
        # Fitness médio do epoch (IGUAL AO evaluate_individual)
        fitness_epoch_media = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular o fitness total do epoch como o produto dos fitness de cada timeslot
        fitness_epoch_produto = np.prod(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular o fitness total do epoch como a soma dos fitness de cada timeslot
        fitness_epoch_soma = np.sum(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular também as médias para informação
        media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
        media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
        
        print(f"\n" + "="*50)
        print(f"RESUMO DO EPOCH {idx+1}:")
        print(f"Todos os C_média_total: {[f'{x:.2f}' for x in todos_c_media]}")
        print(f"Todos os C_min_total: {[f'{x:.2f}' for x in todos_c_min]}")
        print(f"Fitness por timeslot: {[f'{x:.4f}' for x in fitness_por_timeslot]}")
        print(f"Média dos C_média_total: {media_c_media_epoch:.2f} bps")
        print(f"Média dos C_min_total: {media_c_min_epoch:.2f} bps")
        print(f"🎯 Fitness do Epoch (Média) = {fitness_epoch_media:.4f}")
        print(f"🎯 Fitness do Epoch (Produto) = {fitness_epoch_produto:.4f}")
        print(f"🎯 Fitness do Epoch (Soma) = {fitness_epoch_soma:.4f}")
        print(f"✅ Agora deve bater com o valor do gráfico!")
        print("="*50)
    
    return resultados

# %%
resultados = analisar_comunicacoes_detalhado(
    filename="avgbest_solution_epoch.txt",
    num_uavs=4,  # ou o número correto de UAVs que você está usando
    num_timeslots=6,  # Confirmando que são 6 timeslots
    jammer_position=np.array([0,500])  # Posição do jammer
)
# Out:
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['11090.53', '9624.46', '7556.70', '5658.70', '4509.98', '5972.53']
# Todos os C_min_total: ['1219.27', '3767.66', '6818.89', '3772.76', '2767.01', '5571.65']
# Fitness por timeslot: ['13522349.0985', '36261727.5430', '51528318.4578', '21348952.4003', '12479175.5843', '33276849.3139']
# Média dos C_média_total: 7402.15 bps
# Média dos C_min_total: 3986.21 bps
# 🎯 Fitness do Epoch (CORRETO) = 28069562.0663
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================

# %% [markdown]
# # analisar 2

# %%
def analisar_comunicacoes_detalhado(filename, num_uavs, num_timeslots, jammer_position):
    def parse_solution_file(filename):
        with open(filename, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        solutions = []
        current_solution = []
        for line in lines:
            if line.startswith('==='):  # Nova época
                if current_solution:
                    solutions.append(current_solution)
                    current_solution = []
            else:
                current_solution.extend(map(float, line.split()))
        if current_solution:
            solutions.append(current_solution)
        return solutions

    def avaliar_grafo(comm_matrix):
        G = nx.DiGraph()
        
        # 1. Adicionar arestas bidirecionais com capacidades
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j and comm_matrix[i][j] > 0:
                    G.add_edge(i, j, capacity=comm_matrix[i][j])
        
        # 2. Cálculos de métricas
        metricas = {
            'capacidades': [],
            'caminhos_minimos': {},
            'bottlenecks': {},
            'conectividade': None,
            'links_usados': set(),
            'links_nao_usados': set()
        }
        
        # Preencher métricas
        for i in range(num_uavs):
            for j in range(num_uavs):
                if i != j:
                    # Calcular caminhos mínimos (1/capacity como peso)
                    try:
                        path = nx.shortest_path(G, source=i, target=j, weight=lambda u, v, d: 1/d['capacity'])
                        capacidade_min = min(G[u][v]['capacity'] for u, v in zip(path[:-1], path[1:]))
                        
                        metricas['caminhos_minimos'][(i,j)] = {
                            'path': path,
                            'capacidade': capacidade_min
                        }
                        
                        # Adicionar links usados
                        for u, v in zip(path[:-1], path[1:]):
                            metricas['links_usados'].add((u, v))
                            metricas['links_usados'].add((v, u))  # Adicionar a aresta reversa
                    except:
                        pass
        
        # Calcular bottlenecks para cada nó
        for node in G.nodes():
            metricas['bottlenecks'][node] = min(
                [d['capacity'] for _, _, d in G.edges(node, data=True)],
                default=0
            )
        
        # Verificar conectividade
        metricas['conectividade'] = nx.is_strongly_connected(G)
        
        # Coletar todas as capacidades
        metricas['capacidades'] = [d['capacity'] for _, _, d in G.edges(data=True)]
        
        # Identificar links não usados
        all_links = {(i, j) for i in range(num_uavs) for j in range(num_uavs) if i != j}
        metricas['links_nao_usados'] = all_links - metricas['links_usados']
        
        return metricas

    # Processar arquivo de saída
    solucoes = parse_solution_file(filename)
    
    resultados = []
    for idx, solucao in enumerate(solucoes):
        print(f"\nAnálise para Época {idx+1}:")
        
        # 🚨 VERIFICAR COLISÕES PRIMEIRO (IGUAL AO evaluate_individual)
        tem_colisoes = has_collision(solucao, num_uavs, num_timeslots)
        #print(f"🔍 Verificação de colisões: {'❌ TEM COLISÕES' if tem_colisoes else '✅ SEM COLISÕES'}")
        
        if tem_colisoes:
            print(f"🚨 SOLUÇÃO COM COLISÕES DETECTADA!")
            print(f"   Fitness = 0.0 (igual ao evaluate_individual)")
            print(f"   Não será feita análise detalhada.")
            print("="*50)
            # Retornar 4 valores válidos
            return [], 0.0, 0.0, 0.0

        
        # Se não há colisões, continuar com a análise normal
        print(f"✅ Solução válida - prosseguindo com análise detalhada...")
        
        # Lista para armazenar todos os C_média_total e C_min_total do epoch
        todos_c_media = []
        todos_c_min = []
        
        # Recriar a solução para cada timeslot
        for t in range(num_timeslots):
            #print(f"\nTimeslot {t+1}:")
            positions = []
            angles = []
            
            for i in range(num_uavs):
                idx_pos = t * num_uavs * 2 + i * 2  # MUDANÇA: *2, pois só temos x e y
                x, y = solucao[idx_pos:idx_pos+2]
                positions.append(np.array([x, y]))
                
                # Calcular ângulo dinamicamente
                angle = np.degrees(np.arctan2(jammer_position[1] - y, jammer_position[0] - x))
                angles.append(angle)
            
            # Calcular matriz de comunicação
            comm_matrix, _ = calculate_communication_capacity(angles, [1.0]*num_uavs, positions, jammer_position)
            
            # Gerar métricas detalhadas
            metricas = avaliar_grafo(comm_matrix)
            
            # Exibir resultados
            #print("\nMatriz de Comunicação (bps):")
            #print(np.round(comm_matrix, 2))
            
            #print("\nResumo de Capacidades:")
            #print(f"- Capacidades: {metricas['capacidades']}")
            #print(f"- Média: {np.mean(metricas['capacidades']):.2f} bps")
            #print(f"- Mínima: {min(metricas['capacidades']):.2f} bps")
            #print(f"- Máxima: {max(metricas['capacidades']):.2f} bps")
            
            #print("\nCaminhos Críticos:")
            #for (i,j), data in metricas['caminhos_minimos'].items():
                #print(f"UAV {i} → UAV {j}: {data['path']} (Capacidade: {data['capacidade']:.2f} bps)")
            
            #print("\nBottlenecks por UAV:")
            #for uav, cap in metricas['bottlenecks'].items():
                #print(f"UAV {uav}: {cap:.2f} bps")
            
            #print(f"\nGrafo é fortemente conexo? {'Sim' if metricas['conectividade'] else 'Não'}")
            
            #print("\nLinks Usados:")
            #for u, v in metricas['links_usados']:
                #print(f"{u} ↔ {v}")
            
            #print("\nLinks Não Usados:")
            #for u, v in metricas['links_nao_usados']:
                #print(f"{u} ↔ {v}")
            
            # Cálculo do fitness usando apenas links usados
            capacidades_usadas = [comm_matrix[u][v] for u, v in metricas['links_usados'] if u < num_uavs and v < num_uavs]
            if capacidades_usadas:
                C_media_total = np.mean(capacidades_usadas)
                C_min_total = min(capacidades_usadas)
            else:
                C_media_total = 0
                C_min_total = 0
            
            # Adicionar às listas do epoch
            todos_c_media.append(C_media_total)
            todos_c_min.append(C_min_total)
            
            #print(f"\nCálculo do Fitness para Timeslot {t+1}:")
            #print(f"Capacidades Usadas: {capacidades_usadas}")
            #print(f"C_média_total = {C_media_total:.2f} bps")
            #print(f"C_min_total = {C_min_total:.2f} bps")
            
            resultados.append({
                'epoch': idx+1,
                'timeslot': t+1,
                'metricas': metricas,
                'C_media_total': C_media_total,
                'C_min_total': C_min_total
            })
        
        # ✅ CORREÇÃO: Calcular fitness de cada timeslot e depois fazer a média (IGUAL AO evaluate_individual)
        alpha, beta = 1.0, 1.0
        fitness_por_timeslot = []
        
        for i in range(len(todos_c_media)):
            C_media = todos_c_media[i]
            C_min = todos_c_min[i]
            fitness_timeslot = (C_media ** alpha) * (C_min ** beta)
            fitness_por_timeslot.append(fitness_timeslot)
        
        # Fitness médio do epoch (IGUAL AO evaluate_individual)
        fitness_epoch = np.mean(fitness_por_timeslot) if fitness_por_timeslot else 0
        
        # Calcular também as médias para informação
        media_c_media_epoch = np.mean(todos_c_media) if todos_c_media else 0
        media_c_min_epoch = np.mean(todos_c_min) if todos_c_min else 0
        
        print(f"\n" + "="*50)
        print(f"RESUMO DO EPOCH {idx+1}:")
        print(f"Todos os C_média_total: {[f'{x:.2f}' for x in todos_c_media]}")
        print(f"Todos os C_min_total: {[f'{x:.2f}' for x in todos_c_min]}")
        print(f"Fitness por timeslot: {[f'{x:.4f}' for x in fitness_por_timeslot]}")
        print(f"Média dos C_média_total: {media_c_media_epoch:.2f} bps")
        print(f"Média dos C_min_total: {media_c_min_epoch:.2f} bps")
        print(f"🎯 Fitness do Epoch (CORRETO) = {fitness_epoch:.4f}")
        print(f"✅ Agora deve bater com o valor do gráfico!")
        print("="*50)
    
    return resultados, fitness_epoch, media_c_media_epoch, media_c_min_epoch

# %%
import os
import numpy as np
import tempfile
import traceback

# === Configurações ===
INPUT_FILE = "prodbest_solution_epoch.txt"
NUM_UAVS = 4
NUM_TIMESLOTS = 6

jammer_positions = [
    np.array([0, 500]),
    np.array([200, 500]),
    np.array([400, 500]),
    np.array([600, 500]),
    np.array([800, 500]),
    np.array([1000, 500]),
    np.array([0, 30]),
    np.array([1000, 30]),
]
# =====================

def parse_non_empty_lines(filename):
    with open(filename, "r", encoding="utf-8") as f:
        return [line.rstrip() for line in f if line.strip()]

def main():
    if not os.path.exists(INPUT_FILE):
        print(f"Ficheiro de entrada '{INPUT_FILE}' não encontrado.")
        return

    lines = parse_non_empty_lines(INPUT_FILE)
    total = len(lines)
    print(f"Linhas encontradas: {total}")

    for i, line in enumerate(lines):
        block_idx = i // 4
        jammer_pos = jammer_positions[block_idx % len(jammer_positions)]

        # 👇 imprimir linha antes da análise
        print(f"\n=== Linha {i+1}/{total} (bloco {block_idx}, jammer={jammer_pos.tolist()}) ===")
        print(line)

        tmp_name = None
        try:
            # criar ficheiro temporário com apenas esta linha
            with tempfile.NamedTemporaryFile(mode="w", delete=False, encoding="utf-8", suffix=".txt") as tmp:
                tmp_name = tmp.name
                tmp.write(line + "\n")

            # chamar a função como antes, passando o ficheiro
            resultados, fitness_epoch, media_c_media_epoch, media_c_min_epoch = analisar_comunicacoes_detalhado(
                filename=tmp_name,
                num_uavs=NUM_UAVS,
                num_timeslots=NUM_TIMESLOTS,
                jammer_position=jammer_pos
            )

            print(f"→ Fitness: {fitness_epoch:.4f}, Média C_media: {media_c_media_epoch:.2f}, Média C_min: {media_c_min_epoch:.2f}")

        except Exception as e:
            print(f"ERRO na linha {i} ({e})")
            traceback.print_exc()

        finally:
            # apagar ficheiro temporário
            if tmp_name and os.path.exists(tmp_name):
                os.remove(tmp_name)

if __name__ == "__main__":
    main()
# Out:
# Linhas encontradas: 32
#
# === Linha 1/32 (bloco 0, jammer=[0, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 29.61 18.06 31.86 39.35 53.36 22.60 55.63 43.03 39.21 16.11 43.73 38.71 66.72 25.20 71.25 46.06 48.82 14.17 55.59 38.06 80.08 27.79 86.88 49.09 58.42 12.22 67.45 37.41 93.43 30.39 102.51 52.11 68.03 10.28 79.32 36.77 106.79 32.99 118.14 55.14
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['11090.53', '9438.48', '7544.50', '6461.84', '6057.18', '6048.59']
# Todos os C_min_total: ['1219.27', '1279.63', '1913.96', '3304.58', '5201.88', '4461.41']
# Fitness por timeslot: ['13522349.0985', '12077781.6804', '14439896.5191', '21353676.1403', '31508744.4551', '26985221.8764']
# Média dos C_média_total: 7773.52 bps
# Média dos C_min_total: 2896.79 bps
# 🎯 Fitness do Epoch (CORRETO) = 19981278.2950
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 19981278.2950, Média C_media: 7773.52, Média C_min: 2896.79
#
# === Linha 2/32 (bloco 0, jammer=[0, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 29.19 22.42 32.78 42.46 50.59 21.88 52.94 42.36 38.39 24.84 45.57 44.92 61.18 23.75 65.89 44.72 47.58 27.26 58.35 47.38 71.78 25.63 78.83 47.08 56.78 29.68 71.14 49.84 82.37 27.50 91.77 49.44 65.97 32.09 83.92 52.30 92.96 29.38 104.72 51.80
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['11090.53', '10706.36', '10303.72', '9871.95', '9396.63', '8870.46']
# Todos os C_min_total: ['1219.27', '2045.71', '3010.12', '3979.80', '4835.71', '5499.53']
# Fitness por timeslot: ['13522349.0985', '21902121.5385', '31015462.9575', '39288381.8067', '45439327.6141', '48783332.0462']
# Média dos C_média_total: 10039.94 bps
# Média dos C_min_total: 3431.69 bps
# 🎯 Fitness do Epoch (CORRETO) = 33325162.5103
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 33325162.5103, Média C_media: 10039.94, Média C_min: 3431.69
#
# === Linha 3/32 (bloco 0, jammer=[0, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 29.56 18.70 34.40 38.90 50.14 18.49 55.27 37.92 39.12 17.41 48.80 37.80 60.28 16.99 70.54 35.84 48.68 16.11 63.20 36.70 70.42 15.48 85.80 33.76 58.24 14.81 77.60 35.59 80.56 13.97 101.07 31.67 67.80 13.52 92.00 34.49 90.70 12.46 116.34 29.59
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['11090.53', '10749.57', '10303.25', '9703.60', '8960.62', '7542.44']
# Todos os C_min_total: ['1219.27', '2657.50', '4288.48', '5581.52', '6308.30', '5786.15']
# Fitness por timeslot: ['13522349.0985', '28566952.8948', '44185262.4361', '54160836.2571', '56526234.7916', '43641684.8697']
# Média dos C_média_total: 9725.00 bps
# Média dos C_min_total: 4306.87 bps
# 🎯 Fitness do Epoch (CORRETO) = 40100553.3913
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 40100553.3913, Média C_media: 9725.00, Média C_min: 4306.87
#
# === Linha 4/32 (bloco 0, jammer=[0, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 35.78 19.54 28.10 38.07 55.81 21.93 48.19 40.51 51.57 19.07 36.20 36.14 71.62 23.86 56.39 41.01 67.35 18.61 44.31 34.21 87.43 25.79 64.58 41.52 83.13 18.14 52.41 32.27 103.24 27.72 72.77 42.02 98.91 17.68 60.51 30.34 119.05 29.65 80.97 42.53
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['11090.53', '11400.67', '11079.40', '9972.95', '8475.20', '6991.47']
# Todos os C_min_total: ['1219.27', '1930.96', '3663.50', '4784.89', '5133.50', '4997.26']
# Fitness por timeslot: ['13522349.0985', '22014235.6411', '40589309.7755', '47719431.1090', '43507411.4575', '34938210.8950']
# Média dos C_média_total: 9835.04 bps
# Média dos C_min_total: 3621.56 bps
# 🎯 Fitness do Epoch (CORRETO) = 33715157.9961
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 33715157.9961, Média C_media: 9835.04, Média C_min: 3621.56
#
# === Linha 5/32 (bloco 1, jammer=[200, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 36.86 16.35 28.02 37.81 55.35 21.82 49.93 42.91 53.73 12.69 36.04 35.62 70.70 23.64 59.85 45.82 70.59 9.04 44.07 33.43 86.05 25.46 69.78 48.74 87.45 5.38 52.09 31.24 101.40 27.27 79.70 51.65 104.31 1.73 60.11 29.05 116.75 29.09 89.63 54.56
#
# Análise para Época 1:
# 🚨 SOLUÇÃO COM COLISÕES DETECTADA!
#    Fitness = 0.0 (igual ao evaluate_individual)
#    Não será feita análise detalhada.
# ==================================================
# → Fitness: 0.0000, Média C_media: 0.00, Média C_min: 0.00
#
# === Linha 6/32 (bloco 1, jammer=[200, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.67 19.13 29.47 39.66 55.33 19.23 49.66 39.34 49.35 18.26 38.94 39.33 70.66 18.46 59.31 38.68 64.02 17.39 48.40 38.99 86.00 17.70 68.97 38.01 78.69 16.52 57.87 38.65 101.33 16.93 78.62 37.35 93.37 15.65 67.34 38.32 116.66 16.16 88.28 36.69
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7815.03', '8651.42', '9235.51', '9638.35', '9935.60', '8702.33']
# Todos os C_min_total: ['4958.03', '6062.78', '6406.52', '6292.40', '5939.74', '4325.26']
# Fitness por timeslot: ['38747167.9394', '52451643.6942', '59167482.5024', '60648311.0331', '59014931.1485', '37639849.0716']
# Média dos C_média_total: 8996.37 bps
# Média dos C_min_total: 5664.12 bps
# 🎯 Fitness do Epoch (CORRETO) = 51278230.8982
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 51278230.8982, Média C_media: 8996.37, Média C_min: 5664.12
#
# === Linha 7/32 (bloco 1, jammer=[200, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.17 20.50 29.26 40.22 53.75 20.51 50.25 40.40 46.34 21.00 38.53 40.44 67.51 21.02 60.51 40.80 59.51 21.50 47.79 40.66 81.26 21.52 70.76 41.19 72.67 22.00 57.06 40.88 95.01 22.03 81.01 41.59 85.84 22.50 66.32 41.11 108.77 22.54 91.26 41.99
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7815.03', '8364.63', '8734.87', '8961.47', '9076.13', '9126.55']
# Todos os C_min_total: ['4958.03', '6184.20', '6849.38', '7045.77', '6940.45', '6657.10']
# Fitness por timeslot: ['38747167.9394', '51728606.7333', '59828415.9870', '63140423.2739', '62992453.5600', '60756366.5847']
# Média dos C_média_total: 8679.78 bps
# Média dos C_min_total: 6439.16 bps
# 🎯 Fitness do Epoch (CORRETO) = 56198905.6797
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 56198905.6797, Média C_media: 8679.78, Média C_min: 6439.16
#
# === Linha 8/32 (bloco 1, jammer=[200, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.21 16.66 29.21 36.90 54.26 16.84 49.78 36.72 48.43 13.32 38.41 33.80 68.53 13.69 59.57 33.43 62.64 9.99 47.62 30.71 82.79 10.53 69.35 30.15 76.85 6.65 56.83 27.61 97.06 7.37 79.13 26.86 91.07 3.31 66.03 24.51 111.32 4.21 88.92 23.58
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7815.03', '8595.70', '9157.59', '9561.56', '9852.31', '10068.56']
# Todos os C_min_total: ['4958.03', '6074.54', '6576.80', '6618.42', '6406.01', '6063.47']
# Fitness por timeslot: ['38747167.9394', '52214913.7349', '60227654.9309', '63282396.8737', '63114003.7051', '61050372.7273']
# Média dos C_média_total: 9175.12 bps
# Média dos C_min_total: 6116.21 bps
# 🎯 Fitness do Epoch (CORRETO) = 56439418.3186
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 56439418.3186, Média C_media: 9175.12, Média C_min: 6116.21
#
# === Linha 9/32 (bloco 2, jammer=[400, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.31 20.73 30.27 41.20 54.42 16.09 54.77 37.71 48.61 21.46 40.55 42.39 68.83 12.18 69.54 35.42 62.92 22.19 50.82 43.59 83.25 8.27 84.31 33.13 77.23 22.92 61.10 44.79 97.66 4.36 99.08 30.84 91.53 23.65 71.37 45.99 112.08 0.45 113.85 28.55
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['6855.68', '8725.60', '10974.97', '10333.15', '9805.24', '8739.06']
# Todos os C_min_total: ['2683.63', '5057.02', '6906.88', '7636.14', '6571.51', '5495.09']
# Fitness por timeslot: ['18398146.0438', '44125524.2453', '75802792.3411', '78905401.1218', '64435219.8680', '48021868.7508']
# Média dos C_média_total: 9238.95 bps
# Média dos C_min_total: 5725.04 bps
# 🎯 Fitness do Epoch (CORRETO) = 54948158.7285
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 54948158.7285, Média C_media: 9238.95, Média C_min: 5725.04
#
# === Linha 10/32 (bloco 2, jammer=[400, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 35.67 22.16 34.14 42.75 55.57 19.59 55.80 40.41 51.33 24.32 48.28 45.50 71.13 19.18 71.61 40.83 67.00 26.48 62.42 48.25 86.70 18.77 87.41 41.24 82.66 28.64 76.56 51.01 102.26 18.36 103.22 41.65 98.33 30.81 90.69 53.76 117.83 17.95 119.02 42.07
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['6855.68', '7852.01', '9539.49', '11293.19', '12290.94', '12148.26']
# Todos os C_min_total: ['2683.63', '4805.56', '7240.17', '8500.25', '6962.37', '5690.96']
# Fitness por timeslot: ['18398146.0438', '37733304.0567', '69067529.3970', '95994931.8270', '85574050.6883', '69135270.8846']
# Média dos C_média_total: 9996.60 bps
# Média dos C_min_total: 5980.49 bps
# 🎯 Fitness do Epoch (CORRETO) = 62650538.8162
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 62650538.8162, Média C_media: 9996.60, Média C_min: 5980.49
#
# === Linha 11/32 (bloco 2, jammer=[400, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 30.64 21.62 30.60 41.66 52.38 18.44 50.99 38.46 41.28 23.24 41.20 43.32 64.76 16.89 61.99 36.92 51.92 24.85 51.80 44.98 77.14 15.33 72.98 35.38 62.56 26.47 62.41 46.63 89.52 13.78 83.98 33.85 73.19 28.09 73.01 48.29 101.89 12.22 94.97 32.31
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['6855.68', '8310.76', '10409.08', '12109.97', '12674.75', '12102.47']
# Todos os C_min_total: ['2683.63', '6167.74', '9634.06', '8992.60', '7615.05', '6447.07']
# Fitness por timeslot: ['18398146.0438', '51258630.0108', '100281733.5852', '108900113.3029', '96518851.4306', '78025442.3459']
# Média dos C_média_total: 10410.45 bps
# Média dos C_min_total: 6923.36 bps
# 🎯 Fitness do Epoch (CORRETO) = 75563819.4532
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 75563819.4532, Média C_media: 10410.45, Média C_min: 6923.36
#
# === Linha 12/32 (bloco 2, jammer=[400, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 31.07 21.72 30.14 41.76 52.82 18.32 51.10 38.28 42.14 23.44 40.29 43.53 65.64 16.64 62.20 36.56 53.21 25.16 50.43 45.29 78.46 14.96 73.30 34.84 64.27 26.89 60.57 47.05 91.28 13.28 84.39 33.12 75.34 28.61 70.71 48.82 104.10 11.61 95.49 31.40
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['6855.68', '8448.88', '10590.98', '12117.09', '12472.13', '11812.11']
# Todos os C_min_total: ['2683.63', '6264.75', '10200.83', '9285.59', '8023.13', '6950.54']
# Fitness por timeslot: ['18398146.0438', '52930122.4273', '108036817.6580', '112514345.5475', '100065546.7447', '82100507.6998']
# Média dos C_média_total: 10382.81 bps
# Média dos C_min_total: 7234.75 bps
# 🎯 Fitness do Epoch (CORRETO) = 79007581.0202
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 79007581.0202, Média C_media: 10382.81, Média C_min: 7234.75
#
# === Linha 13/32 (bloco 3, jammer=[600, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 30.37 27.60 39.02 38.79 44.42 26.00 55.92 41.82 40.75 35.20 58.04 37.57 48.84 32.00 71.83 43.64 51.12 42.80 77.05 36.36 53.26 38.00 87.75 45.47 61.50 50.39 96.07 35.15 57.68 43.99 103.67 47.29 71.87 57.99 115.09 33.93 62.10 49.99 119.58 49.11
#
# Análise para Época 1:
# 🚨 SOLUÇÃO COM COLISÕES DETECTADA!
#    Fitness = 0.0 (igual ao evaluate_individual)
#    Não será feita análise detalhada.
# ==================================================
# → Fitness: 0.0000, Média C_media: 0.00, Média C_min: 0.00
#
# === Linha 14/32 (bloco 3, jammer=[600, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.45 16.98 29.29 37.70 54.29 16.09 49.46 37.57 46.90 13.96 38.57 35.40 68.59 12.19 58.92 35.15 60.35 10.95 47.86 33.10 82.88 8.28 68.39 32.72 73.79 7.93 57.15 30.80 97.18 4.37 77.85 30.29 87.24 4.91 66.43 28.50 111.47 0.47 87.31 27.87
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7819.08', '8864.91', '10871.23', '12228.84', '12310.44', '11586.36']
# Todos os C_min_total: ['2432.20', '6434.94', '10604.25', '9002.71', '7809.32', '6905.33']
# Fitness por timeslot: ['19017551.9457', '57045163.1135', '115281241.8358', '110092716.9630', '96136081.1935', '80007620.0409']
# Média dos C_média_total: 10613.47 bps
# Média dos C_min_total: 7198.13 bps
# 🎯 Fitness do Epoch (CORRETO) = 79596729.1821
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 79596729.1821, Média C_media: 10613.47, Média C_min: 7198.13
#
# === Linha 15/32 (bloco 3, jammer=[600, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 35.13 21.35 30.86 42.72 55.36 21.06 51.45 41.38 50.25 22.70 41.73 45.44 70.71 22.12 62.91 42.76 65.38 24.05 52.59 48.16 86.07 23.18 74.36 44.14 80.50 25.41 63.45 50.88 101.43 24.25 85.81 45.52 95.63 26.76 74.32 53.59 116.79 25.31 97.27 46.90
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7819.08', '8752.15', '10766.22', '12421.41', '12812.74', '12225.98']
# Todos os C_min_total: ['2432.20', '5956.50', '10568.89', '9431.50', '8229.20', '7296.12']
# Fitness por timeslot: ['19017551.9457', '52132166.0576', '113786989.4063', '117152519.9260', '105438637.6223', '89202251.5818']
# Média dos C_média_total: 10799.60 bps
# Média dos C_min_total: 7319.07 bps
# 🎯 Fitness do Epoch (CORRETO) = 82788352.7566
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 82788352.7566, Média C_media: 10799.60, Média C_min: 7319.07
#
# === Linha 16/32 (bloco 3, jammer=[600, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.55 20.25 29.13 43.05 54.67 20.17 49.29 40.49 49.10 20.51 38.26 46.10 69.33 20.34 58.57 40.99 63.65 20.76 47.39 49.16 84.00 20.51 67.86 41.48 78.20 21.01 56.52 52.21 98.66 20.67 77.14 41.98 92.75 21.26 65.65 55.26 113.33 20.84 86.43 42.47
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['7819.08', '9539.27', '11915.04', '12610.20', '10924.74', '9913.55']
# Todos os C_min_total: ['2432.20', '7122.81', '10488.30', '8937.17', '7779.66', '6882.46']
# Fitness por timeslot: ['19017551.9457', '67946372.2815', '124968514.3043', '112699509.6330', '84990818.3301', '68229643.3693']
# Média dos C_média_total: 10453.65 bps
# Média dos C_min_total: 7273.77 bps
# 🎯 Fitness do Epoch (CORRETO) = 79642068.3106
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 79642068.3106, Média C_media: 10453.65, Média C_min: 7273.77
#
# === Linha 17/32 (bloco 4, jammer=[800, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.71 21.88 32.82 42.74 55.41 20.48 53.28 41.93 49.41 23.77 45.64 45.47 70.82 20.96 66.56 43.86 64.12 25.65 58.46 48.21 86.22 21.44 79.84 45.79 78.82 27.54 71.28 50.95 101.63 21.92 93.12 47.72 93.53 29.42 84.10 53.68 117.04 22.40 106.40 49.65
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['9875.09', '11295.30', '12711.10', '13876.05', '14671.06', '15089.02']
# Todos os C_min_total: ['6628.02', '9462.30', '12025.43', '12451.59', '11655.07', '10972.59']
# Fitness por timeslot: ['65452297.4910', '106879524.7898', '152856455.3306', '172778826.7520', '170992227.7736', '165565586.4608']
# Média dos C_média_total: 12919.61 bps
# Média dos C_min_total: 10532.50 bps
# 🎯 Fitness do Epoch (CORRETO) = 139087486.4330
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 139087486.4330, Média C_media: 12919.61, Média C_min: 10532.50
#
# === Linha 18/32 (bloco 4, jammer=[800, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 32.85 17.08 28.95 39.98 53.01 17.05 49.53 37.31 45.70 14.16 37.89 39.97 66.02 14.09 59.07 34.61 58.55 11.23 46.84 39.95 79.03 11.14 68.60 31.92 71.40 8.31 55.79 39.94 92.04 8.19 78.14 29.23 84.25 5.39 64.74 39.92 105.05 5.23 87.67 26.54
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['9875.09', '12878.38', '15517.77', '16645.69', '16247.97', '13160.59']
# Todos os C_min_total: ['6628.02', '12247.08', '11756.91', '10451.62', '9446.79', '7777.62']
# Fitness por timeslot: ['65452297.4910', '157722536.7958', '182441003.3398', '173974449.6061', '153491102.8875', '102358032.7162']
# Média dos C_média_total: 14054.25 bps
# Média dos C_min_total: 9718.01 bps
# 🎯 Fitness do Epoch (CORRETO) = 139239903.8061
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 139239903.8061, Média C_media: 14054.25, Média C_min: 9718.01
#
# === Linha 19/32 (bloco 4, jammer=[800, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.41 19.99 31.25 41.14 53.58 18.91 51.30 39.67 46.81 19.98 42.50 42.29 67.16 17.82 62.60 39.34 60.22 19.97 53.75 43.43 80.74 16.73 73.89 39.00 73.62 19.96 65.00 44.58 94.32 15.64 85.19 38.67 87.03 19.95 76.25 45.72 107.90 14.55 96.49 38.34
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['9875.09', '11704.12', '13560.20', '15091.70', '16067.76', '16497.56']
# Todos os C_min_total: ['6628.02', '10097.45', '13182.31', '13025.40', '12318.80', '11698.57']
# Fitness por timeslot: ['65452297.4910', '118181777.5170', '178754885.0218', '196575403.6469', '197935406.2908', '192997754.1517']
# Média dos C_média_total: 13799.40 bps
# Média dos C_min_total: 11158.42 bps
# 🎯 Fitness do Epoch (CORRETO) = 158316254.0199
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 158316254.0199, Média C_media: 13799.40, Média C_min: 11158.42
#
# === Linha 20/32 (bloco 4, jammer=[800, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 36.17 21.69 31.18 42.60 55.58 16.69 51.17 41.77 52.35 23.38 42.37 45.20 71.16 13.39 62.33 43.55 68.52 25.07 53.55 47.80 86.74 10.08 73.50 45.32 84.69 26.77 64.74 50.40 102.31 6.78 84.67 47.10 100.86 28.46 75.92 53.00 117.89 3.47 95.84 48.87
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['9875.09', '13886.85', '15988.61', '15551.72', '15307.67', '14000.61']
# Todos os C_min_total: ['6628.02', '11089.34', '12934.63', '11680.86', '10608.35', '9674.07']
# Fitness por timeslot: ['65452297.4910', '153995976.8295', '206806760.7954', '181657365.4404', '162389090.6446', '135442898.1734']
# Média dos C_média_total: 14101.76 bps
# Média dos C_min_total: 10435.88 bps
# 🎯 Fitness do Epoch (CORRETO) = 150957398.2290
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 150957398.2290, Média C_media: 14101.76, Média C_min: 10435.88
#
# === Linha 21/32 (bloco 5, jammer=[1000, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 30.31 21.72 28.50 43.61 52.57 18.18 50.64 39.22 40.62 23.45 37.01 47.22 65.14 16.37 61.27 38.44 50.93 25.17 45.51 50.83 77.72 14.55 71.91 37.66 61.24 26.90 54.01 54.44 90.29 12.74 82.55 36.88 71.55 28.62 62.51 58.05 102.86 10.92 93.18 36.10
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14147.89', '16389.85', '18099.39', '19157.16', '19606.29', '17423.94']
# Todos os C_min_total: ['13142.74', '14565.47', '13433.81', '12388.82', '11462.65', '8455.18']
# Fitness por timeslot: ['185942073.5601', '238725759.3784', '243143696.6854', '237334551.1594', '224739923.3798', '147322527.8149']
# Média dos C_média_total: 17470.75 bps
# Média dos C_min_total: 12241.44 bps
# 🎯 Fitness do Epoch (CORRETO) = 212868088.6630
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 212868088.6630, Média C_media: 17470.75, Média C_min: 12241.44
#
# === Linha 22/32 (bloco 5, jammer=[1000, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.09 20.71 31.30 43.17 53.57 19.79 52.05 39.76 46.18 21.41 42.61 46.34 67.13 19.58 64.10 39.52 59.27 22.12 53.91 49.51 80.70 19.37 76.14 39.27 72.35 22.83 65.21 52.68 94.27 19.16 88.19 39.03 85.44 23.54 76.52 55.85 107.83 18.95 100.24 38.79
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14147.89', '16394.50', '18276.16', '19770.49', '18320.47', '17563.47']
# Todos os C_min_total: ['13142.74', '15399.97', '14961.71', '14429.18', '11021.08', '10591.47']
# Fitness por timeslot: ['185942073.5601', '252474847.2724', '273442702.7486', '285271856.6436', '201911345.0200', '186022881.0816']
# Média dos C_média_total: 17412.16 bps
# Média dos C_min_total: 13257.69 bps
# 🎯 Fitness do Epoch (CORRETO) = 230844284.3877
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 230844284.3877, Média C_media: 17412.16, Média C_min: 13257.69
#
# === Linha 23/32 (bloco 5, jammer=[1000, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 29.94 22.08 28.91 42.37 52.59 17.19 50.73 37.24 39.88 24.17 37.82 44.74 65.17 14.39 61.47 34.48 49.82 26.25 46.73 47.11 77.76 11.58 72.20 31.72 59.76 28.34 55.63 49.48 90.34 8.77 82.94 28.96 69.70 30.42 64.54 51.85 102.93 5.96 93.67 26.20
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14147.89', '16403.06', '18633.44', '20595.53', '22032.44', '17505.96']
# Todos os C_min_total: ['13142.74', '14895.68', '13962.52', '13041.75', '12185.39', '8155.76']
# Fitness por timeslot: ['185942073.5601', '244334712.0148', '260169897.2247', '268601661.5898', '268473879.1771', '142774472.4424']
# Média dos C_média_total: 18219.72 bps
# Média dos C_min_total: 12563.97 bps
# 🎯 Fitness do Epoch (CORRETO) = 228382782.6681
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 228382782.6681, Média C_media: 18219.72, Média C_min: 12563.97
#
# === Linha 24/32 (bloco 5, jammer=[1000, 500]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.28 20.97 31.67 41.06 53.88 16.91 51.76 40.74 48.56 21.95 43.34 42.12 67.77 13.82 63.53 41.47 62.84 22.92 55.01 43.18 81.65 10.73 75.29 42.21 77.12 23.89 66.68 44.24 95.54 7.64 87.05 42.95 91.40 24.87 78.35 45.30 109.42 4.55 98.81 43.69
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14147.89', '17596.02', '20124.47', '21253.95', '19290.36', '17015.24']
# Todos os C_min_total: ['13142.74', '15695.92', '15934.14', '15532.90', '13015.38', '11426.09']
# Fitness por timeslot: ['185942073.5601', '276185762.4675', '320666219.9921', '330135618.1347', '251071320.2779', '194417651.5992']
# Média dos C_média_total: 18237.99 bps
# Média dos C_min_total: 14124.53 bps
# 🎯 Fitness do Epoch (CORRETO) = 259736441.0053
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 259736441.0053, Média C_media: 18237.99, Média C_min: 14124.53
#
# === Linha 25/32 (bloco 6, jammer=[0, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 38.67 25.33 35.03 38.59 44.47 21.37 45.20 40.24 57.35 30.65 50.06 37.18 48.93 22.73 50.39 40.49 76.02 35.98 65.09 35.77 53.40 24.10 55.59 40.73 94.70 41.30 80.12 34.36 57.86 25.46 60.78 40.98 113.37 46.63 95.15 32.95 62.33 26.83 65.98 41.22
#
# Análise para Época 1:
# 🚨 SOLUÇÃO COM COLISÕES DETECTADA!
#    Fitness = 0.0 (igual ao evaluate_individual)
#    Não será feita análise detalhada.
# ==================================================
# → Fitness: 0.0000, Média C_media: 0.00, Média C_min: 0.00
#
# === Linha 26/32 (bloco 6, jammer=[0, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.01 19.53 31.91 40.40 52.95 21.26 52.04 41.38 46.01 19.07 43.81 40.79 65.89 22.52 64.08 42.76 59.02 18.60 55.72 41.19 78.84 23.78 76.12 44.14 72.03 18.14 67.62 41.59 91.78 25.04 88.16 45.52 85.04 17.67 79.53 41.98 104.73 26.30 100.20 46.90
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['199.96', '436.59', '818.87', '1235.21', '1365.24', '1672.77']
# Todos os C_min_total: ['20.39', '38.61', '91.21', '178.79', '258.50', '443.25']
# Fitness por timeslot: ['4077.4221', '16854.8676', '74685.2267', '220845.0460', '352914.7711', '741452.9126']
# Média dos C_média_total: 954.77 bps
# Média dos C_min_total: 171.79 bps
# 🎯 Fitness do Epoch (CORRETO) = 235138.3743
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 235138.3743, Média C_media: 954.77, Média C_min: 171.79
#
# === Linha 27/32 (bloco 6, jammer=[0, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.92 21.88 35.30 42.07 53.63 17.39 55.05 37.40 47.83 23.76 50.60 44.15 67.26 14.77 70.10 34.81 61.75 25.64 65.89 46.22 80.89 12.16 85.15 32.21 75.66 27.52 81.19 48.29 94.52 9.54 100.20 29.62 89.58 29.40 96.49 50.37 108.15 6.93 115.25 27.02
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['199.96', '617.47', '901.26', '1301.99', '1448.14', '1634.75']
# Todos os C_min_total: ['20.39', '52.86', '131.82', '265.95', '458.87', '562.25']
# Fitness por timeslot: ['4077.4221', '32636.2837', '118801.3047', '346261.3077', '664514.0828', '919145.1411']
# Média dos C_média_total: 1017.26 bps
# Média dos C_min_total: 248.69 bps
# 🎯 Fitness do Epoch (CORRETO) = 347572.5904
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 347572.5904, Média C_media: 1017.26, Média C_min: 248.69
#
# === Linha 28/32 (bloco 6, jammer=[0, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 33.60 22.98 34.97 43.76 53.21 16.47 53.66 36.49 47.21 25.96 49.94 47.51 66.42 12.94 67.32 32.98 60.81 28.94 64.92 51.27 79.63 9.41 80.99 29.48 74.42 31.91 79.89 55.03 92.84 5.88 94.65 25.97 88.02 34.89 94.86 58.78 106.05 2.35 108.31 22.46
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['199.96', '589.87', '849.20', '1306.08', '1556.27', '1956.59']
# Todos os C_min_total: ['20.39', '52.89', '141.65', '403.50', '729.50', '816.31']
# Fitness por timeslot: ['4077.4221', '31198.2893', '120286.4720', '527003.7505', '1135304.3701', '1597176.2446']
# Média dos C_média_total: 1076.33 bps
# Média dos C_min_total: 360.71 bps
# 🎯 Fitness do Epoch (CORRETO) = 569174.4248
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 569174.4248, Média C_media: 1076.33, Média C_min: 360.71
#
# === Linha 29/32 (bloco 7, jammer=[1000, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.81 16.61 29.34 37.04 55.45 18.05 50.07 43.73 49.63 13.23 38.68 34.09 70.90 16.10 60.14 47.46 64.44 9.84 48.02 31.13 86.36 14.15 70.21 51.19 79.25 6.46 57.36 28.17 101.81 12.20 80.28 54.92 94.06 3.07 66.70 25.21 117.26 10.24 90.35 58.65
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14507.19', '14348.79', '10228.51', '8096.97', '6784.57', '6064.35']
# Todos os C_min_total: ['1447.10', '5742.30', '8356.91', '3290.19', '2028.27', '2956.60']
# Fitness por timeslot: ['20993341.4804', '82395056.9026', '85478674.7140', '26640608.6504', '13760916.3738', '17929868.1286']
# Média dos C_média_total: 10005.06 bps
# Média dos C_min_total: 3970.23 bps
# 🎯 Fitness do Epoch (CORRETO) = 41199744.3750
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 41199744.3750, Média C_media: 10005.06, Média C_min: 3970.23
#
# === Linha 30/32 (bloco 7, jammer=[1000, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 35.62 19.94 39.30 35.22 55.22 23.90 54.26 34.16 51.24 19.87 58.61 30.43 70.44 27.80 68.51 28.31 66.86 19.81 77.91 25.65 85.66 31.70 82.77 22.47 82.48 19.74 97.22 20.86 100.88 35.60 97.03 16.63 98.11 19.68 116.52 16.08 116.10 39.50 111.28 10.78
#
# Análise para Época 1:
# 🚨 SOLUÇÃO COM COLISÕES DETECTADA!
#    Fitness = 0.0 (igual ao evaluate_individual)
#    Não será feita análise detalhada.
# ==================================================
# → Fitness: 0.0000, Média C_media: 0.00, Média C_min: 0.00
#
# === Linha 31/32 (bloco 7, jammer=[1000, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 34.82 23.88 36.19 43.84 54.05 16.06 54.91 36.39 49.63 27.77 52.37 47.69 68.09 12.12 69.83 32.77 64.45 31.65 68.56 51.53 82.14 8.18 84.74 29.16 79.27 35.53 84.75 55.37 96.19 4.24 99.66 25.55 94.08 39.42 100.93 59.21 110.24 0.30 114.57 21.94
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14507.19', '19340.99', '19389.74', '18683.88', '17319.07', '12571.63']
# Todos os C_min_total: ['1447.10', '4137.07', '7175.03', '9186.65', '9993.46', '7580.82']
# Fitness por timeslot: ['20993341.4804', '80015033.6532', '139121892.5180', '171642380.8336', '173077496.6049', '95303258.9790']
# Média dos C_média_total: 16968.75 bps
# Média dos C_min_total: 6586.69 bps
# 🎯 Fitness do Epoch (CORRETO) = 113358900.6782
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 113358900.6782, Média C_media: 16968.75, Média C_min: 6586.69
#
# === Linha 32/32 (bloco 7, jammer=[1000, 30]) ===
# 20.00 20.00 20.00 40.00 40.00 20.00 40.00 40.00 31.80 23.49 33.10 43.58 50.52 16.11 52.26 37.60 43.60 26.99 46.20 47.16 61.04 12.22 64.52 35.20 55.40 30.48 59.30 50.74 71.57 8.33 76.78 32.80 67.20 33.98 72.40 54.32 82.09 4.44 89.05 30.41 78.99 37.47 85.50 57.90 92.61 0.55 101.31 28.01
#
# Análise para Época 1:
# ✅ Solução válida - prosseguindo com análise detalhada...
#
# ==================================================
# RESUMO DO EPOCH 1:
# Todos os C_média_total: ['14507.19', '18793.30', '18281.31', '17122.51', '15451.19', '12479.74']
# Todos os C_min_total: ['1447.10', '4321.56', '7742.73', '10026.29', '10889.34', '9211.75']
# Fitness por timeslot: ['20993341.4804', '81216456.5950', '141547242.1931', '171675250.4112', '168253211.1145', '114960242.9273']
# Média dos C_média_total: 16105.87 bps
# Média dos C_min_total: 7273.13 bps
# 🎯 Fitness do Epoch (CORRETO) = 116440957.4536
# ✅ Agora deve bater com o valor do gráfico!
# ==================================================
# → Fitness: 116440957.4536, Média C_media: 16105.87, Média C_min: 7273.13
